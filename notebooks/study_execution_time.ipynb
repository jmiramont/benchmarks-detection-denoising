# %%
import numpy as np
from numpy import pi as pi
import pandas as pd
from matplotlib import pyplot as plt
from mcsm_benchmarks.Benchmark import Benchmark
from mcsm_benchmarks.ResultsInterpreter import ResultsInterpreter
import pickle

# %%
from src.methods.method_pseudo_bayesian import NewMethod as Pb
from src.methods.method_sstrd import NewMethod as SstRd
from src.methods.method_contour_filtering import NewMethod as Contours
from src.methods.method_delaunay_triangulation import NewMethod as Dt
from src.methods.method_empty_space import NewMethod as Es
from src.methods.method_sz_classification import NewMethod as Szc
from src.methods.method_garrote_threshold import NewMethod as SoftThr
from src.methods.method_hard_threshold import NewMethod as HardThr

# %% [markdown]
# Let us create a dictionary of methods and a dictionary of parameters to evaluate:

# %%
# Create the dictionary with only one method.
my_methods = { 
              SstRd().id: SstRd().method,
              Contours().id: Contours().method,
              Dt().id: Dt().method,
              Es().id: Es().method,
              Pb().id: Pb().method,
              Szc().id: Szc().method,
              SoftThr().id: SoftThr().method,
              HardThr().id: HardThr().method,
              }

# Create the dictionary of parameters
my_parameters = {k:[([],{}),] for k in my_methods}

my_parameters[Es().id] = [ {'radi_seg':0.8,},{'adapt_thr': True,}]
my_parameters[Dt().id] = [ {'LB':1.6,},{'adapt_thr': True,}]

# %%
benchmark = Benchmark(task = 'denoising',
                        methods = my_methods,
                        parameters= my_parameters,
                        N = 2**11,
                        SNRin = [20,], 
                        repetitions = 100,
                        signal_ids=[ 'McMultiLinear',],
                        verbosity=5, 
                        parallelize=False)
                        
benchmark.run_test() # Run the test. my_results is a dictionary with the results for each of the variables of the simulation.
interpreter = ResultsInterpreter(benchmark)
df = interpreter.elapsed_time_summary()
df
# Out:
# Running benchmark...
# - Signal McMultiLinear
# -- SNR: 20 dB
# --- Method: brevdo_method
# ---- Parameters Combination: 0
# ------ Inner loop. brevdo_method: 0
# ------ Inner loop. brevdo_method: 1
# ------ Inner loop. brevdo_method: 2
# ------ Inner loop. brevdo_method: 3
# ------ Inner loop. brevdo_method: 4
# ------ Inner loop. brevdo_method: 5
# ------ Inner loop. brevdo_method: 6
# ------ Inner loop. brevdo_method: 7
# ------ Inner loop. brevdo_method: 8
# ------ Inner loop. brevdo_method: 9
# ------ Inner loop. brevdo_method: 10
# ------ Inner loop. brevdo_method: 11
# ------ Inner loop. brevdo_method: 12
# ------ Inner loop. brevdo_method: 13
# ------ Inner loop. brevdo_method: 14
# ------ Inner loop. brevdo_method: 15
# ------ Inner loop. brevdo_method: 16
# ------ Inner loop. brevdo_method: 17
# ------ Inner loop. brevdo_method: 18
# ------ Inner loop. brevdo_method: 19
# ------ Inner loop. brevdo_method: 20
# ------ Inner loop. brevdo_method: 21
# ------ Inner loop. brevdo_method: 22
# ------ Inner loop. brevdo_method: 23
# ------ Inner loop. brevdo_method: 24
# ------ Inner loop. brevdo_method: 25
# ------ Inner loop. brevdo_method: 26
# ------ Inner loop. brevdo_method: 27
# ------ Inner loop. brevdo_method: 28
# ------ Inner loop. brevdo_method: 29
# ------ Inner loop. brevdo_method: 30
# ------ Inner loop. brevdo_method: 31
# ------ Inner loop. brevdo_method: 32
# ------ Inner loop. brevdo_method: 33
# ------ Inner loop. brevdo_method: 34
# ------ Inner loop. brevdo_method: 35
# ------ Inner loop. brevdo_method: 36
# ------ Inner loop. brevdo_method: 37
# ------ Inner loop. brevdo_method: 38
# ------ Inner loop. brevdo_method: 39
# ------ Inner loop. brevdo_method: 40
# ------ Inner loop. brevdo_method: 41
# ------ Inner loop. brevdo_method: 42
# ------ Inner loop. brevdo_method: 43
# ------ Inner loop. brevdo_method: 44
# ------ Inner loop. brevdo_method: 45
# ------ Inner loop. brevdo_method: 46
# ------ Inner loop. brevdo_method: 47
# ------ Inner loop. brevdo_method: 48
# ------ Inner loop. brevdo_method: 49
# ------ Inner loop. brevdo_method: 50
# ------ Inner loop. brevdo_method: 51
# ------ Inner loop. brevdo_method: 52
# ------ Inner loop. brevdo_method: 53
# ------ Inner loop. brevdo_method: 54
# ------ Inner loop. brevdo_method: 55
# ------ Inner loop. brevdo_method: 56
# ------ Inner loop. brevdo_method: 57
# ------ Inner loop. brevdo_method: 58
# ------ Inner loop. brevdo_method: 59
# ------ Inner loop. brevdo_method: 60
# ------ Inner loop. brevdo_method: 61
# ------ Inner loop. brevdo_method: 62
# ------ Inner loop. brevdo_method: 63
# ------ Inner loop. brevdo_method: 64
# ------ Inner loop. brevdo_method: 65
# ------ Inner loop. brevdo_method: 66
# ------ Inner loop. brevdo_method: 67
# ------ Inner loop. brevdo_method: 68
# ------ Inner loop. brevdo_method: 69
# ------ Inner loop. brevdo_method: 70
# ------ Inner loop. brevdo_method: 71
# ------ Inner loop. brevdo_method: 72
# ------ Inner loop. brevdo_method: 73
# ------ Inner loop. brevdo_method: 74
# ------ Inner loop. brevdo_method: 75
# ------ Inner loop. brevdo_method: 76
# ------ Inner loop. brevdo_method: 77
# ------ Inner loop. brevdo_method: 78
# ------ Inner loop. brevdo_method: 79
# ------ Inner loop. brevdo_method: 80
# ------ Inner loop. brevdo_method: 81
# ------ Inner loop. brevdo_method: 82
# ------ Inner loop. brevdo_method: 83
# ------ Inner loop. brevdo_method: 84
# ------ Inner loop. brevdo_method: 85
# ------ Inner loop. brevdo_method: 86
# ------ Inner loop. brevdo_method: 87
# ------ Inner loop. brevdo_method: 88
# ------ Inner loop. brevdo_method: 89
# ------ Inner loop. brevdo_method: 90
# ------ Inner loop. brevdo_method: 91
# ------ Inner loop. brevdo_method: 92
# ------ Inner loop. brevdo_method: 93
# ------ Inner loop. brevdo_method: 94
# ------ Inner loop. brevdo_method: 95
# ------ Inner loop. brevdo_method: 96
# ------ Inner loop. brevdo_method: 97
# ------ Inner loop. brevdo_method: 98
# ------ Inner loop. brevdo_method: 99
# Elapsed:3.3180847787857055
# --- Method: contour_filtering
# ---- Parameters Combination: 0
# ------ Inner loop. contour_filtering: 0
# ------ Inner loop. contour_filtering: 1
# ------ Inner loop. contour_filtering: 2
# ------ Inner loop. contour_filtering: 3
# ------ Inner loop. contour_filtering: 4
# ------ Inner loop. contour_filtering: 5
# ------ Inner loop. contour_filtering: 6
# ------ Inner loop. contour_filtering: 7
# ------ Inner loop. contour_filtering: 8
# ------ Inner loop. contour_filtering: 9
# ------ Inner loop. contour_filtering: 10
# ------ Inner loop. contour_filtering: 11
# ------ Inner loop. contour_filtering: 12
# ------ Inner loop. contour_filtering: 13
# ------ Inner loop. contour_filtering: 14
# ------ Inner loop. contour_filtering: 15
# ------ Inner loop. contour_filtering: 16
# ------ Inner loop. contour_filtering: 17
# ------ Inner loop. contour_filtering: 18
# ------ Inner loop. contour_filtering: 19
# ------ Inner loop. contour_filtering: 20
# ------ Inner loop. contour_filtering: 21
# ------ Inner loop. contour_filtering: 22
# ------ Inner loop. contour_filtering: 23
# ------ Inner loop. contour_filtering: 24
# ------ Inner loop. contour_filtering: 25
# ------ Inner loop. contour_filtering: 26
# ------ Inner loop. contour_filtering: 27
# ------ Inner loop. contour_filtering: 28
# ------ Inner loop. contour_filtering: 29
# ------ Inner loop. contour_filtering: 30
# ------ Inner loop. contour_filtering: 31
# ------ Inner loop. contour_filtering: 32
# ------ Inner loop. contour_filtering: 33
# ------ Inner loop. contour_filtering: 34
# ------ Inner loop. contour_filtering: 35
# ------ Inner loop. contour_filtering: 36
# ------ Inner loop. contour_filtering: 37
# ------ Inner loop. contour_filtering: 38
# ------ Inner loop. contour_filtering: 39
# ------ Inner loop. contour_filtering: 40
# ------ Inner loop. contour_filtering: 41
# ------ Inner loop. contour_filtering: 42
# ------ Inner loop. contour_filtering: 43
# ------ Inner loop. contour_filtering: 44
# ------ Inner loop. contour_filtering: 45
# ------ Inner loop. contour_filtering: 46
# ------ Inner loop. contour_filtering: 47
# ------ Inner loop. contour_filtering: 48
# ------ Inner loop. contour_filtering: 49
# ------ Inner loop. contour_filtering: 50
# ------ Inner loop. contour_filtering: 51
# ------ Inner loop. contour_filtering: 52
# ------ Inner loop. contour_filtering: 53
# ------ Inner loop. contour_filtering: 54
# ------ Inner loop. contour_filtering: 55
# ------ Inner loop. contour_filtering: 56
# ------ Inner loop. contour_filtering: 57
# ------ Inner loop. contour_filtering: 58
# ------ Inner loop. contour_filtering: 59
# ------ Inner loop. contour_filtering: 60
# ------ Inner loop. contour_filtering: 61
# ------ Inner loop. contour_filtering: 62
# ------ Inner loop. contour_filtering: 63
# ------ Inner loop. contour_filtering: 64
# ------ Inner loop. contour_filtering: 65
# ------ Inner loop. contour_filtering: 66
# ------ Inner loop. contour_filtering: 67
# ------ Inner loop. contour_filtering: 68
# ------ Inner loop. contour_filtering: 69
# ------ Inner loop. contour_filtering: 70
# ------ Inner loop. contour_filtering: 71
# ------ Inner loop. contour_filtering: 72
# ------ Inner loop. contour_filtering: 73
# ------ Inner loop. contour_filtering: 74
# ------ Inner loop. contour_filtering: 75
# ------ Inner loop. contour_filtering: 76
# ------ Inner loop. contour_filtering: 77
# ------ Inner loop. contour_filtering: 78
# ------ Inner loop. contour_filtering: 79
# ------ Inner loop. contour_filtering: 80
# ------ Inner loop. contour_filtering: 81
# ------ Inner loop. contour_filtering: 82
# ------ Inner loop. contour_filtering: 83
# ------ Inner loop. contour_filtering: 84
# ------ Inner loop. contour_filtering: 85
# ------ Inner loop. contour_filtering: 86
# ------ Inner loop. contour_filtering: 87
# ------ Inner loop. contour_filtering: 88
# ------ Inner loop. contour_filtering: 89
# ------ Inner loop. contour_filtering: 90
# ------ Inner loop. contour_filtering: 91
# ------ Inner loop. contour_filtering: 92
# ------ Inner loop. contour_filtering: 93
# ------ Inner loop. contour_filtering: 94
# ------ Inner loop. contour_filtering: 95
# ------ Inner loop. contour_filtering: 96
# ------ Inner loop. contour_filtering: 97
# ------ Inner loop. contour_filtering: 98
# ------ Inner loop. contour_filtering: 99
# Elapsed:106.59255025148391
# --- Method: delaunay_triangulation
# ---- Parameters Combination: 0
# ------ Inner loop. delaunay_triangulation: 0
# ------ Inner loop. delaunay_triangulation: 1
# ------ Inner loop. delaunay_triangulation: 2
# ------ Inner loop. delaunay_triangulation: 3
# ------ Inner loop. delaunay_triangulation: 4
# ------ Inner loop. delaunay_triangulation: 5
# ------ Inner loop. delaunay_triangulation: 6
# ------ Inner loop. delaunay_triangulation: 7
# ------ Inner loop. delaunay_triangulation: 8
# ------ Inner loop. delaunay_triangulation: 9
# ------ Inner loop. delaunay_triangulation: 10
# ------ Inner loop. delaunay_triangulation: 11
# ------ Inner loop. delaunay_triangulation: 12
# ------ Inner loop. delaunay_triangulation: 13
# ------ Inner loop. delaunay_triangulation: 14
# ------ Inner loop. delaunay_triangulation: 15
# ------ Inner loop. delaunay_triangulation: 16
# ------ Inner loop. delaunay_triangulation: 17
# ------ Inner loop. delaunay_triangulation: 18
# ------ Inner loop. delaunay_triangulation: 19
# ------ Inner loop. delaunay_triangulation: 20
# ------ Inner loop. delaunay_triangulation: 21
# ------ Inner loop. delaunay_triangulation: 22
# ------ Inner loop. delaunay_triangulation: 23
# ------ Inner loop. delaunay_triangulation: 24
# ------ Inner loop. delaunay_triangulation: 25
# ------ Inner loop. delaunay_triangulation: 26
# ------ Inner loop. delaunay_triangulation: 27
# ------ Inner loop. delaunay_triangulation: 28
# ------ Inner loop. delaunay_triangulation: 29
# ------ Inner loop. delaunay_triangulation: 30
# ------ Inner loop. delaunay_triangulation: 31
# ------ Inner loop. delaunay_triangulation: 32
# ------ Inner loop. delaunay_triangulation: 33
# ------ Inner loop. delaunay_triangulation: 34
# ------ Inner loop. delaunay_triangulation: 35
# ------ Inner loop. delaunay_triangulation: 36
# ------ Inner loop. delaunay_triangulation: 37
# ------ Inner loop. delaunay_triangulation: 38
# ------ Inner loop. delaunay_triangulation: 39
# ------ Inner loop. delaunay_triangulation: 40
# ------ Inner loop. delaunay_triangulation: 41
# ------ Inner loop. delaunay_triangulation: 42
# ------ Inner loop. delaunay_triangulation: 43
# ------ Inner loop. delaunay_triangulation: 44
# ------ Inner loop. delaunay_triangulation: 45
# ------ Inner loop. delaunay_triangulation: 46
# ------ Inner loop. delaunay_triangulation: 47
# ------ Inner loop. delaunay_triangulation: 48
# ------ Inner loop. delaunay_triangulation: 49
# ------ Inner loop. delaunay_triangulation: 50
# ------ Inner loop. delaunay_triangulation: 51
# ------ Inner loop. delaunay_triangulation: 52
# ------ Inner loop. delaunay_triangulation: 53
# ------ Inner loop. delaunay_triangulation: 54
# ------ Inner loop. delaunay_triangulation: 55
# ------ Inner loop. delaunay_triangulation: 56
# ------ Inner loop. delaunay_triangulation: 57
# ------ Inner loop. delaunay_triangulation: 58
# ------ Inner loop. delaunay_triangulation: 59
# ------ Inner loop. delaunay_triangulation: 60
# ------ Inner loop. delaunay_triangulation: 61
# ------ Inner loop. delaunay_triangulation: 62
# ------ Inner loop. delaunay_triangulation: 63
# ------ Inner loop. delaunay_triangulation: 64
# ------ Inner loop. delaunay_triangulation: 65
# ------ Inner loop. delaunay_triangulation: 66
# ------ Inner loop. delaunay_triangulation: 67
# ------ Inner loop. delaunay_triangulation: 68
# ------ Inner loop. delaunay_triangulation: 69
# ------ Inner loop. delaunay_triangulation: 70
# ------ Inner loop. delaunay_triangulation: 71
# ------ Inner loop. delaunay_triangulation: 72
# ------ Inner loop. delaunay_triangulation: 73
# ------ Inner loop. delaunay_triangulation: 74
# ------ Inner loop. delaunay_triangulation: 75
# ------ Inner loop. delaunay_triangulation: 76
# ------ Inner loop. delaunay_triangulation: 77
# ------ Inner loop. delaunay_triangulation: 78
# ------ Inner loop. delaunay_triangulation: 79
# ------ Inner loop. delaunay_triangulation: 80
# ------ Inner loop. delaunay_triangulation: 81
# ------ Inner loop. delaunay_triangulation: 82
# ------ Inner loop. delaunay_triangulation: 83
# ------ Inner loop. delaunay_triangulation: 84
# ------ Inner loop. delaunay_triangulation: 85
# ------ Inner loop. delaunay_triangulation: 86
# ------ Inner loop. delaunay_triangulation: 87
# ------ Inner loop. delaunay_triangulation: 88
# ------ Inner loop. delaunay_triangulation: 89
# ------ Inner loop. delaunay_triangulation: 90
# ------ Inner loop. delaunay_triangulation: 91
# ------ Inner loop. delaunay_triangulation: 92
# ------ Inner loop. delaunay_triangulation: 93
# ------ Inner loop. delaunay_triangulation: 94
# ------ Inner loop. delaunay_triangulation: 95
# ------ Inner loop. delaunay_triangulation: 96
# ------ Inner loop. delaunay_triangulation: 97
# ------ Inner loop. delaunay_triangulation: 98
# ------ Inner loop. delaunay_triangulation: 99
# Elapsed:4.4012633228302
# ---- Parameters Combination: 1
# ------ Inner loop. delaunay_triangulation: 0
# A curve_set(1d) object with 2500 curves observed at 7 argument values
# (1 observed, 2499 simulated).
# Contains:
# $ r     :  num [1:7] 0.664 0.725 0.785 0.846 0.906 ...
# $ funcs :  num [1:7, 1:2500] 1.14 1.2 1.25 1.29 1.33 ...
#  - attr(*, "dimnames")=List of 2
#   ..$ : chr [1:7] "12" "13" "14" "15" ...
#   ..$ : chr [1:2500] "obs" "sim1" "sim2" "sim3" ...
#
# ------ Inner loop. delaunay_triangulation: 1
# A curve_set(1d) object with 2500 curves observed at 7 argument values
# (1 observed, 2499 simulated).
# Contains:
# $ r     :  num [1:7] 0.664 0.725 0.785 0.846 0.906 ...
# $ funcs :  num [1:7, 1:2500] 1.15 1.21 1.25 1.29 1.33 ...
#  - attr(*, "dimnames")=List of 2
#   ..$ : chr [1:7] "12" "13" "14" "15" ...
#   ..$ : chr [1:2500] "obs" "sim1" "sim2" "sim3" ...
#
# ------ Inner loop. delaunay_triangulation: 2
# A curve_set(1d) object with 2500 curves observed at 7 argument values
# (1 observed, 2499 simulated).
# Contains:
# $ r     :  num [1:7] 0.664 0.725 0.785 0.846 0.906 ...
# $ funcs :  num [1:7, 1:2500] 1.14 1.2 1.25 1.29 1.32 ...
#  - attr(*, "dimnames")=List of 2
#   ..$ : chr [1:7] "12" "13" "14" "15" ...
#   ..$ : chr [1:2500] "obs" "sim1" "sim2" "sim3" ...
#
# ------ Inner loop. delaunay_triangulation: 3
# A curve_set(1d) object with 2500 curves observed at 7 argument values
# (1 observed, 2499 simulated).
# Contains:
# $ r     :  num [1:7] 0.664 0.725 0.785 0.846 0.906 ...
# $ funcs :  num [1:7, 1:2500] 1.15 1.21 1.25 1.29 1.33 ...
#  - attr(*, "dimnames")=List of 2
#   ..$ : chr [1:7] "12" "13" "14" "15" ...
#   ..$ : chr [1:2500] "obs" "sim1" "sim2" "sim3" ...
#
# ------ Inner loop. delaunay_triangulation: 4
# A curve_set(1d) object with 2500 curves observed at 7 argument values
# (1 observed, 2499 simulated).
# Contains:
# $ r     :  num [1:7] 0.664 0.725 0.785 0.846 0.906 ...
# $ funcs :  num [1:7, 1:2500] 1.15 1.2 1.25 1.29 1.33 ...
#  - attr(*, "dimnames")=List of 2
#   ..$ : chr [1:7] "12" "13" "14" "15" ...
#   ..$ : chr [1:2500] "obs" "sim1" "sim2" "sim3" ...
#
# ------ Inner loop. delaunay_triangulation: 5
# A curve_set(1d) object with 2500 curves observed at 7 argument values
# (1 observed, 2499 simulated).
# Contains:
# $ r     :  num [1:7] 0.664 0.725 0.785 0.846 0.906 ...
# $ funcs :  num [1:7, 1:2500] 1.14 1.2 1.25 1.29 1.32 ...
#  - attr(*, "dimnames")=List of 2
#   ..$ : chr [1:7] "12" "13" "14" "15" ...
#   ..$ : chr [1:2500] "obs" "sim1" "sim2" "sim3" ...
#
# ------ Inner loop. delaunay_triangulation: 6
# A curve_set(1d) object with 2500 curves observed at 7 argument values
# (1 observed, 2499 simulated).
# Contains:
# $ r     :  num [1:7] 0.664 0.725 0.785 0.846 0.906 ...
# $ funcs :  num [1:7, 1:2500] 1.15 1.21 1.25 1.29 1.33 ...
#  - attr(*, "dimnames")=List of 2
#   ..$ : chr [1:7] "12" "13" "14" "15" ...
#   ..$ : chr [1:2500] "obs" "sim1" "sim2" "sim3" ...
#
# ------ Inner loop. delaunay_triangulation: 7
# A curve_set(1d) object with 2500 curves observed at 7 argument values
# (1 observed, 2499 simulated).
# Contains:
# $ r     :  num [1:7] 0.664 0.725 0.785 0.846 0.906 ...
# $ funcs :  num [1:7, 1:2500] 1.15 1.21 1.25 1.29 1.33 ...
#  - attr(*, "dimnames")=List of 2
#   ..$ : chr [1:7] "12" "13" "14" "15" ...
#   ..$ : chr [1:2500] "obs" "sim1" "sim2" "sim3" ...
#
# ------ Inner loop. delaunay_triangulation: 8
# A curve_set(1d) object with 2500 curves observed at 7 argument values
# (1 observed, 2499 simulated).
# Contains:
# $ r     :  num [1:7] 0.664 0.725 0.785 0.846 0.906 ...
# $ funcs :  num [1:7, 1:2500] 1.15 1.21 1.26 1.29 1.33 ...
#  - attr(*, "dimnames")=List of 2
#   ..$ : chr [1:7] "12" "13" "14" "15" ...
#   ..$ : chr [1:2500] "obs" "sim1" "sim2" "sim3" ...
#
# ------ Inner loop. delaunay_triangulation: 9
# A curve_set(1d) object with 2500 curves observed at 7 argument values
# (1 observed, 2499 simulated).
# Contains:
# $ r     :  num [1:7] 0.664 0.725 0.785 0.846 0.906 ...
# $ funcs :  num [1:7, 1:2500] 1.15 1.21 1.25 1.29 1.32 ...
#  - attr(*, "dimnames")=List of 2
#   ..$ : chr [1:7] "12" "13" "14" "15" ...
#   ..$ : chr [1:2500] "obs" "sim1" "sim2" "sim3" ...
#
# ------ Inner loop. delaunay_triangulation: 10
# A curve_set(1d) object with 2500 curves observed at 7 argument values
# (1 observed, 2499 simulated).
# Contains:
# $ r     :  num [1:7] 0.664 0.725 0.785 0.846 0.906 ...
# $ funcs :  num [1:7, 1:2500] 1.15 1.21 1.25 1.29 1.33 ...
#  - attr(*, "dimnames")=List of 2
#   ..$ : chr [1:7] "12" "13" "14" "15" ...
#   ..$ : chr [1:2500] "obs" "sim1" "sim2" "sim3" ...
#
# ------ Inner loop. delaunay_triangulation: 11
# A curve_set(1d) object with 2500 curves observed at 7 argument values
# (1 observed, 2499 simulated).
# Contains:
# $ r     :  num [1:7] 0.664 0.725 0.785 0.846 0.906 ...
# $ funcs :  num [1:7, 1:2500] 1.15 1.21 1.25 1.29 1.33 ...
#  - attr(*, "dimnames")=List of 2
#   ..$ : chr [1:7] "12" "13" "14" "15" ...
#   ..$ : chr [1:2500] "obs" "sim1" "sim2" "sim3" ...
#
# ------ Inner loop. delaunay_triangulation: 12
# A curve_set(1d) object with 2500 curves observed at 7 argument values
# (1 observed, 2499 simulated).
# Contains:
# $ r     :  num [1:7] 0.664 0.725 0.785 0.846 0.906 ...
# $ funcs :  num [1:7, 1:2500] 1.14 1.2 1.25 1.29 1.32 ...
#  - attr(*, "dimnames")=List of 2
#   ..$ : chr [1:7] "12" "13" "14" "15" ...
#   ..$ : chr [1:2500] "obs" "sim1" "sim2" "sim3" ...
#
# ------ Inner loop. delaunay_triangulation: 13
# A curve_set(1d) object with 2500 curves observed at 7 argument values
# (1 observed, 2499 simulated).
# Contains:
# $ r     :  num [1:7] 0.664 0.725 0.785 0.846 0.906 ...
# $ funcs :  num [1:7, 1:2500] 1.15 1.21 1.26 1.3 1.33 ...
#  - attr(*, "dimnames")=List of 2
#   ..$ : chr [1:7] "12" "13" "14" "15" ...
#   ..$ : chr [1:2500] "obs" "sim1" "sim2" "sim3" ...
#
# ------ Inner loop. delaunay_triangulation: 14
# A curve_set(1d) object with 2500 curves observed at 7 argument values
# (1 observed, 2499 simulated).
# Contains:
# $ r     :  num [1:7] 0.664 0.725 0.785 0.846 0.906 ...
# $ funcs :  num [1:7, 1:2500] 1.15 1.21 1.26 1.29 1.33 ...
#  - attr(*, "dimnames")=List of 2
#   ..$ : chr [1:7] "12" "13" "14" "15" ...
#   ..$ : chr [1:2500] "obs" "sim1" "sim2" "sim3" ...
#
# ------ Inner loop. delaunay_triangulation: 15
# A curve_set(1d) object with 2500 curves observed at 7 argument values
# (1 observed, 2499 simulated).
# Contains:
# $ r     :  num [1:7] 0.664 0.725 0.785 0.846 0.906 ...
# $ funcs :  num [1:7, 1:2500] 1.14 1.2 1.25 1.29 1.32 ...
#  - attr(*, "dimnames")=List of 2
#   ..$ : chr [1:7] "12" "13" "14" "15" ...
#   ..$ : chr [1:2500] "obs" "sim1" "sim2" "sim3" ...
#
# ------ Inner loop. delaunay_triangulation: 16
# A curve_set(1d) object with 2500 curves observed at 7 argument values
# (1 observed, 2499 simulated).
# Contains:
# $ r     :  num [1:7] 0.664 0.725 0.785 0.846 0.906 ...
# $ funcs :  num [1:7, 1:2500] 1.15 1.2 1.25 1.29 1.33 ...
#  - attr(*, "dimnames")=List of 2
#   ..$ : chr [1:7] "12" "13" "14" "15" ...
#   ..$ : chr [1:2500] "obs" "sim1" "sim2" "sim3" ...
#
# ------ Inner loop. delaunay_triangulation: 17
# A curve_set(1d) object with 2500 curves observed at 7 argument values
# (1 observed, 2499 simulated).
# Contains:
# $ r     :  num [1:7] 0.664 0.725 0.785 0.846 0.906 ...
# $ funcs :  num [1:7, 1:2500] 1.15 1.21 1.25 1.29 1.32 ...
#  - attr(*, "dimnames")=List of 2
#   ..$ : chr [1:7] "12" "13" "14" "15" ...
#   ..$ : chr [1:2500] "obs" "sim1" "sim2" "sim3" ...
#
# ------ Inner loop. delaunay_triangulation: 18
# A curve_set(1d) object with 2500 curves observed at 7 argument values
# (1 observed, 2499 simulated).
# Contains:
# $ r     :  num [1:7] 0.664 0.725 0.785 0.846 0.906 ...
# $ funcs :  num [1:7, 1:2500] 1.15 1.2 1.25 1.29 1.33 ...
#  - attr(*, "dimnames")=List of 2
#   ..$ : chr [1:7] "12" "13" "14" "15" ...
#   ..$ : chr [1:2500] "obs" "sim1" "sim2" "sim3" ...
#
# ------ Inner loop. delaunay_triangulation: 19
# A curve_set(1d) object with 2500 curves observed at 7 argument values
# (1 observed, 2499 simulated).
# Contains:
# $ r     :  num [1:7] 0.664 0.725 0.785 0.846 0.906 ...
# $ funcs :  num [1:7, 1:2500] 1.15 1.2 1.25 1.29 1.32 ...
#  - attr(*, "dimnames")=List of 2
#   ..$ : chr [1:7] "12" "13" "14" "15" ...
#   ..$ : chr [1:2500] "obs" "sim1" "sim2" "sim3" ...
#
# ------ Inner loop. delaunay_triangulation: 20
# A curve_set(1d) object with 2500 curves observed at 7 argument values
# (1 observed, 2499 simulated).
# Contains:
# $ r     :  num [1:7] 0.664 0.725 0.785 0.846 0.906 ...
# $ funcs :  num [1:7, 1:2500] 1.14 1.2 1.25 1.28 1.32 ...
#  - attr(*, "dimnames")=List of 2
#   ..$ : chr [1:7] "12" "13" "14" "15" ...
#   ..$ : chr [1:2500] "obs" "sim1" "sim2" "sim3" ...
#
# ------ Inner loop. delaunay_triangulation: 21
# A curve_set(1d) object with 2500 curves observed at 7 argument values
# (1 observed, 2499 simulated).
# Contains:
# $ r     :  num [1:7] 0.664 0.725 0.785 0.846 0.906 ...
# $ funcs :  num [1:7, 1:2500] 1.15 1.21 1.26 1.29 1.33 ...
#  - attr(*, "dimnames")=List of 2
#   ..$ : chr [1:7] "12" "13" "14" "15" ...
#   ..$ : chr [1:2500] "obs" "sim1" "sim2" "sim3" ...
#
# ------ Inner loop. delaunay_triangulation: 22
# A curve_set(1d) object with 2500 curves observed at 7 argument values
# (1 observed, 2499 simulated).
# Contains:
# $ r     :  num [1:7] 0.664 0.725 0.785 0.846 0.906 ...
# $ funcs :  num [1:7, 1:2500] 1.15 1.21 1.25 1.29 1.33 ...
#  - attr(*, "dimnames")=List of 2
#   ..$ : chr [1:7] "12" "13" "14" "15" ...
#   ..$ : chr [1:2500] "obs" "sim1" "sim2" "sim3" ...
#
# ------ Inner loop. delaunay_triangulation: 23
# A curve_set(1d) object with 2500 curves observed at 7 argument values
# (1 observed, 2499 simulated).
# Contains:
# $ r     :  num [1:7] 0.664 0.725 0.785 0.846 0.906 ...
# $ funcs :  num [1:7, 1:2500] 1.15 1.21 1.25 1.29 1.33 ...
#  - attr(*, "dimnames")=List of 2
#   ..$ : chr [1:7] "12" "13" "14" "15" ...
#   ..$ : chr [1:2500] "obs" "sim1" "sim2" "sim3" ...
#
# ------ Inner loop. delaunay_triangulation: 24
# A curve_set(1d) object with 2500 curves observed at 7 argument values
# (1 observed, 2499 simulated).
# Contains:
# $ r     :  num [1:7] 0.664 0.725 0.785 0.846 0.906 ...
# $ funcs :  num [1:7, 1:2500] 1.15 1.2 1.25 1.29 1.32 ...
#  - attr(*, "dimnames")=List of 2
#   ..$ : chr [1:7] "12" "13" "14" "15" ...
#   ..$ : chr [1:2500] "obs" "sim1" "sim2" "sim3" ...
#
# ------ Inner loop. delaunay_triangulation: 25
# A curve_set(1d) object with 2500 curves observed at 7 argument values
# (1 observed, 2499 simulated).
# Contains:
# $ r     :  num [1:7] 0.664 0.725 0.785 0.846 0.906 ...
# $ funcs :  num [1:7, 1:2500] 1.15 1.21 1.25 1.29 1.32 ...
#  - attr(*, "dimnames")=List of 2
#   ..$ : chr [1:7] "12" "13" "14" "15" ...
#   ..$ : chr [1:2500] "obs" "sim1" "sim2" "sim3" ...
#
# ------ Inner loop. delaunay_triangulation: 26
# A curve_set(1d) object with 2500 curves observed at 7 argument values
# (1 observed, 2499 simulated).
# Contains:
# $ r     :  num [1:7] 0.664 0.725 0.785 0.846 0.906 ...
# $ funcs :  num [1:7, 1:2500] 1.16 1.21 1.25 1.29 1.33 ...
#  - attr(*, "dimnames")=List of 2
#   ..$ : chr [1:7] "12" "13" "14" "15" ...
#   ..$ : chr [1:2500] "obs" "sim1" "sim2" "sim3" ...
#
# ------ Inner loop. delaunay_triangulation: 27
# A curve_set(1d) object with 2500 curves observed at 7 argument values
# (1 observed, 2499 simulated).
# Contains:
# $ r     :  num [1:7] 0.664 0.725 0.785 0.846 0.906 ...
# $ funcs :  num [1:7, 1:2500] 1.14 1.21 1.25 1.29 1.33 ...
#  - attr(*, "dimnames")=List of 2
#   ..$ : chr [1:7] "12" "13" "14" "15" ...
#   ..$ : chr [1:2500] "obs" "sim1" "sim2" "sim3" ...
#
# ------ Inner loop. delaunay_triangulation: 28
# A curve_set(1d) object with 2500 curves observed at 7 argument values
# (1 observed, 2499 simulated).
# Contains:
# $ r     :  num [1:7] 0.664 0.725 0.785 0.846 0.906 ...
# $ funcs :  num [1:7, 1:2500] 1.14 1.2 1.25 1.29 1.33 ...
#  - attr(*, "dimnames")=List of 2
#   ..$ : chr [1:7] "12" "13" "14" "15" ...
#   ..$ : chr [1:2500] "obs" "sim1" "sim2" "sim3" ...
#
# ------ Inner loop. delaunay_triangulation: 29
# A curve_set(1d) object with 2500 curves observed at 7 argument values
# (1 observed, 2499 simulated).
# Contains:
# $ r     :  num [1:7] 0.664 0.725 0.785 0.846 0.906 ...
# $ funcs :  num [1:7, 1:2500] 1.16 1.21 1.26 1.29 1.33 ...
#  - attr(*, "dimnames")=List of 2
#   ..$ : chr [1:7] "12" "13" "14" "15" ...
#   ..$ : chr [1:2500] "obs" "sim1" "sim2" "sim3" ...
#
# ------ Inner loop. delaunay_triangulation: 30
# A curve_set(1d) object with 2500 curves observed at 7 argument values
# (1 observed, 2499 simulated).
# Contains:
# $ r     :  num [1:7] 0.664 0.725 0.785 0.846 0.906 ...
# $ funcs :  num [1:7, 1:2500] 1.15 1.21 1.25 1.29 1.33 ...
#  - attr(*, "dimnames")=List of 2
#   ..$ : chr [1:7] "12" "13" "14" "15" ...
#   ..$ : chr [1:2500] "obs" "sim1" "sim2" "sim3" ...
#
# ------ Inner loop. delaunay_triangulation: 31
# A curve_set(1d) object with 2500 curves observed at 7 argument values
# (1 observed, 2499 simulated).
# Contains:
# $ r     :  num [1:7] 0.664 0.725 0.785 0.846 0.906 ...
# $ funcs :  num [1:7, 1:2500] 1.15 1.2 1.25 1.29 1.32 ...
#  - attr(*, "dimnames")=List of 2
#   ..$ : chr [1:7] "12" "13" "14" "15" ...
#   ..$ : chr [1:2500] "obs" "sim1" "sim2" "sim3" ...
#
# ------ Inner loop. delaunay_triangulation: 32
# A curve_set(1d) object with 2500 curves observed at 7 argument values
# (1 observed, 2499 simulated).
# Contains:
# $ r     :  num [1:7] 0.664 0.725 0.785 0.846 0.906 ...
# $ funcs :  num [1:7, 1:2500] 1.15 1.21 1.25 1.29 1.33 ...
#  - attr(*, "dimnames")=List of 2
#   ..$ : chr [1:7] "12" "13" "14" "15" ...
#   ..$ : chr [1:2500] "obs" "sim1" "sim2" "sim3" ...
#
# ------ Inner loop. delaunay_triangulation: 33
# A curve_set(1d) object with 2500 curves observed at 7 argument values
# (1 observed, 2499 simulated).
# Contains:
# $ r     :  num [1:7] 0.664 0.725 0.785 0.846 0.906 ...
# $ funcs :  num [1:7, 1:2500] 1.15 1.21 1.25 1.29 1.32 ...
#  - attr(*, "dimnames")=List of 2
#   ..$ : chr [1:7] "12" "13" "14" "15" ...
#   ..$ : chr [1:2500] "obs" "sim1" "sim2" "sim3" ...
#
# ------ Inner loop. delaunay_triangulation: 34
# A curve_set(1d) object with 2500 curves observed at 7 argument values
# (1 observed, 2499 simulated).
# Contains:
# $ r     :  num [1:7] 0.664 0.725 0.785 0.846 0.906 ...
# $ funcs :  num [1:7, 1:2500] 1.15 1.21 1.26 1.29 1.33 ...
#  - attr(*, "dimnames")=List of 2
#   ..$ : chr [1:7] "12" "13" "14" "15" ...
#   ..$ : chr [1:2500] "obs" "sim1" "sim2" "sim3" ...
#
# ------ Inner loop. delaunay_triangulation: 35
# A curve_set(1d) object with 2500 curves observed at 7 argument values
# (1 observed, 2499 simulated).
# Contains:
# $ r     :  num [1:7] 0.664 0.725 0.785 0.846 0.906 ...
# $ funcs :  num [1:7, 1:2500] 1.14 1.2 1.25 1.29 1.32 ...
#  - attr(*, "dimnames")=List of 2
#   ..$ : chr [1:7] "12" "13" "14" "15" ...
#   ..$ : chr [1:2500] "obs" "sim1" "sim2" "sim3" ...
#
# ------ Inner loop. delaunay_triangulation: 36
# A curve_set(1d) object with 2500 curves observed at 7 argument values
# (1 observed, 2499 simulated).
# Contains:
# $ r     :  num [1:7] 0.664 0.725 0.785 0.846 0.906 ...
# $ funcs :  num [1:7, 1:2500] 1.15 1.21 1.25 1.29 1.32 ...
#  - attr(*, "dimnames")=List of 2
#   ..$ : chr [1:7] "12" "13" "14" "15" ...
#   ..$ : chr [1:2500] "obs" "sim1" "sim2" "sim3" ...
#
# ------ Inner loop. delaunay_triangulation: 37
# A curve_set(1d) object with 2500 curves observed at 7 argument values
# (1 observed, 2499 simulated).
# Contains:
# $ r     :  num [1:7] 0.664 0.725 0.785 0.846 0.906 ...
# $ funcs :  num [1:7, 1:2500] 1.14 1.2 1.25 1.29 1.32 ...
#  - attr(*, "dimnames")=List of 2
#   ..$ : chr [1:7] "12" "13" "14" "15" ...
#   ..$ : chr [1:2500] "obs" "sim1" "sim2" "sim3" ...
#
# ------ Inner loop. delaunay_triangulation: 38
# A curve_set(1d) object with 2500 curves observed at 7 argument values
# (1 observed, 2499 simulated).
# Contains:
# $ r     :  num [1:7] 0.664 0.725 0.785 0.846 0.906 ...
# $ funcs :  num [1:7, 1:2500] 1.15 1.21 1.25 1.29 1.33 ...
#  - attr(*, "dimnames")=List of 2
#   ..$ : chr [1:7] "12" "13" "14" "15" ...
#   ..$ : chr [1:2500] "obs" "sim1" "sim2" "sim3" ...
#
# ------ Inner loop. delaunay_triangulation: 39
# A curve_set(1d) object with 2500 curves observed at 7 argument values
# (1 observed, 2499 simulated).
# Contains:
# $ r     :  num [1:7] 0.664 0.725 0.785 0.846 0.906 ...
# $ funcs :  num [1:7, 1:2500] 1.15 1.2 1.25 1.29 1.32 ...
#  - attr(*, "dimnames")=List of 2
#   ..$ : chr [1:7] "12" "13" "14" "15" ...
#   ..$ : chr [1:2500] "obs" "sim1" "sim2" "sim3" ...
#
# ------ Inner loop. delaunay_triangulation: 40
# A curve_set(1d) object with 2500 curves observed at 7 argument values
# (1 observed, 2499 simulated).
# Contains:
# $ r     :  num [1:7] 0.664 0.725 0.785 0.846 0.906 ...
# $ funcs :  num [1:7, 1:2500] 1.15 1.21 1.26 1.29 1.33 ...
#  - attr(*, "dimnames")=List of 2
#   ..$ : chr [1:7] "12" "13" "14" "15" ...
#   ..$ : chr [1:2500] "obs" "sim1" "sim2" "sim3" ...
#
# ------ Inner loop. delaunay_triangulation: 41
# A curve_set(1d) object with 2500 curves observed at 7 argument values
# (1 observed, 2499 simulated).
# Contains:
# $ r     :  num [1:7] 0.664 0.725 0.785 0.846 0.906 ...
# $ funcs :  num [1:7, 1:2500] 1.15 1.21 1.25 1.29 1.33 ...
#  - attr(*, "dimnames")=List of 2
#   ..$ : chr [1:7] "12" "13" "14" "15" ...
#   ..$ : chr [1:2500] "obs" "sim1" "sim2" "sim3" ...
#
# ------ Inner loop. delaunay_triangulation: 42
# A curve_set(1d) object with 2500 curves observed at 7 argument values
# (1 observed, 2499 simulated).
# Contains:
# $ r     :  num [1:7] 0.664 0.725 0.785 0.846 0.906 ...
# $ funcs :  num [1:7, 1:2500] 1.15 1.21 1.25 1.29 1.33 ...
#  - attr(*, "dimnames")=List of 2
#   ..$ : chr [1:7] "12" "13" "14" "15" ...
#   ..$ : chr [1:2500] "obs" "sim1" "sim2" "sim3" ...
#
# ------ Inner loop. delaunay_triangulation: 43
# A curve_set(1d) object with 2500 curves observed at 7 argument values
# (1 observed, 2499 simulated).
# Contains:
# $ r     :  num [1:7] 0.664 0.725 0.785 0.846 0.906 ...
# $ funcs :  num [1:7, 1:2500] 1.15 1.21 1.25 1.29 1.33 ...
#  - attr(*, "dimnames")=List of 2
#   ..$ : chr [1:7] "12" "13" "14" "15" ...
#   ..$ : chr [1:2500] "obs" "sim1" "sim2" "sim3" ...
#
# ------ Inner loop. delaunay_triangulation: 44
# A curve_set(1d) object with 2500 curves observed at 7 argument values
# (1 observed, 2499 simulated).
# Contains:
# $ r     :  num [1:7] 0.664 0.725 0.785 0.846 0.906 ...
# $ funcs :  num [1:7, 1:2500] 1.15 1.2 1.25 1.29 1.33 ...
#  - attr(*, "dimnames")=List of 2
#   ..$ : chr [1:7] "12" "13" "14" "15" ...
#   ..$ : chr [1:2500] "obs" "sim1" "sim2" "sim3" ...
#
# ------ Inner loop. delaunay_triangulation: 45
# A curve_set(1d) object with 2500 curves observed at 7 argument values
# (1 observed, 2499 simulated).
# Contains:
# $ r     :  num [1:7] 0.664 0.725 0.785 0.846 0.906 ...
# $ funcs :  num [1:7, 1:2500] 1.15 1.21 1.25 1.29 1.33 ...
#  - attr(*, "dimnames")=List of 2
#   ..$ : chr [1:7] "12" "13" "14" "15" ...
#   ..$ : chr [1:2500] "obs" "sim1" "sim2" "sim3" ...
#
# ------ Inner loop. delaunay_triangulation: 46
# A curve_set(1d) object with 2500 curves observed at 7 argument values
# (1 observed, 2499 simulated).
# Contains:
# $ r     :  num [1:7] 0.664 0.725 0.785 0.846 0.906 ...
# $ funcs :  num [1:7, 1:2500] 1.15 1.21 1.25 1.29 1.33 ...
#  - attr(*, "dimnames")=List of 2
#   ..$ : chr [1:7] "12" "13" "14" "15" ...
#   ..$ : chr [1:2500] "obs" "sim1" "sim2" "sim3" ...
#
# ------ Inner loop. delaunay_triangulation: 47
# A curve_set(1d) object with 2500 curves observed at 7 argument values
# (1 observed, 2499 simulated).
# Contains:
# $ r     :  num [1:7] 0.664 0.725 0.785 0.846 0.906 ...
# $ funcs :  num [1:7, 1:2500] 1.15 1.2 1.25 1.29 1.33 ...
#  - attr(*, "dimnames")=List of 2
#   ..$ : chr [1:7] "12" "13" "14" "15" ...
#   ..$ : chr [1:2500] "obs" "sim1" "sim2" "sim3" ...
#
# ------ Inner loop. delaunay_triangulation: 48
# A curve_set(1d) object with 2500 curves observed at 7 argument values
# (1 observed, 2499 simulated).
# Contains:
# $ r     :  num [1:7] 0.664 0.725 0.785 0.846 0.906 ...
# $ funcs :  num [1:7, 1:2500] 1.16 1.21 1.26 1.29 1.33 ...
#  - attr(*, "dimnames")=List of 2
#   ..$ : chr [1:7] "12" "13" "14" "15" ...
#   ..$ : chr [1:2500] "obs" "sim1" "sim2" "sim3" ...
#
# ------ Inner loop. delaunay_triangulation: 49
# A curve_set(1d) object with 2500 curves observed at 7 argument values
# (1 observed, 2499 simulated).
# Contains:
# $ r     :  num [1:7] 0.664 0.725 0.785 0.846 0.906 ...
# $ funcs :  num [1:7, 1:2500] 1.14 1.19 1.24 1.28 1.32 ...
#  - attr(*, "dimnames")=List of 2
#   ..$ : chr [1:7] "12" "13" "14" "15" ...
#   ..$ : chr [1:2500] "obs" "sim1" "sim2" "sim3" ...
#
# ------ Inner loop. delaunay_triangulation: 50
# A curve_set(1d) object with 2500 curves observed at 7 argument values
# (1 observed, 2499 simulated).
# Contains:
# $ r     :  num [1:7] 0.664 0.725 0.785 0.846 0.906 ...
# $ funcs :  num [1:7, 1:2500] 1.15 1.2 1.25 1.29 1.33 ...
#  - attr(*, "dimnames")=List of 2
#   ..$ : chr [1:7] "12" "13" "14" "15" ...
#   ..$ : chr [1:2500] "obs" "sim1" "sim2" "sim3" ...
#
# ------ Inner loop. delaunay_triangulation: 51
# A curve_set(1d) object with 2500 curves observed at 7 argument values
# (1 observed, 2499 simulated).
# Contains:
# $ r     :  num [1:7] 0.664 0.725 0.785 0.846 0.906 ...
# $ funcs :  num [1:7, 1:2500] 1.16 1.22 1.26 1.29 1.33 ...
#  - attr(*, "dimnames")=List of 2
#   ..$ : chr [1:7] "12" "13" "14" "15" ...
#   ..$ : chr [1:2500] "obs" "sim1" "sim2" "sim3" ...
#
# ------ Inner loop. delaunay_triangulation: 52
# A curve_set(1d) object with 2500 curves observed at 7 argument values
# (1 observed, 2499 simulated).
# Contains:
# $ r     :  num [1:7] 0.664 0.725 0.785 0.846 0.906 ...
# $ funcs :  num [1:7, 1:2500] 1.14 1.2 1.25 1.29 1.33 ...
#  - attr(*, "dimnames")=List of 2
#   ..$ : chr [1:7] "12" "13" "14" "15" ...
#   ..$ : chr [1:2500] "obs" "sim1" "sim2" "sim3" ...
#
# ------ Inner loop. delaunay_triangulation: 53
# A curve_set(1d) object with 2500 curves observed at 7 argument values
# (1 observed, 2499 simulated).
# Contains:
# $ r     :  num [1:7] 0.664 0.725 0.785 0.846 0.906 ...
# $ funcs :  num [1:7, 1:2500] 1.16 1.21 1.26 1.29 1.33 ...
#  - attr(*, "dimnames")=List of 2
#   ..$ : chr [1:7] "12" "13" "14" "15" ...
#   ..$ : chr [1:2500] "obs" "sim1" "sim2" "sim3" ...
#
# ------ Inner loop. delaunay_triangulation: 54
# A curve_set(1d) object with 2500 curves observed at 7 argument values
# (1 observed, 2499 simulated).
# Contains:
# $ r     :  num [1:7] 0.664 0.725 0.785 0.846 0.906 ...
# $ funcs :  num [1:7, 1:2500] 1.15 1.2 1.25 1.29 1.32 ...
#  - attr(*, "dimnames")=List of 2
#   ..$ : chr [1:7] "12" "13" "14" "15" ...
#   ..$ : chr [1:2500] "obs" "sim1" "sim2" "sim3" ...
#
# ------ Inner loop. delaunay_triangulation: 55
# A curve_set(1d) object with 2500 curves observed at 7 argument values
# (1 observed, 2499 simulated).
# Contains:
# $ r     :  num [1:7] 0.664 0.725 0.785 0.846 0.906 ...
# $ funcs :  num [1:7, 1:2500] 1.15 1.2 1.25 1.29 1.33 ...
#  - attr(*, "dimnames")=List of 2
#   ..$ : chr [1:7] "12" "13" "14" "15" ...
#   ..$ : chr [1:2500] "obs" "sim1" "sim2" "sim3" ...
#
# ------ Inner loop. delaunay_triangulation: 56
# A curve_set(1d) object with 2500 curves observed at 7 argument values
# (1 observed, 2499 simulated).
# Contains:
# $ r     :  num [1:7] 0.664 0.725 0.785 0.846 0.906 ...
# $ funcs :  num [1:7, 1:2500] 1.15 1.21 1.25 1.29 1.33 ...
#  - attr(*, "dimnames")=List of 2
#   ..$ : chr [1:7] "12" "13" "14" "15" ...
#   ..$ : chr [1:2500] "obs" "sim1" "sim2" "sim3" ...
#
# ------ Inner loop. delaunay_triangulation: 57
# A curve_set(1d) object with 2500 curves observed at 7 argument values
# (1 observed, 2499 simulated).
# Contains:
# $ r     :  num [1:7] 0.664 0.725 0.785 0.846 0.906 ...
# $ funcs :  num [1:7, 1:2500] 1.15 1.21 1.25 1.29 1.32 ...
#  - attr(*, "dimnames")=List of 2
#   ..$ : chr [1:7] "12" "13" "14" "15" ...
#   ..$ : chr [1:2500] "obs" "sim1" "sim2" "sim3" ...
#
# ------ Inner loop. delaunay_triangulation: 58
# A curve_set(1d) object with 2500 curves observed at 7 argument values
# (1 observed, 2499 simulated).
# Contains:
# $ r     :  num [1:7] 0.664 0.725 0.785 0.846 0.906 ...
# $ funcs :  num [1:7, 1:2500] 1.15 1.21 1.25 1.29 1.32 ...
#  - attr(*, "dimnames")=List of 2
#   ..$ : chr [1:7] "12" "13" "14" "15" ...
#   ..$ : chr [1:2500] "obs" "sim1" "sim2" "sim3" ...
#
# ------ Inner loop. delaunay_triangulation: 59
# A curve_set(1d) object with 2500 curves observed at 7 argument values
# (1 observed, 2499 simulated).
# Contains:
# $ r     :  num [1:7] 0.664 0.725 0.785 0.846 0.906 ...
# $ funcs :  num [1:7, 1:2500] 1.15 1.21 1.26 1.29 1.33 ...
#  - attr(*, "dimnames")=List of 2
#   ..$ : chr [1:7] "12" "13" "14" "15" ...
#   ..$ : chr [1:2500] "obs" "sim1" "sim2" "sim3" ...
#
# ------ Inner loop. delaunay_triangulation: 60
# A curve_set(1d) object with 2500 curves observed at 7 argument values
# (1 observed, 2499 simulated).
# Contains:
# $ r     :  num [1:7] 0.664 0.725 0.785 0.846 0.906 ...
# $ funcs :  num [1:7, 1:2500] 1.14 1.2 1.25 1.29 1.33 ...
#  - attr(*, "dimnames")=List of 2
#   ..$ : chr [1:7] "12" "13" "14" "15" ...
#   ..$ : chr [1:2500] "obs" "sim1" "sim2" "sim3" ...
#
# ------ Inner loop. delaunay_triangulation: 61
# A curve_set(1d) object with 2500 curves observed at 7 argument values
# (1 observed, 2499 simulated).
# Contains:
# $ r     :  num [1:7] 0.664 0.725 0.785 0.846 0.906 ...
# $ funcs :  num [1:7, 1:2500] 1.15 1.21 1.25 1.29 1.32 ...
#  - attr(*, "dimnames")=List of 2
#   ..$ : chr [1:7] "12" "13" "14" "15" ...
#   ..$ : chr [1:2500] "obs" "sim1" "sim2" "sim3" ...
#
# ------ Inner loop. delaunay_triangulation: 62
# A curve_set(1d) object with 2500 curves observed at 7 argument values
# (1 observed, 2499 simulated).
# Contains:
# $ r     :  num [1:7] 0.664 0.725 0.785 0.846 0.906 ...
# $ funcs :  num [1:7, 1:2500] 1.14 1.2 1.25 1.29 1.32 ...
#  - attr(*, "dimnames")=List of 2
#   ..$ : chr [1:7] "12" "13" "14" "15" ...
#   ..$ : chr [1:2500] "obs" "sim1" "sim2" "sim3" ...
#
# ------ Inner loop. delaunay_triangulation: 63
# A curve_set(1d) object with 2500 curves observed at 7 argument values
# (1 observed, 2499 simulated).
# Contains:
# $ r     :  num [1:7] 0.664 0.725 0.785 0.846 0.906 ...
# $ funcs :  num [1:7, 1:2500] 1.14 1.2 1.25 1.29 1.32 ...
#  - attr(*, "dimnames")=List of 2
#   ..$ : chr [1:7] "12" "13" "14" "15" ...
#   ..$ : chr [1:2500] "obs" "sim1" "sim2" "sim3" ...
#
# ------ Inner loop. delaunay_triangulation: 64
# A curve_set(1d) object with 2500 curves observed at 7 argument values
# (1 observed, 2499 simulated).
# Contains:
# $ r     :  num [1:7] 0.664 0.725 0.785 0.846 0.906 ...
# $ funcs :  num [1:7, 1:2500] 1.15 1.21 1.25 1.29 1.33 ...
#  - attr(*, "dimnames")=List of 2
#   ..$ : chr [1:7] "12" "13" "14" "15" ...
#   ..$ : chr [1:2500] "obs" "sim1" "sim2" "sim3" ...
#
# ------ Inner loop. delaunay_triangulation: 65
# A curve_set(1d) object with 2500 curves observed at 7 argument values
# (1 observed, 2499 simulated).
# Contains:
# $ r     :  num [1:7] 0.664 0.725 0.785 0.846 0.906 ...
# $ funcs :  num [1:7, 1:2500] 1.16 1.21 1.25 1.29 1.33 ...
#  - attr(*, "dimnames")=List of 2
#   ..$ : chr [1:7] "12" "13" "14" "15" ...
#   ..$ : chr [1:2500] "obs" "sim1" "sim2" "sim3" ...
#
# ------ Inner loop. delaunay_triangulation: 66
# A curve_set(1d) object with 2500 curves observed at 7 argument values
# (1 observed, 2499 simulated).
# Contains:
# $ r     :  num [1:7] 0.664 0.725 0.785 0.846 0.906 ...
# $ funcs :  num [1:7, 1:2500] 1.15 1.2 1.25 1.29 1.32 ...
#  - attr(*, "dimnames")=List of 2
#   ..$ : chr [1:7] "12" "13" "14" "15" ...
#   ..$ : chr [1:2500] "obs" "sim1" "sim2" "sim3" ...
#
# ------ Inner loop. delaunay_triangulation: 67
# A curve_set(1d) object with 2500 curves observed at 7 argument values
# (1 observed, 2499 simulated).
# Contains:
# $ r     :  num [1:7] 0.664 0.725 0.785 0.846 0.906 ...
# $ funcs :  num [1:7, 1:2500] 1.15 1.21 1.25 1.29 1.33 ...
#  - attr(*, "dimnames")=List of 2
#   ..$ : chr [1:7] "12" "13" "14" "15" ...
#   ..$ : chr [1:2500] "obs" "sim1" "sim2" "sim3" ...
#
# ------ Inner loop. delaunay_triangulation: 68
# A curve_set(1d) object with 2500 curves observed at 7 argument values
# (1 observed, 2499 simulated).
# Contains:
# $ r     :  num [1:7] 0.664 0.725 0.785 0.846 0.906 ...
# $ funcs :  num [1:7, 1:2500] 1.15 1.21 1.25 1.29 1.33 ...
#  - attr(*, "dimnames")=List of 2
#   ..$ : chr [1:7] "12" "13" "14" "15" ...
#   ..$ : chr [1:2500] "obs" "sim1" "sim2" "sim3" ...
#
# ------ Inner loop. delaunay_triangulation: 69
# A curve_set(1d) object with 2500 curves observed at 7 argument values
# (1 observed, 2499 simulated).
# Contains:
# $ r     :  num [1:7] 0.664 0.725 0.785 0.846 0.906 ...
# $ funcs :  num [1:7, 1:2500] 1.15 1.21 1.26 1.3 1.33 ...
#  - attr(*, "dimnames")=List of 2
#   ..$ : chr [1:7] "12" "13" "14" "15" ...
#   ..$ : chr [1:2500] "obs" "sim1" "sim2" "sim3" ...
#
# ------ Inner loop. delaunay_triangulation: 70
# A curve_set(1d) object with 2500 curves observed at 7 argument values
# (1 observed, 2499 simulated).
# Contains:
# $ r     :  num [1:7] 0.664 0.725 0.785 0.846 0.906 ...
# $ funcs :  num [1:7, 1:2500] 1.15 1.2 1.25 1.29 1.33 ...
#  - attr(*, "dimnames")=List of 2
#   ..$ : chr [1:7] "12" "13" "14" "15" ...
#   ..$ : chr [1:2500] "obs" "sim1" "sim2" "sim3" ...
#
# ------ Inner loop. delaunay_triangulation: 71
# A curve_set(1d) object with 2500 curves observed at 7 argument values
# (1 observed, 2499 simulated).
# Contains:
# $ r     :  num [1:7] 0.664 0.725 0.785 0.846 0.906 ...
# $ funcs :  num [1:7, 1:2500] 1.15 1.21 1.25 1.29 1.33 ...
#  - attr(*, "dimnames")=List of 2
#   ..$ : chr [1:7] "12" "13" "14" "15" ...
#   ..$ : chr [1:2500] "obs" "sim1" "sim2" "sim3" ...
#
# ------ Inner loop. delaunay_triangulation: 72
# A curve_set(1d) object with 2500 curves observed at 7 argument values
# (1 observed, 2499 simulated).
# Contains:
# $ r     :  num [1:7] 0.664 0.725 0.785 0.846 0.906 ...
# $ funcs :  num [1:7, 1:2500] 1.15 1.21 1.25 1.29 1.33 ...
#  - attr(*, "dimnames")=List of 2
#   ..$ : chr [1:7] "12" "13" "14" "15" ...
#   ..$ : chr [1:2500] "obs" "sim1" "sim2" "sim3" ...
#
# ------ Inner loop. delaunay_triangulation: 73
# A curve_set(1d) object with 2500 curves observed at 7 argument values
# (1 observed, 2499 simulated).
# Contains:
# $ r     :  num [1:7] 0.664 0.725 0.785 0.846 0.906 ...
# $ funcs :  num [1:7, 1:2500] 1.15 1.2 1.25 1.29 1.32 ...
#  - attr(*, "dimnames")=List of 2
#   ..$ : chr [1:7] "12" "13" "14" "15" ...
#   ..$ : chr [1:2500] "obs" "sim1" "sim2" "sim3" ...
#
# ------ Inner loop. delaunay_triangulation: 74
# A curve_set(1d) object with 2500 curves observed at 7 argument values
# (1 observed, 2499 simulated).
# Contains:
# $ r     :  num [1:7] 0.664 0.725 0.785 0.846 0.906 ...
# $ funcs :  num [1:7, 1:2500] 1.16 1.22 1.26 1.3 1.33 ...
#  - attr(*, "dimnames")=List of 2
#   ..$ : chr [1:7] "12" "13" "14" "15" ...
#   ..$ : chr [1:2500] "obs" "sim1" "sim2" "sim3" ...
#
# ------ Inner loop. delaunay_triangulation: 75
# A curve_set(1d) object with 2500 curves observed at 7 argument values
# (1 observed, 2499 simulated).
# Contains:
# $ r     :  num [1:7] 0.664 0.725 0.785 0.846 0.906 ...
# $ funcs :  num [1:7, 1:2500] 1.15 1.2 1.25 1.29 1.32 ...
#  - attr(*, "dimnames")=List of 2
#   ..$ : chr [1:7] "12" "13" "14" "15" ...
#   ..$ : chr [1:2500] "obs" "sim1" "sim2" "sim3" ...
#
# ------ Inner loop. delaunay_triangulation: 76
# A curve_set(1d) object with 2500 curves observed at 7 argument values
# (1 observed, 2499 simulated).
# Contains:
# $ r     :  num [1:7] 0.664 0.725 0.785 0.846 0.906 ...
# $ funcs :  num [1:7, 1:2500] 1.15 1.21 1.25 1.29 1.33 ...
#  - attr(*, "dimnames")=List of 2
#   ..$ : chr [1:7] "12" "13" "14" "15" ...
#   ..$ : chr [1:2500] "obs" "sim1" "sim2" "sim3" ...
#
# ------ Inner loop. delaunay_triangulation: 77
# A curve_set(1d) object with 2500 curves observed at 7 argument values
# (1 observed, 2499 simulated).
# Contains:
# $ r     :  num [1:7] 0.664 0.725 0.785 0.846 0.906 ...
# $ funcs :  num [1:7, 1:2500] 1.14 1.2 1.25 1.29 1.33 ...
#  - attr(*, "dimnames")=List of 2
#   ..$ : chr [1:7] "12" "13" "14" "15" ...
#   ..$ : chr [1:2500] "obs" "sim1" "sim2" "sim3" ...
#
# ------ Inner loop. delaunay_triangulation: 78
# A curve_set(1d) object with 2500 curves observed at 7 argument values
# (1 observed, 2499 simulated).
# Contains:
# $ r     :  num [1:7] 0.664 0.725 0.785 0.846 0.906 ...
# $ funcs :  num [1:7, 1:2500] 1.15 1.21 1.26 1.29 1.33 ...
#  - attr(*, "dimnames")=List of 2
#   ..$ : chr [1:7] "12" "13" "14" "15" ...
#   ..$ : chr [1:2500] "obs" "sim1" "sim2" "sim3" ...
#
# ------ Inner loop. delaunay_triangulation: 79
# A curve_set(1d) object with 2500 curves observed at 7 argument values
# (1 observed, 2499 simulated).
# Contains:
# $ r     :  num [1:7] 0.664 0.725 0.785 0.846 0.906 ...
# $ funcs :  num [1:7, 1:2500] 1.15 1.21 1.25 1.29 1.32 ...
#  - attr(*, "dimnames")=List of 2
#   ..$ : chr [1:7] "12" "13" "14" "15" ...
#   ..$ : chr [1:2500] "obs" "sim1" "sim2" "sim3" ...
#
# ------ Inner loop. delaunay_triangulation: 80
# A curve_set(1d) object with 2500 curves observed at 7 argument values
# (1 observed, 2499 simulated).
# Contains:
# $ r     :  num [1:7] 0.664 0.725 0.785 0.846 0.906 ...
# $ funcs :  num [1:7, 1:2500] 1.14 1.2 1.25 1.29 1.33 ...
#  - attr(*, "dimnames")=List of 2
#   ..$ : chr [1:7] "12" "13" "14" "15" ...
#   ..$ : chr [1:2500] "obs" "sim1" "sim2" "sim3" ...
#
# ------ Inner loop. delaunay_triangulation: 81
# A curve_set(1d) object with 2500 curves observed at 7 argument values
# (1 observed, 2499 simulated).
# Contains:
# $ r     :  num [1:7] 0.664 0.725 0.785 0.846 0.906 ...
# $ funcs :  num [1:7, 1:2500] 1.15 1.2 1.25 1.29 1.32 ...
#  - attr(*, "dimnames")=List of 2
#   ..$ : chr [1:7] "12" "13" "14" "15" ...
#   ..$ : chr [1:2500] "obs" "sim1" "sim2" "sim3" ...
#
# ------ Inner loop. delaunay_triangulation: 82
# A curve_set(1d) object with 2500 curves observed at 7 argument values
# (1 observed, 2499 simulated).
# Contains:
# $ r     :  num [1:7] 0.664 0.725 0.785 0.846 0.906 ...
# $ funcs :  num [1:7, 1:2500] 1.14 1.2 1.25 1.29 1.32 ...
#  - attr(*, "dimnames")=List of 2
#   ..$ : chr [1:7] "12" "13" "14" "15" ...
#   ..$ : chr [1:2500] "obs" "sim1" "sim2" "sim3" ...
#
# ------ Inner loop. delaunay_triangulation: 83
# A curve_set(1d) object with 2500 curves observed at 7 argument values
# (1 observed, 2499 simulated).
# Contains:
# $ r     :  num [1:7] 0.664 0.725 0.785 0.846 0.906 ...
# $ funcs :  num [1:7, 1:2500] 1.15 1.21 1.25 1.29 1.33 ...
#  - attr(*, "dimnames")=List of 2
#   ..$ : chr [1:7] "12" "13" "14" "15" ...
#   ..$ : chr [1:2500] "obs" "sim1" "sim2" "sim3" ...
#
# ------ Inner loop. delaunay_triangulation: 84
# A curve_set(1d) object with 2500 curves observed at 7 argument values
# (1 observed, 2499 simulated).
# Contains:
# $ r     :  num [1:7] 0.664 0.725 0.785 0.846 0.906 ...
# $ funcs :  num [1:7, 1:2500] 1.15 1.21 1.26 1.29 1.33 ...
#  - attr(*, "dimnames")=List of 2
#   ..$ : chr [1:7] "12" "13" "14" "15" ...
#   ..$ : chr [1:2500] "obs" "sim1" "sim2" "sim3" ...
#
# ------ Inner loop. delaunay_triangulation: 85
# A curve_set(1d) object with 2500 curves observed at 7 argument values
# (1 observed, 2499 simulated).
# Contains:
# $ r     :  num [1:7] 0.664 0.725 0.785 0.846 0.906 ...
# $ funcs :  num [1:7, 1:2500] 1.15 1.2 1.25 1.29 1.33 ...
#  - attr(*, "dimnames")=List of 2
#   ..$ : chr [1:7] "12" "13" "14" "15" ...
#   ..$ : chr [1:2500] "obs" "sim1" "sim2" "sim3" ...
#
# ------ Inner loop. delaunay_triangulation: 86
# A curve_set(1d) object with 2500 curves observed at 7 argument values
# (1 observed, 2499 simulated).
# Contains:
# $ r     :  num [1:7] 0.664 0.725 0.785 0.846 0.906 ...
# $ funcs :  num [1:7, 1:2500] 1.15 1.21 1.25 1.29 1.33 ...
#  - attr(*, "dimnames")=List of 2
#   ..$ : chr [1:7] "12" "13" "14" "15" ...
#   ..$ : chr [1:2500] "obs" "sim1" "sim2" "sim3" ...
#
# ------ Inner loop. delaunay_triangulation: 87
# A curve_set(1d) object with 2500 curves observed at 7 argument values
# (1 observed, 2499 simulated).
# Contains:
# $ r     :  num [1:7] 0.664 0.725 0.785 0.846 0.906 ...
# $ funcs :  num [1:7, 1:2500] 1.15 1.21 1.26 1.29 1.33 ...
#  - attr(*, "dimnames")=List of 2
#   ..$ : chr [1:7] "12" "13" "14" "15" ...
#   ..$ : chr [1:2500] "obs" "sim1" "sim2" "sim3" ...
#
# ------ Inner loop. delaunay_triangulation: 88
# A curve_set(1d) object with 2500 curves observed at 7 argument values
# (1 observed, 2499 simulated).
# Contains:
# $ r     :  num [1:7] 0.664 0.725 0.785 0.846 0.906 ...
# $ funcs :  num [1:7, 1:2500] 1.14 1.2 1.25 1.29 1.32 ...
#  - attr(*, "dimnames")=List of 2
# ...
#
# Computing histogram...
# ------ Inner loop. sz_classification: 16
#         4096
#
# Computing histogram...
# ------ Inner loop. sz_classification: 17
#         4096
#
# Computing histogram...
# ------ Inner loop. sz_classification: 18
#         4096
#
# Computing histogram...
# ------ Inner loop. sz_classification: 19
#         4096
#
# Computing histogram...
# ------ Inner loop. sz_classification: 20
#         4096
#
# Computing histogram...
# ------ Inner loop. sz_classification: 21
#         4096
#
# Computing histogram...
# ------ Inner loop. sz_classification: 22
#         4096
#
# Computing histogram...
# ------ Inner loop. sz_classification: 23
#         4096
#
# Computing histogram...
# ------ Inner loop. sz_classification: 24
#         4096
#
# Computing histogram...
# ------ Inner loop. sz_classification: 25
#         4096
#
# Computing histogram...
# ------ Inner loop. sz_classification: 26
#         4096
#
# Computing histogram...
# ------ Inner loop. sz_classification: 27
#         4096
#
# Computing histogram...
# ------ Inner loop. sz_classification: 28
#         4096
#
# Computing histogram...
# ------ Inner loop. sz_classification: 29
#         4096
#
# Computing histogram...
# ------ Inner loop. sz_classification: 30
#         4096
#
# Computing histogram...
# ------ Inner loop. sz_classification: 31
#         4096
#
# Computing histogram...
# ------ Inner loop. sz_classification: 32
#         4096
#
# Computing histogram...
# ------ Inner loop. sz_classification: 33
#         4096
#
# Computing histogram...
# ------ Inner loop. sz_classification: 34
#         4096
#
# Computing histogram...
# ------ Inner loop. sz_classification: 35
#         4096
#
# Computing histogram...
# ------ Inner loop. sz_classification: 36
#         4096
#
# Computing histogram...
# ------ Inner loop. sz_classification: 37
#         4096
#
# Computing histogram...
# ------ Inner loop. sz_classification: 38
#         4096
#
# Computing histogram...
# ------ Inner loop. sz_classification: 39
#         4096
#
# Computing histogram...
# ------ Inner loop. sz_classification: 40
#         4096
#
# Computing histogram...
# ------ Inner loop. sz_classification: 41
#         4096
#
# Computing histogram...
# ------ Inner loop. sz_classification: 42
#         4096
#
# Computing histogram...
# ------ Inner loop. sz_classification: 43
#         4096
#
# Computing histogram...
# ------ Inner loop. sz_classification: 44
#         4096
#
# Computing histogram...
# ------ Inner loop. sz_classification: 45
#         4096
#
# Computing histogram...
# ------ Inner loop. sz_classification: 46
#         4096
#
# Computing histogram...
# ------ Inner loop. sz_classification: 47
#         4096
#
# Computing histogram...
# ------ Inner loop. sz_classification: 48
#         4096
#
# Computing histogram...
# ------ Inner loop. sz_classification: 49
#         4096
#
# Computing histogram...
# ------ Inner loop. sz_classification: 50
#         4096
#
# Computing histogram...
# ------ Inner loop. sz_classification: 51
#         4096
#
# Computing histogram...
# ------ Inner loop. sz_classification: 52
#         4096
#
# Computing histogram...
# ------ Inner loop. sz_classification: 53
#         4096
#
# Computing histogram...
# ------ Inner loop. sz_classification: 54
#         4096
#
# Computing histogram...
# ------ Inner loop. sz_classification: 55
#         4096
#
# Computing histogram...
# ------ Inner loop. sz_classification: 56
#         4096
#
# Computing histogram...
# ------ Inner loop. sz_classification: 57
#         4096
#
# Computing histogram...
# ------ Inner loop. sz_classification: 58
#         4096
#
# Computing histogram...
# ------ Inner loop. sz_classification: 59
#         4096
#
# Computing histogram...
# ------ Inner loop. sz_classification: 60
#         4096
#
# Computing histogram...
# ------ Inner loop. sz_classification: 61
#         4096
#
# Computing histogram...
# ------ Inner loop. sz_classification: 62
#         4096
#
# Computing histogram...
# ------ Inner loop. sz_classification: 63
#         4096
#
# Computing histogram...
# ------ Inner loop. sz_classification: 64
#         4096
#
# Computing histogram...
# ------ Inner loop. sz_classification: 65
#         4096
#
# Computing histogram...
# ------ Inner loop. sz_classification: 66
#         4096
#
# Computing histogram...
# ------ Inner loop. sz_classification: 67
#         4096
#
# Computing histogram...
# ------ Inner loop. sz_classification: 68
#         4096
#
# Computing histogram...
# ------ Inner loop. sz_classification: 69
#         4096
#
# Computing histogram...
# ------ Inner loop. sz_classification: 70
#         4096
#
# Computing histogram...
# ------ Inner loop. sz_classification: 71
#         4096
#
# Computing histogram...
# ------ Inner loop. sz_classification: 72
#         4096
#
# Computing histogram...
# ------ Inner loop. sz_classification: 73
#         4096
#
# Computing histogram...
# ------ Inner loop. sz_classification: 74
#         4096
#
# Computing histogram...
# ------ Inner loop. sz_classification: 75
#         4096
#
# Computing histogram...
# ------ Inner loop. sz_classification: 76
#         4096
#
# Computing histogram...
# ------ Inner loop. sz_classification: 77
#         4096
#
# Computing histogram...
# ------ Inner loop. sz_classification: 78
#         4096
#
# Computing histogram...
# ------ Inner loop. sz_classification: 79
#         4096
#
# Computing histogram...
# ------ Inner loop. sz_classification: 80
#         4096
#
# Computing histogram...
# ------ Inner loop. sz_classification: 81
#         4096
#
# Computing histogram...
# ------ Inner loop. sz_classification: 82
#         4096
#
# Computing histogram...
# ------ Inner loop. sz_classification: 83
#         4096
#
# Computing histogram...
# ------ Inner loop. sz_classification: 84
#         4096
#
# Computing histogram...
# ------ Inner loop. sz_classification: 85
#         4096
#
# Computing histogram...
# ------ Inner loop. sz_classification: 86
#         4096
#
# Computing histogram...
# ------ Inner loop. sz_classification: 87
#         4096
#
# Computing histogram...
# ------ Inner loop. sz_classification: 88
#         4096
#
# Computing histogram...
# ------ Inner loop. sz_classification: 89
#         4096
#
# Computing histogram...
# ------ Inner loop. sz_classification: 90
#         4096
#
# Computing histogram...
# ------ Inner loop. sz_classification: 91
#         4096
#
# Computing histogram...
# ------ Inner loop. sz_classification: 92
#         4096
#
# Computing histogram...
# ------ Inner loop. sz_classification: 93
#         4096
#
# Computing histogram...
# ------ Inner loop. sz_classification: 94
#         4096
#
# Computing histogram...
# ------ Inner loop. sz_classification: 95
#         4096
#
# Computing histogram...
# ------ Inner loop. sz_classification: 96
#         4096
#
# Computing histogram...
# ------ Inner loop. sz_classification: 97
#         4096
#
# Computing histogram...
# ------ Inner loop. sz_classification: 98
#         4096
#
# Computing histogram...
# ------ Inner loop. sz_classification: 99
#         4096
#
# Computing histogram...
# Elapsed:138.00222079277037
# --- Method: thresholding_garrote
# ---- Parameters Combination: 0
# ------ Inner loop. thresholding_garrote: 0
# ------ Inner loop. thresholding_garrote: 1
# ------ Inner loop. thresholding_garrote: 2
# ------ Inner loop. thresholding_garrote: 3
# ------ Inner loop. thresholding_garrote: 4
# ------ Inner loop. thresholding_garrote: 5
# ------ Inner loop. thresholding_garrote: 6
# ------ Inner loop. thresholding_garrote: 7
# ------ Inner loop. thresholding_garrote: 8
# ------ Inner loop. thresholding_garrote: 9
# ------ Inner loop. thresholding_garrote: 10
# ------ Inner loop. thresholding_garrote: 11
# ------ Inner loop. thresholding_garrote: 12
# ------ Inner loop. thresholding_garrote: 13
# ------ Inner loop. thresholding_garrote: 14
# ------ Inner loop. thresholding_garrote: 15
# ------ Inner loop. thresholding_garrote: 16
# ------ Inner loop. thresholding_garrote: 17
# ------ Inner loop. thresholding_garrote: 18
# ------ Inner loop. thresholding_garrote: 19
# ------ Inner loop. thresholding_garrote: 20
# ------ Inner loop. thresholding_garrote: 21
# ------ Inner loop. thresholding_garrote: 22
# ------ Inner loop. thresholding_garrote: 23
# ------ Inner loop. thresholding_garrote: 24
# ------ Inner loop. thresholding_garrote: 25
# ------ Inner loop. thresholding_garrote: 26
# ------ Inner loop. thresholding_garrote: 27
# ------ Inner loop. thresholding_garrote: 28
# ------ Inner loop. thresholding_garrote: 29
# ------ Inner loop. thresholding_garrote: 30
# ------ Inner loop. thresholding_garrote: 31
# ------ Inner loop. thresholding_garrote: 32
# ------ Inner loop. thresholding_garrote: 33
# ------ Inner loop. thresholding_garrote: 34
# ------ Inner loop. thresholding_garrote: 35
# ------ Inner loop. thresholding_garrote: 36
# ------ Inner loop. thresholding_garrote: 37
# ------ Inner loop. thresholding_garrote: 38
# ------ Inner loop. thresholding_garrote: 39
# ------ Inner loop. thresholding_garrote: 40
# ------ Inner loop. thresholding_garrote: 41
# ------ Inner loop. thresholding_garrote: 42
# ------ Inner loop. thresholding_garrote: 43
# ------ Inner loop. thresholding_garrote: 44
# ------ Inner loop. thresholding_garrote: 45
# ------ Inner loop. thresholding_garrote: 46
# ------ Inner loop. thresholding_garrote: 47
# ------ Inner loop. thresholding_garrote: 48
# ------ Inner loop. thresholding_garrote: 49
# ------ Inner loop. thresholding_garrote: 50
# ------ Inner loop. thresholding_garrote: 51
# ------ Inner loop. thresholding_garrote: 52
# ------ Inner loop. thresholding_garrote: 53
# ------ Inner loop. thresholding_garrote: 54
# ------ Inner loop. thresholding_garrote: 55
# ------ Inner loop. thresholding_garrote: 56
# ------ Inner loop. thresholding_garrote: 57
# ------ Inner loop. thresholding_garrote: 58
# ------ Inner loop. thresholding_garrote: 59
# ------ Inner loop. thresholding_garrote: 60
# ------ Inner loop. thresholding_garrote: 61
# ------ Inner loop. thresholding_garrote: 62
# ------ Inner loop. thresholding_garrote: 63
# ------ Inner loop. thresholding_garrote: 64
# ------ Inner loop. thresholding_garrote: 65
# ------ Inner loop. thresholding_garrote: 66
# ------ Inner loop. thresholding_garrote: 67
# ------ Inner loop. thresholding_garrote: 68
# ------ Inner loop. thresholding_garrote: 69
# ------ Inner loop. thresholding_garrote: 70
# ------ Inner loop. thresholding_garrote: 71
# ------ Inner loop. thresholding_garrote: 72
# ------ Inner loop. thresholding_garrote: 73
# ------ Inner loop. thresholding_garrote: 74
# ------ Inner loop. thresholding_garrote: 75
# ------ Inner loop. thresholding_garrote: 76
# ------ Inner loop. thresholding_garrote: 77
# ------ Inner loop. thresholding_garrote: 78
# ------ Inner loop. thresholding_garrote: 79
# ------ Inner loop. thresholding_garrote: 80
# ------ Inner loop. thresholding_garrote: 81
# ------ Inner loop. thresholding_garrote: 82
# ------ Inner loop. thresholding_garrote: 83
# ------ Inner loop. thresholding_garrote: 84
# ------ Inner loop. thresholding_garrote: 85
# ------ Inner loop. thresholding_garrote: 86
# ------ Inner loop. thresholding_garrote: 87
# ------ Inner loop. thresholding_garrote: 88
# ------ Inner loop. thresholding_garrote: 89
# ------ Inner loop. thresholding_garrote: 90
# ------ Inner loop. thresholding_garrote: 91
# ------ Inner loop. thresholding_garrote: 92
# ------ Inner loop. thresholding_garrote: 93
# ------ Inner loop. thresholding_garrote: 94
# ------ Inner loop. thresholding_garrote: 95
# ------ Inner loop. thresholding_garrote: 96
# ------ Inner loop. thresholding_garrote: 97
# ------ Inner loop. thresholding_garrote: 98
# ------ Inner loop. thresholding_garrote: 99
# Elapsed:1.2871962761878968
# --- Method: thresholding_hard
# ---- Parameters Combination: 0
# ------ Inner loop. thresholding_hard: 0
# ------ Inner loop. thresholding_hard: 1
# ------ Inner loop. thresholding_hard: 2
# ------ Inner loop. thresholding_hard: 3
# ------ Inner loop. thresholding_hard: 4
# ------ Inner loop. thresholding_hard: 5
# ------ Inner loop. thresholding_hard: 6
# ------ Inner loop. thresholding_hard: 7
# ------ Inner loop. thresholding_hard: 8
# ------ Inner loop. thresholding_hard: 9
# ------ Inner loop. thresholding_hard: 10
# ------ Inner loop. thresholding_hard: 11
# ------ Inner loop. thresholding_hard: 12
# ------ Inner loop. thresholding_hard: 13
# ------ Inner loop. thresholding_hard: 14
# ------ Inner loop. thresholding_hard: 15
# ------ Inner loop. thresholding_hard: 16
# ------ Inner loop. thresholding_hard: 17
# ------ Inner loop. thresholding_hard: 18
# ------ Inner loop. thresholding_hard: 19
# ------ Inner loop. thresholding_hard: 20
# ------ Inner loop. thresholding_hard: 21
# ------ Inner loop. thresholding_hard: 22
# ------ Inner loop. thresholding_hard: 23
# ------ Inner loop. thresholding_hard: 24
# ------ Inner loop. thresholding_hard: 25
# ------ Inner loop. thresholding_hard: 26
# ------ Inner loop. thresholding_hard: 27
# ------ Inner loop. thresholding_hard: 28
# ------ Inner loop. thresholding_hard: 29
# ------ Inner loop. thresholding_hard: 30
# ------ Inner loop. thresholding_hard: 31
# ------ Inner loop. thresholding_hard: 32
# ------ Inner loop. thresholding_hard: 33
# ------ Inner loop. thresholding_hard: 34
# ------ Inner loop. thresholding_hard: 35
# ------ Inner loop. thresholding_hard: 36
# ------ Inner loop. thresholding_hard: 37
# ------ Inner loop. thresholding_hard: 38
# ------ Inner loop. thresholding_hard: 39
# ------ Inner loop. thresholding_hard: 40
# ------ Inner loop. thresholding_hard: 41
# ------ Inner loop. thresholding_hard: 42
# ------ Inner loop. thresholding_hard: 43
# ------ Inner loop. thresholding_hard: 44
# ------ Inner loop. thresholding_hard: 45
# ------ Inner loop. thresholding_hard: 46
# ------ Inner loop. thresholding_hard: 47
# ------ Inner loop. thresholding_hard: 48
# ------ Inner loop. thresholding_hard: 49
# ------ Inner loop. thresholding_hard: 50
# ------ Inner loop. thresholding_hard: 51
# ------ Inner loop. thresholding_hard: 52
# ------ Inner loop. thresholding_hard: 53
# ------ Inner loop. thresholding_hard: 54
# ------ Inner loop. thresholding_hard: 55
# ------ Inner loop. thresholding_hard: 56
# ------ Inner loop. thresholding_hard: 57
# ------ Inner loop. thresholding_hard: 58
# ------ Inner loop. thresholding_hard: 59
# ------ Inner loop. thresholding_hard: 60
# ------ Inner loop. thresholding_hard: 61
# ------ Inner loop. thresholding_hard: 62
# ------ Inner loop. thresholding_hard: 63
# ------ Inner loop. thresholding_hard: 64
# ------ Inner loop. thresholding_hard: 65
# ------ Inner loop. thresholding_hard: 66
# ------ Inner loop. thresholding_hard: 67
# ------ Inner loop. thresholding_hard: 68
# ------ Inner loop. thresholding_hard: 69
# ------ Inner loop. thresholding_hard: 70
# ------ Inner loop. thresholding_hard: 71
# ------ Inner loop. thresholding_hard: 72
# ------ Inner loop. thresholding_hard: 73
# ------ Inner loop. thresholding_hard: 74
# ------ Inner loop. thresholding_hard: 75
# ------ Inner loop. thresholding_hard: 76
# ------ Inner loop. thresholding_hard: 77
# ------ Inner loop. thresholding_hard: 78
# ------ Inner loop. thresholding_hard: 79
# ------ Inner loop. thresholding_hard: 80
# ------ Inner loop. thresholding_hard: 81
# ------ Inner loop. thresholding_hard: 82
# ------ Inner loop. thresholding_hard: 83
# ------ Inner loop. thresholding_hard: 84
# ------ Inner loop. thresholding_hard: 85
# ------ Inner loop. thresholding_hard: 86
# ------ Inner loop. thresholding_hard: 87
# ------ Inner loop. thresholding_hard: 88
# ------ Inner loop. thresholding_hard: 89
# ------ Inner loop. thresholding_hard: 90
# ------ Inner loop. thresholding_hard: 91
# ------ Inner loop. thresholding_hard: 92
# ------ Inner loop. thresholding_hard: 93
# ------ Inner loop. thresholding_hard: 94
# ------ Inner loop. thresholding_hard: 95
# ------ Inner loop. thresholding_hard: 96
# ------ Inner loop. thresholding_hard: 97
# ------ Inner loop. thresholding_hard: 98
# ------ Inner loop. thresholding_hard: 99
# Elapsed:1.2448014736175537
# The test has finished.
#                                                   Mean       Std
# brevdo_method-([], {})                        3.318085  0.200911
# contour_filtering-([], {})                  106.592550  0.358551
# delaunay_triangulation-{'LB': 1.6}            4.401263  0.102618
# delaunay_triangulation-{'adapt_thr': True}   15.015847  0.241527
# empty_space-{'adapt_thr': True}              57.435851  1.389149
# empty_space-{'radi_seg': 0.8}                47.859664  0.512056
# pseudo_bayesian_method-([], {})              21.881486  0.713039
# sz_classification-([], {})                  138.002221  1.510537
# thresholding_garrote-([], {})                 1.287196  0.011069
# thresholding_hard-([], {})                    1.244801  0.009164

# %%
results_df = benchmark.get_results_as_df() # This formats the results on a DataFrame
# results_df.to_csv('study_parameters_es.csv')
results_df
# Out:
#                 Method Parameter      Signal_id  Repetition         20
# 0        brevdo_method  ([], {})  McMultiLinear           0  22.793654
# 1        brevdo_method  ([], {})  McMultiLinear           1  22.541436
# 2        brevdo_method  ([], {})  McMultiLinear           2  22.591180
# 3        brevdo_method  ([], {})  McMultiLinear           3  22.640383
# 4        brevdo_method  ([], {})  McMultiLinear           4  22.684990
# ..                 ...       ...            ...         ...        ...
# 795  thresholding_hard  ([], {})  McMultiLinear          95  27.075663
# 796  thresholding_hard  ([], {})  McMultiLinear          96  26.886910
# 797  thresholding_hard  ([], {})  McMultiLinear          97  27.040826
# 798  thresholding_hard  ([], {})  McMultiLinear          98  27.050767
# 799  thresholding_hard  ([], {})  McMultiLinear          99  27.221763
#
# [1000 rows x 5 columns]

# %%
benchmark = Benchmark(task = 'denoising',
                        methods = my_methods,
                        parameters= my_parameters,
                        N = 2**10,
                        SNRin = [20,], 
                        repetitions = 100,
                        signal_ids=[ 'McMultiLinear',],
                        verbosity=5, 
                        parallelize=False)
                        
benchmark.run_test() # Run the test. my_results is a dictionary with the results for each of the variables of the simulation.
interpreter = ResultsInterpreter(benchmark)
df = interpreter.elapsed_time_summary()
df
# Out:
# Running benchmark...
# - Signal McMultiLinear
# -- SNR: 20 dB
# --- Method: brevdo_method
# ---- Parameters Combination: 0
# ------ Inner loop. brevdo_method: 0
# ------ Inner loop. brevdo_method: 1
# ------ Inner loop. brevdo_method: 2
# ------ Inner loop. brevdo_method: 3
# ------ Inner loop. brevdo_method: 4
# ------ Inner loop. brevdo_method: 5
# ------ Inner loop. brevdo_method: 6
# ------ Inner loop. brevdo_method: 7
# ------ Inner loop. brevdo_method: 8
# ------ Inner loop. brevdo_method: 9
# ------ Inner loop. brevdo_method: 10
# ------ Inner loop. brevdo_method: 11
# ------ Inner loop. brevdo_method: 12
# ------ Inner loop. brevdo_method: 13
# ------ Inner loop. brevdo_method: 14
# ------ Inner loop. brevdo_method: 15
# ------ Inner loop. brevdo_method: 16
# ------ Inner loop. brevdo_method: 17
# ------ Inner loop. brevdo_method: 18
# ------ Inner loop. brevdo_method: 19
# ------ Inner loop. brevdo_method: 20
# ------ Inner loop. brevdo_method: 21
# ------ Inner loop. brevdo_method: 22
# ------ Inner loop. brevdo_method: 23
# ------ Inner loop. brevdo_method: 24
# ------ Inner loop. brevdo_method: 25
# ------ Inner loop. brevdo_method: 26
# ------ Inner loop. brevdo_method: 27
# ------ Inner loop. brevdo_method: 28
# ------ Inner loop. brevdo_method: 29
# ------ Inner loop. brevdo_method: 30
# ------ Inner loop. brevdo_method: 31
# ------ Inner loop. brevdo_method: 32
# ------ Inner loop. brevdo_method: 33
# ------ Inner loop. brevdo_method: 34
# ------ Inner loop. brevdo_method: 35
# ------ Inner loop. brevdo_method: 36
# ------ Inner loop. brevdo_method: 37
# ------ Inner loop. brevdo_method: 38
# ------ Inner loop. brevdo_method: 39
# ------ Inner loop. brevdo_method: 40
# ------ Inner loop. brevdo_method: 41
# ------ Inner loop. brevdo_method: 42
# ------ Inner loop. brevdo_method: 43
# ------ Inner loop. brevdo_method: 44
# ------ Inner loop. brevdo_method: 45
# ------ Inner loop. brevdo_method: 46
# ------ Inner loop. brevdo_method: 47
# ------ Inner loop. brevdo_method: 48
# ------ Inner loop. brevdo_method: 49
# ------ Inner loop. brevdo_method: 50
# ------ Inner loop. brevdo_method: 51
# ------ Inner loop. brevdo_method: 52
# ------ Inner loop. brevdo_method: 53
# ------ Inner loop. brevdo_method: 54
# ------ Inner loop. brevdo_method: 55
# ------ Inner loop. brevdo_method: 56
# ------ Inner loop. brevdo_method: 57
# ------ Inner loop. brevdo_method: 58
# ------ Inner loop. brevdo_method: 59
# ------ Inner loop. brevdo_method: 60
# ------ Inner loop. brevdo_method: 61
# ------ Inner loop. brevdo_method: 62
# ------ Inner loop. brevdo_method: 63
# ------ Inner loop. brevdo_method: 64
# ------ Inner loop. brevdo_method: 65
# ------ Inner loop. brevdo_method: 66
# ------ Inner loop. brevdo_method: 67
# ------ Inner loop. brevdo_method: 68
# ------ Inner loop. brevdo_method: 69
# ------ Inner loop. brevdo_method: 70
# ------ Inner loop. brevdo_method: 71
# ------ Inner loop. brevdo_method: 72
# ------ Inner loop. brevdo_method: 73
# ------ Inner loop. brevdo_method: 74
# ------ Inner loop. brevdo_method: 75
# ------ Inner loop. brevdo_method: 76
# ------ Inner loop. brevdo_method: 77
# ------ Inner loop. brevdo_method: 78
# ------ Inner loop. brevdo_method: 79
# ------ Inner loop. brevdo_method: 80
# ------ Inner loop. brevdo_method: 81
# ------ Inner loop. brevdo_method: 82
# ------ Inner loop. brevdo_method: 83
# ------ Inner loop. brevdo_method: 84
# ------ Inner loop. brevdo_method: 85
# ------ Inner loop. brevdo_method: 86
# ------ Inner loop. brevdo_method: 87
# ------ Inner loop. brevdo_method: 88
# ------ Inner loop. brevdo_method: 89
# ------ Inner loop. brevdo_method: 90
# ------ Inner loop. brevdo_method: 91
# ------ Inner loop. brevdo_method: 92
# ------ Inner loop. brevdo_method: 93
# ------ Inner loop. brevdo_method: 94
# ------ Inner loop. brevdo_method: 95
# ------ Inner loop. brevdo_method: 96
# ------ Inner loop. brevdo_method: 97
# ------ Inner loop. brevdo_method: 98
# ------ Inner loop. brevdo_method: 99
# Elapsed:0.8683697533607483
# --- Method: contour_filtering
# ---- Parameters Combination: 0
# ------ Inner loop. contour_filtering: 0
# ------ Inner loop. contour_filtering: 1
# ------ Inner loop. contour_filtering: 2
# ------ Inner loop. contour_filtering: 3
# ------ Inner loop. contour_filtering: 4
# ------ Inner loop. contour_filtering: 5
# ------ Inner loop. contour_filtering: 6
# ------ Inner loop. contour_filtering: 7
# ------ Inner loop. contour_filtering: 8
# ------ Inner loop. contour_filtering: 9
# ------ Inner loop. contour_filtering: 10
# ------ Inner loop. contour_filtering: 11
# ------ Inner loop. contour_filtering: 12
# ------ Inner loop. contour_filtering: 13
# ------ Inner loop. contour_filtering: 14
# ------ Inner loop. contour_filtering: 15
# ------ Inner loop. contour_filtering: 16
# ------ Inner loop. contour_filtering: 17
# ------ Inner loop. contour_filtering: 18
# ------ Inner loop. contour_filtering: 19
# ------ Inner loop. contour_filtering: 20
# ------ Inner loop. contour_filtering: 21
# ------ Inner loop. contour_filtering: 22
# ------ Inner loop. contour_filtering: 23
# ------ Inner loop. contour_filtering: 24
# ------ Inner loop. contour_filtering: 25
# ------ Inner loop. contour_filtering: 26
# ------ Inner loop. contour_filtering: 27
# ------ Inner loop. contour_filtering: 28
# ------ Inner loop. contour_filtering: 29
# ------ Inner loop. contour_filtering: 30
# ------ Inner loop. contour_filtering: 31
# ------ Inner loop. contour_filtering: 32
# ------ Inner loop. contour_filtering: 33
# ------ Inner loop. contour_filtering: 34
# ------ Inner loop. contour_filtering: 35
# ------ Inner loop. contour_filtering: 36
# ------ Inner loop. contour_filtering: 37
# ------ Inner loop. contour_filtering: 38
# ------ Inner loop. contour_filtering: 39
# ------ Inner loop. contour_filtering: 40
# ------ Inner loop. contour_filtering: 41
# ------ Inner loop. contour_filtering: 42
# ------ Inner loop. contour_filtering: 43
# ------ Inner loop. contour_filtering: 44
# ------ Inner loop. contour_filtering: 45
# ------ Inner loop. contour_filtering: 46
# ------ Inner loop. contour_filtering: 47
# ------ Inner loop. contour_filtering: 48
# ------ Inner loop. contour_filtering: 49
# ------ Inner loop. contour_filtering: 50
# ------ Inner loop. contour_filtering: 51
# ------ Inner loop. contour_filtering: 52
# ------ Inner loop. contour_filtering: 53
# ------ Inner loop. contour_filtering: 54
# ------ Inner loop. contour_filtering: 55
# ------ Inner loop. contour_filtering: 56
# ------ Inner loop. contour_filtering: 57
# ------ Inner loop. contour_filtering: 58
# ------ Inner loop. contour_filtering: 59
# ------ Inner loop. contour_filtering: 60
# ------ Inner loop. contour_filtering: 61
# ------ Inner loop. contour_filtering: 62
# ------ Inner loop. contour_filtering: 63
# ------ Inner loop. contour_filtering: 64
# ------ Inner loop. contour_filtering: 65
# ------ Inner loop. contour_filtering: 66
# ------ Inner loop. contour_filtering: 67
# ------ Inner loop. contour_filtering: 68
# ------ Inner loop. contour_filtering: 69
# ------ Inner loop. contour_filtering: 70
# ------ Inner loop. contour_filtering: 71
# ------ Inner loop. contour_filtering: 72
# ------ Inner loop. contour_filtering: 73
# ------ Inner loop. contour_filtering: 74
# ------ Inner loop. contour_filtering: 75
# ------ Inner loop. contour_filtering: 76
# ------ Inner loop. contour_filtering: 77
# ------ Inner loop. contour_filtering: 78
# ------ Inner loop. contour_filtering: 79
# ------ Inner loop. contour_filtering: 80
# ------ Inner loop. contour_filtering: 81
# ------ Inner loop. contour_filtering: 82
# ------ Inner loop. contour_filtering: 83
# ------ Inner loop. contour_filtering: 84
# ------ Inner loop. contour_filtering: 85
# ------ Inner loop. contour_filtering: 86
# ------ Inner loop. contour_filtering: 87
# ------ Inner loop. contour_filtering: 88
# ------ Inner loop. contour_filtering: 89
# ------ Inner loop. contour_filtering: 90
# ------ Inner loop. contour_filtering: 91
# ------ Inner loop. contour_filtering: 92
# ------ Inner loop. contour_filtering: 93
# ------ Inner loop. contour_filtering: 94
# ------ Inner loop. contour_filtering: 95
# ------ Inner loop. contour_filtering: 96
# ------ Inner loop. contour_filtering: 97
# ------ Inner loop. contour_filtering: 98
# ------ Inner loop. contour_filtering: 99
# Elapsed:25.645484318733214
# --- Method: delaunay_triangulation
# ---- Parameters Combination: 0
# ------ Inner loop. delaunay_triangulation: 0
# ------ Inner loop. delaunay_triangulation: 1
# ------ Inner loop. delaunay_triangulation: 2
# ------ Inner loop. delaunay_triangulation: 3
# ------ Inner loop. delaunay_triangulation: 4
# ------ Inner loop. delaunay_triangulation: 5
# ------ Inner loop. delaunay_triangulation: 6
# ------ Inner loop. delaunay_triangulation: 7
# ------ Inner loop. delaunay_triangulation: 8
# ------ Inner loop. delaunay_triangulation: 9
# ------ Inner loop. delaunay_triangulation: 10
# ------ Inner loop. delaunay_triangulation: 11
# ------ Inner loop. delaunay_triangulation: 12
# ------ Inner loop. delaunay_triangulation: 13
# ------ Inner loop. delaunay_triangulation: 14
# ------ Inner loop. delaunay_triangulation: 15
# ------ Inner loop. delaunay_triangulation: 16
# ------ Inner loop. delaunay_triangulation: 17
# ------ Inner loop. delaunay_triangulation: 18
# ------ Inner loop. delaunay_triangulation: 19
# ------ Inner loop. delaunay_triangulation: 20
# ------ Inner loop. delaunay_triangulation: 21
# ------ Inner loop. delaunay_triangulation: 22
# ------ Inner loop. delaunay_triangulation: 23
# ------ Inner loop. delaunay_triangulation: 24
# ------ Inner loop. delaunay_triangulation: 25
# ------ Inner loop. delaunay_triangulation: 26
# ------ Inner loop. delaunay_triangulation: 27
# ------ Inner loop. delaunay_triangulation: 28
# ------ Inner loop. delaunay_triangulation: 29
# ------ Inner loop. delaunay_triangulation: 30
# ------ Inner loop. delaunay_triangulation: 31
# ------ Inner loop. delaunay_triangulation: 32
# ------ Inner loop. delaunay_triangulation: 33
# ------ Inner loop. delaunay_triangulation: 34
# ------ Inner loop. delaunay_triangulation: 35
# ------ Inner loop. delaunay_triangulation: 36
# ------ Inner loop. delaunay_triangulation: 37
# ------ Inner loop. delaunay_triangulation: 38
# ------ Inner loop. delaunay_triangulation: 39
# ------ Inner loop. delaunay_triangulation: 40
# ------ Inner loop. delaunay_triangulation: 41
# ------ Inner loop. delaunay_triangulation: 42
# ------ Inner loop. delaunay_triangulation: 43
# ------ Inner loop. delaunay_triangulation: 44
# ------ Inner loop. delaunay_triangulation: 45
# ------ Inner loop. delaunay_triangulation: 46
# ------ Inner loop. delaunay_triangulation: 47
# ------ Inner loop. delaunay_triangulation: 48
# ------ Inner loop. delaunay_triangulation: 49
# ------ Inner loop. delaunay_triangulation: 50
# ------ Inner loop. delaunay_triangulation: 51
# ------ Inner loop. delaunay_triangulation: 52
# ------ Inner loop. delaunay_triangulation: 53
# ------ Inner loop. delaunay_triangulation: 54
# ------ Inner loop. delaunay_triangulation: 55
# ------ Inner loop. delaunay_triangulation: 56
# ------ Inner loop. delaunay_triangulation: 57
# ------ Inner loop. delaunay_triangulation: 58
# ------ Inner loop. delaunay_triangulation: 59
# ------ Inner loop. delaunay_triangulation: 60
# ------ Inner loop. delaunay_triangulation: 61
# ------ Inner loop. delaunay_triangulation: 62
# ------ Inner loop. delaunay_triangulation: 63
# ------ Inner loop. delaunay_triangulation: 64
# ------ Inner loop. delaunay_triangulation: 65
# ------ Inner loop. delaunay_triangulation: 66
# ------ Inner loop. delaunay_triangulation: 67
# ------ Inner loop. delaunay_triangulation: 68
# ------ Inner loop. delaunay_triangulation: 69
# ------ Inner loop. delaunay_triangulation: 70
# ------ Inner loop. delaunay_triangulation: 71
# ------ Inner loop. delaunay_triangulation: 72
# ------ Inner loop. delaunay_triangulation: 73
# ------ Inner loop. delaunay_triangulation: 74
# ------ Inner loop. delaunay_triangulation: 75
# ------ Inner loop. delaunay_triangulation: 76
# ------ Inner loop. delaunay_triangulation: 77
# ------ Inner loop. delaunay_triangulation: 78
# ------ Inner loop. delaunay_triangulation: 79
# ------ Inner loop. delaunay_triangulation: 80
# ------ Inner loop. delaunay_triangulation: 81
# ------ Inner loop. delaunay_triangulation: 82
# ------ Inner loop. delaunay_triangulation: 83
# ------ Inner loop. delaunay_triangulation: 84
# ------ Inner loop. delaunay_triangulation: 85
# ------ Inner loop. delaunay_triangulation: 86
# ------ Inner loop. delaunay_triangulation: 87
# ------ Inner loop. delaunay_triangulation: 88
# ------ Inner loop. delaunay_triangulation: 89
# ------ Inner loop. delaunay_triangulation: 90
# ------ Inner loop. delaunay_triangulation: 91
# ------ Inner loop. delaunay_triangulation: 92
# ------ Inner loop. delaunay_triangulation: 93
# ------ Inner loop. delaunay_triangulation: 94
# ------ Inner loop. delaunay_triangulation: 95
# ------ Inner loop. delaunay_triangulation: 96
# ------ Inner loop. delaunay_triangulation: 97
# ------ Inner loop. delaunay_triangulation: 98
# ------ Inner loop. delaunay_triangulation: 99
# Elapsed:1.18056565284729
# ---- Parameters Combination: 1
# ------ Inner loop. delaunay_triangulation: 0
# A curve_set(1d) object with 2500 curves observed at 9 argument values
# (1 observed, 2499 simulated).
# Contains:
# $ r     :  num [1:9] 0.673 0.715 0.757 0.8 0.842 ...
# $ funcs :  num [1:9, 1:2500] 1.11 1.15 1.18 1.21 1.23 ...
#  - attr(*, "dimnames")=List of 2
#   ..$ : chr [1:9] "17" "18" "19" "20" ...
#   ..$ : chr [1:2500] "obs" "sim1" "sim2" "sim3" ...
#
# ------ Inner loop. delaunay_triangulation: 1
# A curve_set(1d) object with 2500 curves observed at 9 argument values
# (1 observed, 2499 simulated).
# Contains:
# $ r     :  num [1:9] 0.673 0.715 0.757 0.8 0.842 ...
# $ funcs :  num [1:9, 1:2500] 1.11 1.14 1.17 1.2 1.23 ...
#  - attr(*, "dimnames")=List of 2
#   ..$ : chr [1:9] "17" "18" "19" "20" ...
#   ..$ : chr [1:2500] "obs" "sim1" "sim2" "sim3" ...
#
# ------ Inner loop. delaunay_triangulation: 2
# A curve_set(1d) object with 2500 curves observed at 9 argument values
# (1 observed, 2499 simulated).
# Contains:
# $ r     :  num [1:9] 0.673 0.715 0.757 0.8 0.842 ...
# $ funcs :  num [1:9, 1:2500] 1.1 1.14 1.18 1.21 1.23 ...
#  - attr(*, "dimnames")=List of 2
#   ..$ : chr [1:9] "17" "18" "19" "20" ...
#   ..$ : chr [1:2500] "obs" "sim1" "sim2" "sim3" ...
#
# ------ Inner loop. delaunay_triangulation: 3
# A curve_set(1d) object with 2500 curves observed at 9 argument values
# (1 observed, 2499 simulated).
# Contains:
# $ r     :  num [1:9] 0.673 0.715 0.757 0.8 0.842 ...
# $ funcs :  num [1:9, 1:2500] 1.11 1.15 1.18 1.21 1.24 ...
#  - attr(*, "dimnames")=List of 2
#   ..$ : chr [1:9] "17" "18" "19" "20" ...
#   ..$ : chr [1:2500] "obs" "sim1" "sim2" "sim3" ...
#
# ------ Inner loop. delaunay_triangulation: 4
# A curve_set(1d) object with 2500 curves observed at 9 argument values
# (1 observed, 2499 simulated).
# Contains:
# $ r     :  num [1:9] 0.673 0.715 0.757 0.8 0.842 ...
# $ funcs :  num [1:9, 1:2500] 1.11 1.15 1.18 1.21 1.24 ...
#  - attr(*, "dimnames")=List of 2
#   ..$ : chr [1:9] "17" "18" "19" "20" ...
#   ..$ : chr [1:2500] "obs" "sim1" "sim2" "sim3" ...
#
# ------ Inner loop. delaunay_triangulation: 5
# A curve_set(1d) object with 2500 curves observed at 9 argument values
# (1 observed, 2499 simulated).
# Contains:
# $ r     :  num [1:9] 0.673 0.715 0.757 0.8 0.842 ...
# $ funcs :  num [1:9, 1:2500] 1.11 1.15 1.18 1.21 1.24 ...
#  - attr(*, "dimnames")=List of 2
#   ..$ : chr [1:9] "17" "18" "19" "20" ...
#   ..$ : chr [1:2500] "obs" "sim1" "sim2" "sim3" ...
#
# ------ Inner loop. delaunay_triangulation: 6
# A curve_set(1d) object with 2500 curves observed at 9 argument values
# (1 observed, 2499 simulated).
# Contains:
# $ r     :  num [1:9] 0.673 0.715 0.757 0.8 0.842 ...
# $ funcs :  num [1:9, 1:2500] 1.11 1.14 1.18 1.21 1.23 ...
#  - attr(*, "dimnames")=List of 2
#   ..$ : chr [1:9] "17" "18" "19" "20" ...
#   ..$ : chr [1:2500] "obs" "sim1" "sim2" "sim3" ...
#
# ------ Inner loop. delaunay_triangulation: 7
# A curve_set(1d) object with 2500 curves observed at 9 argument values
# (1 observed, 2499 simulated).
# Contains:
# $ r     :  num [1:9] 0.673 0.715 0.757 0.8 0.842 ...
# $ funcs :  num [1:9, 1:2500] 1.11 1.14 1.18 1.21 1.23 ...
#  - attr(*, "dimnames")=List of 2
#   ..$ : chr [1:9] "17" "18" "19" "20" ...
#   ..$ : chr [1:2500] "obs" "sim1" "sim2" "sim3" ...
#
# ------ Inner loop. delaunay_triangulation: 8
# A curve_set(1d) object with 2500 curves observed at 9 argument values
# (1 observed, 2499 simulated).
# Contains:
# $ r     :  num [1:9] 0.673 0.715 0.757 0.8 0.842 ...
# $ funcs :  num [1:9, 1:2500] 1.11 1.14 1.18 1.21 1.23 ...
#  - attr(*, "dimnames")=List of 2
#   ..$ : chr [1:9] "17" "18" "19" "20" ...
#   ..$ : chr [1:2500] "obs" "sim1" "sim2" "sim3" ...
#
# ------ Inner loop. delaunay_triangulation: 9
# A curve_set(1d) object with 2500 curves observed at 9 argument values
# (1 observed, 2499 simulated).
# Contains:
# $ r     :  num [1:9] 0.673 0.715 0.757 0.8 0.842 ...
# $ funcs :  num [1:9, 1:2500] 1.11 1.15 1.18 1.21 1.24 ...
#  - attr(*, "dimnames")=List of 2
#   ..$ : chr [1:9] "17" "18" "19" "20" ...
#   ..$ : chr [1:2500] "obs" "sim1" "sim2" "sim3" ...
#
# ------ Inner loop. delaunay_triangulation: 10
# A curve_set(1d) object with 2500 curves observed at 9 argument values
# (1 observed, 2499 simulated).
# Contains:
# $ r     :  num [1:9] 0.673 0.715 0.757 0.8 0.842 ...
# $ funcs :  num [1:9, 1:2500] 1.11 1.15 1.18 1.21 1.23 ...
#  - attr(*, "dimnames")=List of 2
#   ..$ : chr [1:9] "17" "18" "19" "20" ...
#   ..$ : chr [1:2500] "obs" "sim1" "sim2" "sim3" ...
#
# ------ Inner loop. delaunay_triangulation: 11
# A curve_set(1d) object with 2500 curves observed at 9 argument values
# (1 observed, 2499 simulated).
# Contains:
# $ r     :  num [1:9] 0.673 0.715 0.757 0.8 0.842 ...
# $ funcs :  num [1:9, 1:2500] 1.11 1.14 1.18 1.21 1.24 ...
#  - attr(*, "dimnames")=List of 2
#   ..$ : chr [1:9] "17" "18" "19" "20" ...
#   ..$ : chr [1:2500] "obs" "sim1" "sim2" "sim3" ...
#
# ------ Inner loop. delaunay_triangulation: 12
# A curve_set(1d) object with 2500 curves observed at 9 argument values
# (1 observed, 2499 simulated).
# Contains:
# $ r     :  num [1:9] 0.673 0.715 0.757 0.8 0.842 ...
# $ funcs :  num [1:9, 1:2500] 1.11 1.15 1.18 1.21 1.23 ...
#  - attr(*, "dimnames")=List of 2
#   ..$ : chr [1:9] "17" "18" "19" "20" ...
#   ..$ : chr [1:2500] "obs" "sim1" "sim2" "sim3" ...
#
# ------ Inner loop. delaunay_triangulation: 13
# A curve_set(1d) object with 2500 curves observed at 9 argument values
# (1 observed, 2499 simulated).
# Contains:
# $ r     :  num [1:9] 0.673 0.715 0.757 0.8 0.842 ...
# $ funcs :  num [1:9, 1:2500] 1.12 1.15 1.19 1.22 1.24 ...
#  - attr(*, "dimnames")=List of 2
#   ..$ : chr [1:9] "17" "18" "19" "20" ...
#   ..$ : chr [1:2500] "obs" "sim1" "sim2" "sim3" ...
#
# ------ Inner loop. delaunay_triangulation: 14
# A curve_set(1d) object with 2500 curves observed at 9 argument values
# (1 observed, 2499 simulated).
# Contains:
# $ r     :  num [1:9] 0.673 0.715 0.757 0.8 0.842 ...
# $ funcs :  num [1:9, 1:2500] 1.11 1.14 1.18 1.21 1.23 ...
#  - attr(*, "dimnames")=List of 2
#   ..$ : chr [1:9] "17" "18" "19" "20" ...
#   ..$ : chr [1:2500] "obs" "sim1" "sim2" "sim3" ...
#
# ------ Inner loop. delaunay_triangulation: 15
# A curve_set(1d) object with 2500 curves observed at 9 argument values
# (1 observed, 2499 simulated).
# Contains:
# $ r     :  num [1:9] 0.673 0.715 0.757 0.8 0.842 ...
# $ funcs :  num [1:9, 1:2500] 1.11 1.15 1.19 1.21 1.24 ...
#  - attr(*, "dimnames")=List of 2
#   ..$ : chr [1:9] "17" "18" "19" "20" ...
#   ..$ : chr [1:2500] "obs" "sim1" "sim2" "sim3" ...
#
# ------ Inner loop. delaunay_triangulation: 16
# A curve_set(1d) object with 2500 curves observed at 9 argument values
# (1 observed, 2499 simulated).
# Contains:
# $ r     :  num [1:9] 0.673 0.715 0.757 0.8 0.842 ...
# $ funcs :  num [1:9, 1:2500] 1.11 1.15 1.18 1.21 1.23 ...
#  - attr(*, "dimnames")=List of 2
#   ..$ : chr [1:9] "17" "18" "19" "20" ...
#   ..$ : chr [1:2500] "obs" "sim1" "sim2" "sim3" ...
#
# ------ Inner loop. delaunay_triangulation: 17
# A curve_set(1d) object with 2500 curves observed at 9 argument values
# (1 observed, 2499 simulated).
# Contains:
# $ r     :  num [1:9] 0.673 0.715 0.757 0.8 0.842 ...
# $ funcs :  num [1:9, 1:2500] 1.12 1.15 1.19 1.21 1.24 ...
#  - attr(*, "dimnames")=List of 2
#   ..$ : chr [1:9] "17" "18" "19" "20" ...
#   ..$ : chr [1:2500] "obs" "sim1" "sim2" "sim3" ...
#
# ------ Inner loop. delaunay_triangulation: 18
# A curve_set(1d) object with 2500 curves observed at 9 argument values
# (1 observed, 2499 simulated).
# Contains:
# $ r     :  num [1:9] 0.673 0.715 0.757 0.8 0.842 ...
# $ funcs :  num [1:9, 1:2500] 1.1 1.14 1.18 1.21 1.23 ...
#  - attr(*, "dimnames")=List of 2
#   ..$ : chr [1:9] "17" "18" "19" "20" ...
#   ..$ : chr [1:2500] "obs" "sim1" "sim2" "sim3" ...
#
# ------ Inner loop. delaunay_triangulation: 19
# A curve_set(1d) object with 2500 curves observed at 9 argument values
# (1 observed, 2499 simulated).
# Contains:
# $ r     :  num [1:9] 0.673 0.715 0.757 0.8 0.842 ...
# $ funcs :  num [1:9, 1:2500] 1.11 1.15 1.18 1.21 1.24 ...
#  - attr(*, "dimnames")=List of 2
#   ..$ : chr [1:9] "17" "18" "19" "20" ...
#   ..$ : chr [1:2500] "obs" "sim1" "sim2" "sim3" ...
#
# ------ Inner loop. delaunay_triangulation: 20
# A curve_set(1d) object with 2500 curves observed at 9 argument values
# (1 observed, 2499 simulated).
# Contains:
# $ r     :  num [1:9] 0.673 0.715 0.757 0.8 0.842 ...
# $ funcs :  num [1:9, 1:2500] 1.1 1.14 1.18 1.21 1.24 ...
#  - attr(*, "dimnames")=List of 2
#   ..$ : chr [1:9] "17" "18" "19" "20" ...
#   ..$ : chr [1:2500] "obs" "sim1" "sim2" "sim3" ...
#
# ------ Inner loop. delaunay_triangulation: 21
# A curve_set(1d) object with 2500 curves observed at 9 argument values
# (1 observed, 2499 simulated).
# Contains:
# $ r     :  num [1:9] 0.673 0.715 0.757 0.8 0.842 ...
# $ funcs :  num [1:9, 1:2500] 1.1 1.14 1.18 1.21 1.23 ...
#  - attr(*, "dimnames")=List of 2
#   ..$ : chr [1:9] "17" "18" "19" "20" ...
#   ..$ : chr [1:2500] "obs" "sim1" "sim2" "sim3" ...
#
# ------ Inner loop. delaunay_triangulation: 22
# A curve_set(1d) object with 2500 curves observed at 9 argument values
# (1 observed, 2499 simulated).
# Contains:
# $ r     :  num [1:9] 0.673 0.715 0.757 0.8 0.842 ...
# $ funcs :  num [1:9, 1:2500] 1.11 1.15 1.18 1.21 1.24 ...
#  - attr(*, "dimnames")=List of 2
#   ..$ : chr [1:9] "17" "18" "19" "20" ...
#   ..$ : chr [1:2500] "obs" "sim1" "sim2" "sim3" ...
#
# ------ Inner loop. delaunay_triangulation: 23
# A curve_set(1d) object with 2500 curves observed at 9 argument values
# (1 observed, 2499 simulated).
# Contains:
# $ r     :  num [1:9] 0.673 0.715 0.757 0.8 0.842 ...
# $ funcs :  num [1:9, 1:2500] 1.1 1.14 1.17 1.2 1.23 ...
#  - attr(*, "dimnames")=List of 2
#   ..$ : chr [1:9] "17" "18" "19" "20" ...
#   ..$ : chr [1:2500] "obs" "sim1" "sim2" "sim3" ...
#
# ------ Inner loop. delaunay_triangulation: 24
# A curve_set(1d) object with 2500 curves observed at 9 argument values
# (1 observed, 2499 simulated).
# Contains:
# $ r     :  num [1:9] 0.673 0.715 0.757 0.8 0.842 ...
# $ funcs :  num [1:9, 1:2500] 1.11 1.15 1.18 1.21 1.23 ...
#  - attr(*, "dimnames")=List of 2
#   ..$ : chr [1:9] "17" "18" "19" "20" ...
#   ..$ : chr [1:2500] "obs" "sim1" "sim2" "sim3" ...
#
# ------ Inner loop. delaunay_triangulation: 25
# A curve_set(1d) object with 2500 curves observed at 9 argument values
# (1 observed, 2499 simulated).
# Contains:
# $ r     :  num [1:9] 0.673 0.715 0.757 0.8 0.842 ...
# $ funcs :  num [1:9, 1:2500] 1.1 1.14 1.18 1.21 1.23 ...
#  - attr(*, "dimnames")=List of 2
#   ..$ : chr [1:9] "17" "18" "19" "20" ...
#   ..$ : chr [1:2500] "obs" "sim1" "sim2" "sim3" ...
#
# ------ Inner loop. delaunay_triangulation: 26
# A curve_set(1d) object with 2500 curves observed at 9 argument values
# (1 observed, 2499 simulated).
# Contains:
# $ r     :  num [1:9] 0.673 0.715 0.757 0.8 0.842 ...
# $ funcs :  num [1:9, 1:2500] 1.11 1.14 1.18 1.21 1.23 ...
#  - attr(*, "dimnames")=List of 2
#   ..$ : chr [1:9] "17" "18" "19" "20" ...
#   ..$ : chr [1:2500] "obs" "sim1" "sim2" "sim3" ...
#
# ------ Inner loop. delaunay_triangulation: 27
# A curve_set(1d) object with 2500 curves observed at 9 argument values
# (1 observed, 2499 simulated).
# Contains:
# $ r     :  num [1:9] 0.673 0.715 0.757 0.8 0.842 ...
# $ funcs :  num [1:9, 1:2500] 1.1 1.14 1.17 1.2 1.23 ...
#  - attr(*, "dimnames")=List of 2
#   ..$ : chr [1:9] "17" "18" "19" "20" ...
#   ..$ : chr [1:2500] "obs" "sim1" "sim2" "sim3" ...
#
# ------ Inner loop. delaunay_triangulation: 28
# A curve_set(1d) object with 2500 curves observed at 9 argument values
# (1 observed, 2499 simulated).
# Contains:
# $ r     :  num [1:9] 0.673 0.715 0.757 0.8 0.842 ...
# $ funcs :  num [1:9, 1:2500] 1.11 1.15 1.18 1.21 1.24 ...
#  - attr(*, "dimnames")=List of 2
#   ..$ : chr [1:9] "17" "18" "19" "20" ...
#   ..$ : chr [1:2500] "obs" "sim1" "sim2" "sim3" ...
#
# ------ Inner loop. delaunay_triangulation: 29
# A curve_set(1d) object with 2500 curves observed at 9 argument values
# (1 observed, 2499 simulated).
# Contains:
# $ r     :  num [1:9] 0.673 0.715 0.757 0.8 0.842 ...
# $ funcs :  num [1:9, 1:2500] 1.11 1.15 1.18 1.21 1.23 ...
#  - attr(*, "dimnames")=List of 2
#   ..$ : chr [1:9] "17" "18" "19" "20" ...
#   ..$ : chr [1:2500] "obs" "sim1" "sim2" "sim3" ...
#
# ------ Inner loop. delaunay_triangulation: 30
# A curve_set(1d) object with 2500 curves observed at 9 argument values
# (1 observed, 2499 simulated).
# Contains:
# $ r     :  num [1:9] 0.673 0.715 0.757 0.8 0.842 ...
# $ funcs :  num [1:9, 1:2500] 1.1 1.14 1.18 1.2 1.23 ...
#  - attr(*, "dimnames")=List of 2
#   ..$ : chr [1:9] "17" "18" "19" "20" ...
#   ..$ : chr [1:2500] "obs" "sim1" "sim2" "sim3" ...
#
# ------ Inner loop. delaunay_triangulation: 31
# A curve_set(1d) object with 2500 curves observed at 9 argument values
# (1 observed, 2499 simulated).
# Contains:
# $ r     :  num [1:9] 0.673 0.715 0.757 0.8 0.842 ...
# $ funcs :  num [1:9, 1:2500] 1.11 1.15 1.18 1.21 1.23 ...
#  - attr(*, "dimnames")=List of 2
#   ..$ : chr [1:9] "17" "18" "19" "20" ...
#   ..$ : chr [1:2500] "obs" "sim1" "sim2" "sim3" ...
#
# ------ Inner loop. delaunay_triangulation: 32
# A curve_set(1d) object with 2500 curves observed at 9 argument values
# (1 observed, 2499 simulated).
# Contains:
# $ r     :  num [1:9] 0.673 0.715 0.757 0.8 0.842 ...
# $ funcs :  num [1:9, 1:2500] 1.11 1.15 1.18 1.21 1.24 ...
#  - attr(*, "dimnames")=List of 2
#   ..$ : chr [1:9] "17" "18" "19" "20" ...
#   ..$ : chr [1:2500] "obs" "sim1" "sim2" "sim3" ...
#
# ------ Inner loop. delaunay_triangulation: 33
# A curve_set(1d) object with 2500 curves observed at 9 argument values
# (1 observed, 2499 simulated).
# Contains:
# $ r     :  num [1:9] 0.673 0.715 0.757 0.8 0.842 ...
# $ funcs :  num [1:9, 1:2500] 1.11 1.15 1.18 1.21 1.23 ...
#  - attr(*, "dimnames")=List of 2
#   ..$ : chr [1:9] "17" "18" "19" "20" ...
#   ..$ : chr [1:2500] "obs" "sim1" "sim2" "sim3" ...
#
# ------ Inner loop. delaunay_triangulation: 34
# A curve_set(1d) object with 2500 curves observed at 9 argument values
# (1 observed, 2499 simulated).
# Contains:
# $ r     :  num [1:9] 0.673 0.715 0.757 0.8 0.842 ...
# $ funcs :  num [1:9, 1:2500] 1.11 1.15 1.18 1.21 1.24 ...
#  - attr(*, "dimnames")=List of 2
#   ..$ : chr [1:9] "17" "18" "19" "20" ...
#   ..$ : chr [1:2500] "obs" "sim1" "sim2" "sim3" ...
#
# ------ Inner loop. delaunay_triangulation: 35
# A curve_set(1d) object with 2500 curves observed at 9 argument values
# (1 observed, 2499 simulated).
# Contains:
# $ r     :  num [1:9] 0.673 0.715 0.757 0.8 0.842 ...
# $ funcs :  num [1:9, 1:2500] 1.1 1.14 1.18 1.2 1.23 ...
#  - attr(*, "dimnames")=List of 2
#   ..$ : chr [1:9] "17" "18" "19" "20" ...
#   ..$ : chr [1:2500] "obs" "sim1" "sim2" "sim3" ...
#
# ------ Inner loop. delaunay_triangulation: 36
# A curve_set(1d) object with 2500 curves observed at 9 argument values
# (1 observed, 2499 simulated).
# Contains:
# $ r     :  num [1:9] 0.673 0.715 0.757 0.8 0.842 ...
# $ funcs :  num [1:9, 1:2500] 1.1 1.14 1.18 1.2 1.23 ...
#  - attr(*, "dimnames")=List of 2
#   ..$ : chr [1:9] "17" "18" "19" "20" ...
#   ..$ : chr [1:2500] "obs" "sim1" "sim2" "sim3" ...
#
# ------ Inner loop. delaunay_triangulation: 37
# A curve_set(1d) object with 2500 curves observed at 9 argument values
# (1 observed, 2499 simulated).
# Contains:
# $ r     :  num [1:9] 0.673 0.715 0.757 0.8 0.842 ...
# $ funcs :  num [1:9, 1:2500] 1.12 1.15 1.19 1.22 1.24 ...
#  - attr(*, "dimnames")=List of 2
#   ..$ : chr [1:9] "17" "18" "19" "20" ...
#   ..$ : chr [1:2500] "obs" "sim1" "sim2" "sim3" ...
#
# ------ Inner loop. delaunay_triangulation: 38
# A curve_set(1d) object with 2500 curves observed at 9 argument values
# (1 observed, 2499 simulated).
# Contains:
# $ r     :  num [1:9] 0.673 0.715 0.757 0.8 0.842 ...
# $ funcs :  num [1:9, 1:2500] 1.11 1.15 1.18 1.21 1.23 ...
#  - attr(*, "dimnames")=List of 2
#   ..$ : chr [1:9] "17" "18" "19" "20" ...
#   ..$ : chr [1:2500] "obs" "sim1" "sim2" "sim3" ...
#
# ------ Inner loop. delaunay_triangulation: 39
# A curve_set(1d) object with 2500 curves observed at 9 argument values
# (1 observed, 2499 simulated).
# Contains:
# $ r     :  num [1:9] 0.673 0.715 0.757 0.8 0.842 ...
# $ funcs :  num [1:9, 1:2500] 1.11 1.15 1.18 1.21 1.23 ...
#  - attr(*, "dimnames")=List of 2
#   ..$ : chr [1:9] "17" "18" "19" "20" ...
#   ..$ : chr [1:2500] "obs" "sim1" "sim2" "sim3" ...
#
# ------ Inner loop. delaunay_triangulation: 40
# A curve_set(1d) object with 2500 curves observed at 9 argument values
# (1 observed, 2499 simulated).
# Contains:
# $ r     :  num [1:9] 0.673 0.715 0.757 0.8 0.842 ...
# $ funcs :  num [1:9, 1:2500] 1.11 1.14 1.17 1.2 1.23 ...
#  - attr(*, "dimnames")=List of 2
#   ..$ : chr [1:9] "17" "18" "19" "20" ...
#   ..$ : chr [1:2500] "obs" "sim1" "sim2" "sim3" ...
#
# ------ Inner loop. delaunay_triangulation: 41
# A curve_set(1d) object with 2500 curves observed at 9 argument values
# (1 observed, 2499 simulated).
# Contains:
# $ r     :  num [1:9] 0.673 0.715 0.757 0.8 0.842 ...
# $ funcs :  num [1:9, 1:2500] 1.1 1.14 1.17 1.2 1.23 ...
#  - attr(*, "dimnames")=List of 2
#   ..$ : chr [1:9] "17" "18" "19" "20" ...
#   ..$ : chr [1:2500] "obs" "sim1" "sim2" "sim3" ...
#
# ------ Inner loop. delaunay_triangulation: 42
# A curve_set(1d) object with 2500 curves observed at 9 argument values
# (1 observed, 2499 simulated).
# Contains:
# $ r     :  num [1:9] 0.673 0.715 0.757 0.8 0.842 ...
# $ funcs :  num [1:9, 1:2500] 1.11 1.15 1.18 1.21 1.24 ...
#  - attr(*, "dimnames")=List of 2
#   ..$ : chr [1:9] "17" "18" "19" "20" ...
#   ..$ : chr [1:2500] "obs" "sim1" "sim2" "sim3" ...
#
# ------ Inner loop. delaunay_triangulation: 43
# A curve_set(1d) object with 2500 curves observed at 9 argument values
# (1 observed, 2499 simulated).
# Contains:
# $ r     :  num [1:9] 0.673 0.715 0.757 0.8 0.842 ...
# $ funcs :  num [1:9, 1:2500] 1.11 1.15 1.18 1.21 1.23 ...
#  - attr(*, "dimnames")=List of 2
#   ..$ : chr [1:9] "17" "18" "19" "20" ...
#   ..$ : chr [1:2500] "obs" "sim1" "sim2" "sim3" ...
#
# ------ Inner loop. delaunay_triangulation: 44
# A curve_set(1d) object with 2500 curves observed at 9 argument values
# (1 observed, 2499 simulated).
# Contains:
# $ r     :  num [1:9] 0.673 0.715 0.757 0.8 0.842 ...
# $ funcs :  num [1:9, 1:2500] 1.11 1.14 1.18 1.21 1.23 ...
#  - attr(*, "dimnames")=List of 2
#   ..$ : chr [1:9] "17" "18" "19" "20" ...
#   ..$ : chr [1:2500] "obs" "sim1" "sim2" "sim3" ...
#
# ------ Inner loop. delaunay_triangulation: 45
# A curve_set(1d) object with 2500 curves observed at 9 argument values
# (1 observed, 2499 simulated).
# Contains:
# $ r     :  num [1:9] 0.673 0.715 0.757 0.8 0.842 ...
# $ funcs :  num [1:9, 1:2500] 1.11 1.15 1.18 1.21 1.24 ...
#  - attr(*, "dimnames")=List of 2
#   ..$ : chr [1:9] "17" "18" "19" "20" ...
#   ..$ : chr [1:2500] "obs" "sim1" "sim2" "sim3" ...
#
# ------ Inner loop. delaunay_triangulation: 46
# A curve_set(1d) object with 2500 curves observed at 9 argument values
# (1 observed, 2499 simulated).
# Contains:
# $ r     :  num [1:9] 0.673 0.715 0.757 0.8 0.842 ...
# $ funcs :  num [1:9, 1:2500] 1.11 1.15 1.18 1.21 1.23 ...
#  - attr(*, "dimnames")=List of 2
#   ..$ : chr [1:9] "17" "18" "19" "20" ...
#   ..$ : chr [1:2500] "obs" "sim1" "sim2" "sim3" ...
#
# ------ Inner loop. delaunay_triangulation: 47
# A curve_set(1d) object with 2500 curves observed at 9 argument values
# (1 observed, 2499 simulated).
# Contains:
# $ r     :  num [1:9] 0.673 0.715 0.757 0.8 0.842 ...
# $ funcs :  num [1:9, 1:2500] 1.11 1.14 1.18 1.21 1.23 ...
#  - attr(*, "dimnames")=List of 2
#   ..$ : chr [1:9] "17" "18" "19" "20" ...
#   ..$ : chr [1:2500] "obs" "sim1" "sim2" "sim3" ...
#
# ------ Inner loop. delaunay_triangulation: 48
# A curve_set(1d) object with 2500 curves observed at 9 argument values
# (1 observed, 2499 simulated).
# Contains:
# $ r     :  num [1:9] 0.673 0.715 0.757 0.8 0.842 ...
# $ funcs :  num [1:9, 1:2500] 1.11 1.15 1.18 1.21 1.24 ...
#  - attr(*, "dimnames")=List of 2
#   ..$ : chr [1:9] "17" "18" "19" "20" ...
#   ..$ : chr [1:2500] "obs" "sim1" "sim2" "sim3" ...
#
# ------ Inner loop. delaunay_triangulation: 49
# A curve_set(1d) object with 2500 curves observed at 9 argument values
# (1 observed, 2499 simulated).
# Contains:
# $ r     :  num [1:9] 0.673 0.715 0.757 0.8 0.842 ...
# $ funcs :  num [1:9, 1:2500] 1.11 1.15 1.18 1.21 1.24 ...
#  - attr(*, "dimnames")=List of 2
#   ..$ : chr [1:9] "17" "18" "19" "20" ...
#   ..$ : chr [1:2500] "obs" "sim1" "sim2" "sim3" ...
#
# ------ Inner loop. delaunay_triangulation: 50
# A curve_set(1d) object with 2500 curves observed at 9 argument values
# (1 observed, 2499 simulated).
# Contains:
# $ r     :  num [1:9] 0.673 0.715 0.757 0.8 0.842 ...
# $ funcs :  num [1:9, 1:2500] 1.11 1.15 1.18 1.21 1.23 ...
#  - attr(*, "dimnames")=List of 2
#   ..$ : chr [1:9] "17" "18" "19" "20" ...
#   ..$ : chr [1:2500] "obs" "sim1" "sim2" "sim3" ...
#
# ------ Inner loop. delaunay_triangulation: 51
# A curve_set(1d) object with 2500 curves observed at 9 argument values
# (1 observed, 2499 simulated).
# Contains:
# $ r     :  num [1:9] 0.673 0.715 0.757 0.8 0.842 ...
# $ funcs :  num [1:9, 1:2500] 1.11 1.15 1.18 1.21 1.24 ...
#  - attr(*, "dimnames")=List of 2
#   ..$ : chr [1:9] "17" "18" "19" "20" ...
#   ..$ : chr [1:2500] "obs" "sim1" "sim2" "sim3" ...
#
# ------ Inner loop. delaunay_triangulation: 52
# A curve_set(1d) object with 2500 curves observed at 9 argument values
# (1 observed, 2499 simulated).
# Contains:
# $ r     :  num [1:9] 0.673 0.715 0.757 0.8 0.842 ...
# $ funcs :  num [1:9, 1:2500] 1.11 1.15 1.18 1.21 1.24 ...
#  - attr(*, "dimnames")=List of 2
#   ..$ : chr [1:9] "17" "18" "19" "20" ...
#   ..$ : chr [1:2500] "obs" "sim1" "sim2" "sim3" ...
#
# ------ Inner loop. delaunay_triangulation: 53
# A curve_set(1d) object with 2500 curves observed at 9 argument values
# (1 observed, 2499 simulated).
# Contains:
# $ r     :  num [1:9] 0.673 0.715 0.757 0.8 0.842 ...
# $ funcs :  num [1:9, 1:2500] 1.11 1.15 1.18 1.21 1.24 ...
#  - attr(*, "dimnames")=List of 2
#   ..$ : chr [1:9] "17" "18" "19" "20" ...
#   ..$ : chr [1:2500] "obs" "sim1" "sim2" "sim3" ...
#
# ------ Inner loop. delaunay_triangulation: 54
# A curve_set(1d) object with 2500 curves observed at 9 argument values
# (1 observed, 2499 simulated).
# Contains:
# $ r     :  num [1:9] 0.673 0.715 0.757 0.8 0.842 ...
# $ funcs :  num [1:9, 1:2500] 1.1 1.14 1.18 1.21 1.24 ...
#  - attr(*, "dimnames")=List of 2
#   ..$ : chr [1:9] "17" "18" "19" "20" ...
#   ..$ : chr [1:2500] "obs" "sim1" "sim2" "sim3" ...
#
# ------ Inner loop. delaunay_triangulation: 55
# A curve_set(1d) object with 2500 curves observed at 9 argument values
# (1 observed, 2499 simulated).
# Contains:
# $ r     :  num [1:9] 0.673 0.715 0.757 0.8 0.842 ...
# $ funcs :  num [1:9, 1:2500] 1.11 1.15 1.18 1.21 1.23 ...
#  - attr(*, "dimnames")=List of 2
#   ..$ : chr [1:9] "17" "18" "19" "20" ...
#   ..$ : chr [1:2500] "obs" "sim1" "sim2" "sim3" ...
#
# ------ Inner loop. delaunay_triangulation: 56
# A curve_set(1d) object with 2500 curves observed at 9 argument values
# (1 observed, 2499 simulated).
# Contains:
# $ r     :  num [1:9] 0.673 0.715 0.757 0.8 0.842 ...
# $ funcs :  num [1:9, 1:2500] 1.11 1.15 1.18 1.21 1.24 ...
#  - attr(*, "dimnames")=List of 2
#   ..$ : chr [1:9] "17" "18" "19" "20" ...
#   ..$ : chr [1:2500] "obs" "sim1" "sim2" "sim3" ...
#
# ------ Inner loop. delaunay_triangulation: 57
# A curve_set(1d) object with 2500 curves observed at 9 argument values
# (1 observed, 2499 simulated).
# Contains:
# $ r     :  num [1:9] 0.673 0.715 0.757 0.8 0.842 ...
# $ funcs :  num [1:9, 1:2500] 1.11 1.15 1.18 1.21 1.24 ...
#  - attr(*, "dimnames")=List of 2
#   ..$ : chr [1:9] "17" "18" "19" "20" ...
#   ..$ : chr [1:2500] "obs" "sim1" "sim2" "sim3" ...
#
# ------ Inner loop. delaunay_triangulation: 58
# A curve_set(1d) object with 2500 curves observed at 9 argument values
# (1 observed, 2499 simulated).
# Contains:
# $ r     :  num [1:9] 0.673 0.715 0.757 0.8 0.842 ...
# $ funcs :  num [1:9, 1:2500] 1.11 1.15 1.18 1.21 1.24 ...
#  - attr(*, "dimnames")=List of 2
#   ..$ : chr [1:9] "17" "18" "19" "20" ...
#   ..$ : chr [1:2500] "obs" "sim1" "sim2" "sim3" ...
#
# ------ Inner loop. delaunay_triangulation: 59
# A curve_set(1d) object with 2500 curves observed at 9 argument values
# (1 observed, 2499 simulated).
# Contains:
# $ r     :  num [1:9] 0.673 0.715 0.757 0.8 0.842 ...
# $ funcs :  num [1:9, 1:2500] 1.11 1.15 1.18 1.21 1.24 ...
#  - attr(*, "dimnames")=List of 2
#   ..$ : chr [1:9] "17" "18" "19" "20" ...
#   ..$ : chr [1:2500] "obs" "sim1" "sim2" "sim3" ...
#
# ------ Inner loop. delaunay_triangulation: 60
# A curve_set(1d) object with 2500 curves observed at 9 argument values
# (1 observed, 2499 simulated).
# Contains:
# $ r     :  num [1:9] 0.673 0.715 0.757 0.8 0.842 ...
# $ funcs :  num [1:9, 1:2500] 1.11 1.15 1.18 1.21 1.24 ...
#  - attr(*, "dimnames")=List of 2
#   ..$ : chr [1:9] "17" "18" "19" "20" ...
#   ..$ : chr [1:2500] "obs" "sim1" "sim2" "sim3" ...
#
# ------ Inner loop. delaunay_triangulation: 61
# A curve_set(1d) object with 2500 curves observed at 9 argument values
# (1 observed, 2499 simulated).
# Contains:
# $ r     :  num [1:9] 0.673 0.715 0.757 0.8 0.842 ...
# $ funcs :  num [1:9, 1:2500] 1.11 1.14 1.18 1.21 1.23 ...
#  - attr(*, "dimnames")=List of 2
#   ..$ : chr [1:9] "17" "18" "19" "20" ...
#   ..$ : chr [1:2500] "obs" "sim1" "sim2" "sim3" ...
#
# ------ Inner loop. delaunay_triangulation: 62
# A curve_set(1d) object with 2500 curves observed at 9 argument values
# (1 observed, 2499 simulated).
# Contains:
# $ r     :  num [1:9] 0.673 0.715 0.757 0.8 0.842 ...
# $ funcs :  num [1:9, 1:2500] 1.11 1.15 1.18 1.21 1.24 ...
#  - attr(*, "dimnames")=List of 2
#   ..$ : chr [1:9] "17" "18" "19" "20" ...
#   ..$ : chr [1:2500] "obs" "sim1" "sim2" "sim3" ...
#
# ------ Inner loop. delaunay_triangulation: 63
# A curve_set(1d) object with 2500 curves observed at 9 argument values
# (1 observed, 2499 simulated).
# Contains:
# $ r     :  num [1:9] 0.673 0.715 0.757 0.8 0.842 ...
# $ funcs :  num [1:9, 1:2500] 1.11 1.15 1.18 1.21 1.23 ...
#  - attr(*, "dimnames")=List of 2
#   ..$ : chr [1:9] "17" "18" "19" "20" ...
#   ..$ : chr [1:2500] "obs" "sim1" "sim2" "sim3" ...
#
# ------ Inner loop. delaunay_triangulation: 64
# A curve_set(1d) object with 2500 curves observed at 9 argument values
# (1 observed, 2499 simulated).
# Contains:
# $ r     :  num [1:9] 0.673 0.715 0.757 0.8 0.842 ...
# $ funcs :  num [1:9, 1:2500] 1.11 1.15 1.18 1.21 1.23 ...
#  - attr(*, "dimnames")=List of 2
#   ..$ : chr [1:9] "17" "18" "19" "20" ...
#   ..$ : chr [1:2500] "obs" "sim1" "sim2" "sim3" ...
#
# ------ Inner loop. delaunay_triangulation: 65
# A curve_set(1d) object with 2500 curves observed at 9 argument values
# (1 observed, 2499 simulated).
# Contains:
# $ r     :  num [1:9] 0.673 0.715 0.757 0.8 0.842 ...
# $ funcs :  num [1:9, 1:2500] 1.11 1.15 1.18 1.21 1.24 ...
#  - attr(*, "dimnames")=List of 2
#   ..$ : chr [1:9] "17" "18" "19" "20" ...
#   ..$ : chr [1:2500] "obs" "sim1" "sim2" "sim3" ...
#
# ------ Inner loop. delaunay_triangulation: 66
# A curve_set(1d) object with 2500 curves observed at 9 argument values
# (1 observed, 2499 simulated).
# Contains:
# $ r     :  num [1:9] 0.673 0.715 0.757 0.8 0.842 ...
# $ funcs :  num [1:9, 1:2500] 1.11 1.15 1.18 1.21 1.24 ...
#  - attr(*, "dimnames")=List of 2
#   ..$ : chr [1:9] "17" "18" "19" "20" ...
#   ..$ : chr [1:2500] "obs" "sim1" "sim2" "sim3" ...
#
# ------ Inner loop. delaunay_triangulation: 67
# A curve_set(1d) object with 2500 curves observed at 9 argument values
# (1 observed, 2499 simulated).
# Contains:
# $ r     :  num [1:9] 0.673 0.715 0.757 0.8 0.842 ...
# $ funcs :  num [1:9, 1:2500] 1.11 1.15 1.18 1.21 1.23 ...
#  - attr(*, "dimnames")=List of 2
#   ..$ : chr [1:9] "17" "18" "19" "20" ...
#   ..$ : chr [1:2500] "obs" "sim1" "sim2" "sim3" ...
#
# ------ Inner loop. delaunay_triangulation: 68
# A curve_set(1d) object with 2500 curves observed at 9 argument values
# (1 observed, 2499 simulated).
# Contains:
# $ r     :  num [1:9] 0.673 0.715 0.757 0.8 0.842 ...
# $ funcs :  num [1:9, 1:2500] 1.11 1.15 1.18 1.21 1.23 ...
#  - attr(*, "dimnames")=List of 2
#   ..$ : chr [1:9] "17" "18" "19" "20" ...
#   ..$ : chr [1:2500] "obs" "sim1" "sim2" "sim3" ...
#
# ------ Inner loop. delaunay_triangulation: 69
# A curve_set(1d) object with 2500 curves observed at 9 argument values
# (1 observed, 2499 simulated).
# Contains:
# $ r     :  num [1:9] 0.673 0.715 0.757 0.8 0.842 ...
# $ funcs :  num [1:9, 1:2500] 1.11 1.15 1.18 1.21 1.23 ...
#  - attr(*, "dimnames")=List of 2
#   ..$ : chr [1:9] "17" "18" "19" "20" ...
#   ..$ : chr [1:2500] "obs" "sim1" "sim2" "sim3" ...
#
# ------ Inner loop. delaunay_triangulation: 70
# A curve_set(1d) object with 2500 curves observed at 9 argument values
# (1 observed, 2499 simulated).
# Contains:
# $ r     :  num [1:9] 0.673 0.715 0.757 0.8 0.842 ...
# $ funcs :  num [1:9, 1:2500] 1.1 1.14 1.18 1.2 1.23 ...
#  - attr(*, "dimnames")=List of 2
#   ..$ : chr [1:9] "17" "18" "19" "20" ...
#   ..$ : chr [1:2500] "obs" "sim1" "sim2" "sim3" ...
#
# ------ Inner loop. delaunay_triangulation: 71
# A curve_set(1d) object with 2500 curves observed at 9 argument values
# (1 observed, 2499 simulated).
# Contains:
# $ r     :  num [1:9] 0.673 0.715 0.757 0.8 0.842 ...
# $ funcs :  num [1:9, 1:2500] 1.11 1.14 1.18 1.2 1.23 ...
#  - attr(*, "dimnames")=List of 2
#   ..$ : chr [1:9] "17" "18" "19" "20" ...
#   ..$ : chr [1:2500] "obs" "sim1" "sim2" "sim3" ...
#
# ------ Inner loop. delaunay_triangulation: 72
# A curve_set(1d) object with 2500 curves observed at 9 argument values
# (1 observed, 2499 simulated).
# Contains:
# $ r     :  num [1:9] 0.673 0.715 0.757 0.8 0.842 ...
# $ funcs :  num [1:9, 1:2500] 1.11 1.14 1.18 1.21 1.23 ...
#  - attr(*, "dimnames")=List of 2
#   ..$ : chr [1:9] "17" "18" "19" "20" ...
#   ..$ : chr [1:2500] "obs" "sim1" "sim2" "sim3" ...
#
# ------ Inner loop. delaunay_triangulation: 73
# A curve_set(1d) object with 2500 curves observed at 9 argument values
# (1 observed, 2499 simulated).
# Contains:
# $ r     :  num [1:9] 0.673 0.715 0.757 0.8 0.842 ...
# $ funcs :  num [1:9, 1:2500] 1.12 1.15 1.18 1.21 1.24 ...
#  - attr(*, "dimnames")=List of 2
#   ..$ : chr [1:9] "17" "18" "19" "20" ...
#   ..$ : chr [1:2500] "obs" "sim1" "sim2" "sim3" ...
#
# ------ Inner loop. delaunay_triangulation: 74
# A curve_set(1d) object with 2500 curves observed at 9 argument values
# (1 observed, 2499 simulated).
# Contains:
# $ r     :  num [1:9] 0.673 0.715 0.757 0.8 0.842 ...
# $ funcs :  num [1:9, 1:2500] 1.11 1.15 1.18 1.21 1.23 ...
#  - attr(*, "dimnames")=List of 2
#   ..$ : chr [1:9] "17" "18" "19" "20" ...
#   ..$ : chr [1:2500] "obs" "sim1" "sim2" "sim3" ...
#
# ------ Inner loop. delaunay_triangulation: 75
# A curve_set(1d) object with 2500 curves observed at 9 argument values
# (1 observed, 2499 simulated).
# Contains:
# $ r     :  num [1:9] 0.673 0.715 0.757 0.8 0.842 ...
# $ funcs :  num [1:9, 1:2500] 1.11 1.15 1.18 1.21 1.24 ...
#  - attr(*, "dimnames")=List of 2
#   ..$ : chr [1:9] "17" "18" "19" "20" ...
#   ..$ : chr [1:2500] "obs" "sim1" "sim2" "sim3" ...
#
# ------ Inner loop. delaunay_triangulation: 76
# A curve_set(1d) object with 2500 curves observed at 9 argument values
# (1 observed, 2499 simulated).
# Contains:
# $ r     :  num [1:9] 0.673 0.715 0.757 0.8 0.842 ...
# $ funcs :  num [1:9, 1:2500] 1.11 1.15 1.18 1.21 1.23 ...
#  - attr(*, "dimnames")=List of 2
#   ..$ : chr [1:9] "17" "18" "19" "20" ...
#   ..$ : chr [1:2500] "obs" "sim1" "sim2" "sim3" ...
#
# ------ Inner loop. delaunay_triangulation: 77
# A curve_set(1d) object with 2500 curves observed at 9 argument values
# (1 observed, 2499 simulated).
# Contains:
# $ r     :  num [1:9] 0.673 0.715 0.757 0.8 0.842 ...
# $ funcs :  num [1:9, 1:2500] 1.11 1.15 1.18 1.21 1.24 ...
#  - attr(*, "dimnames")=List of 2
#   ..$ : chr [1:9] "17" "18" "19" "20" ...
#   ..$ : chr [1:2500] "obs" "sim1" "sim2" "sim3" ...
#
# ------ Inner loop. delaunay_triangulation: 78
# A curve_set(1d) object with 2500 curves observed at 9 argument values
# (1 observed, 2499 simulated).
# Contains:
# $ r     :  num [1:9] 0.673 0.715 0.757 0.8 0.842 ...
# $ funcs :  num [1:9, 1:2500] 1.11 1.14 1.18 1.21 1.23 ...
#  - attr(*, "dimnames")=List of 2
#   ..$ : chr [1:9] "17" "18" "19" "20" ...
#   ..$ : chr [1:2500] "obs" "sim1" "sim2" "sim3" ...
#
# ------ Inner loop. delaunay_triangulation: 79
# A curve_set(1d) object with 2500 curves observed at 9 argument values
# (1 observed, 2499 simulated).
# Contains:
# $ r     :  num [1:9] 0.673 0.715 0.757 0.8 0.842 ...
# $ funcs :  num [1:9, 1:2500] 1.11 1.15 1.18 1.21 1.24 ...
#  - attr(*, "dimnames")=List of 2
#   ..$ : chr [1:9] "17" "18" "19" "20" ...
#   ..$ : chr [1:2500] "obs" "sim1" "sim2" "sim3" ...
#
# ------ Inner loop. delaunay_triangulation: 80
# A curve_set(1d) object with 2500 curves observed at 9 argument values
# (1 observed, 2499 simulated).
# Contains:
# $ r     :  num [1:9] 0.673 0.715 0.757 0.8 0.842 ...
# $ funcs :  num [1:9, 1:2500] 1.11 1.15 1.18 1.21 1.24 ...
#  - attr(*, "dimnames")=List of 2
#   ..$ : chr [1:9] "17" "18" "19" "20" ...
#   ..$ : chr [1:2500] "obs" "sim1" "sim2" "sim3" ...
#
# ------ Inner loop. delaunay_triangulation: 81
# A curve_set(1d) object with 2500 curves observed at 9 argument values
# (1 observed, 2499 simulated).
# Contains:
# $ r     :  num [1:9] 0.673 0.715 0.757 0.8 0.842 ...
# $ funcs :  num [1:9, 1:2500] 1.1 1.14 1.17 1.2 1.23 ...
#  - attr(*, "dimnames")=List of 2
#   ..$ : chr [1:9] "17" "18" "19" "20" ...
#   ..$ : chr [1:2500] "obs" "sim1" "sim2" "sim3" ...
#
# ------ Inner loop. delaunay_triangulation: 82
# A curve_set(1d) object with 2500 curves observed at 9 argument values
# (1 observed, 2499 simulated).
# Contains:
# $ r     :  num [1:9] 0.673 0.715 0.757 0.8 0.842 ...
# $ funcs :  num [1:9, 1:2500] 1.11 1.15 1.18 1.22 1.24 ...
#  - attr(*, "dimnames")=List of 2
#   ..$ : chr [1:9] "17" "18" "19" "20" ...
#   ..$ : chr [1:2500] "obs" "sim1" "sim2" "sim3" ...
#
# ------ Inner loop. delaunay_triangulation: 83
# A curve_set(1d) object with 2500 curves observed at 9 argument values
# (1 observed, 2499 simulated).
# Contains:
# $ r     :  num [1:9] 0.673 0.715 0.757 0.8 0.842 ...
# $ funcs :  num [1:9, 1:2500] 1.11 1.15 1.18 1.21 1.24 ...
#  - attr(*, "dimnames")=List of 2
#   ..$ : chr [1:9] "17" "18" "19" "20" ...
#   ..$ : chr [1:2500] "obs" "sim1" "sim2" "sim3" ...
#
# ------ Inner loop. delaunay_triangulation: 84
# A curve_set(1d) object with 2500 curves observed at 9 argument values
# (1 observed, 2499 simulated).
# Contains:
# $ r     :  num [1:9] 0.673 0.715 0.757 0.8 0.842 ...
# $ funcs :  num [1:9, 1:2500] 1.11 1.15 1.18 1.21 1.24 ...
#  - attr(*, "dimnames")=List of 2
#   ..$ : chr [1:9] "17" "18" "19" "20" ...
#   ..$ : chr [1:2500] "obs" "sim1" "sim2" "sim3" ...
#
# ------ Inner loop. delaunay_triangulation: 85
# A curve_set(1d) object with 2500 curves observed at 9 argument values
# (1 observed, 2499 simulated).
# Contains:
# $ r     :  num [1:9] 0.673 0.715 0.757 0.8 0.842 ...
# $ funcs :  num [1:9, 1:2500] 1.11 1.14 1.18 1.2 1.23 ...
#  - attr(*, "dimnames")=List of 2
#   ..$ : chr [1:9] "17" "18" "19" "20" ...
#   ..$ : chr [1:2500] "obs" "sim1" "sim2" "sim3" ...
#
# ------ Inner loop. delaunay_triangulation: 86
# A curve_set(1d) object with 2500 curves observed at 9 argument values
# (1 observed, 2499 simulated).
# Contains:
# $ r     :  num [1:9] 0.673 0.715 0.757 0.8 0.842 ...
# $ funcs :  num [1:9, 1:2500] 1.11 1.15 1.19 1.21 1.24 ...
#  - attr(*, "dimnames")=List of 2
#   ..$ : chr [1:9] "17" "18" "19" "20" ...
#   ..$ : chr [1:2500] "obs" "sim1" "sim2" "sim3" ...
#
# ------ Inner loop. delaunay_triangulation: 87
# A curve_set(1d) object with 2500 curves observed at 9 argument values
# (1 observed, 2499 simulated).
# Contains:
# $ r     :  num [1:9] 0.673 0.715 0.757 0.8 0.842 ...
# $ funcs :  num [1:9, 1:2500] 1.11 1.14 1.18 1.21 1.24 ...
#  - attr(*, "dimnames")=List of 2
#   ..$ : chr [1:9] "17" "18" "19" "20" ...
#   ..$ : chr [1:2500] "obs" "sim1" "sim2" "sim3" ...
#
# ------ Inner loop. delaunay_triangulation: 88
# A curve_set(1d) object with 2500 curves observed at 9 argument values
# (1 observed, 2499 simulated).
# Contains:
# $ r     :  num [1:9] 0.673 0.715 0.757 0.8 0.842 ...
# $ funcs :  num [1:9, 1:2500] 1.12 1.15 1.19 1.22 1.25 ...
#  - attr(*, "dimnames")=List of 2
#   ..$ : chr [1:9] "17" "18" "19" "20" ...
#   ..$ : chr [1:2500] "obs" "sim1" "sim2" "sim3" ...
#
# ------ Inner loop. delaunay_triangulation: 89
# ...
#
# Computing histogram...
# ------ Inner loop. sz_classification: 16
#         2048
#
# Computing histogram...
# ------ Inner loop. sz_classification: 17
#         2048
#
# Computing histogram...
# ------ Inner loop. sz_classification: 18
#         2048
#
# Computing histogram...
# ------ Inner loop. sz_classification: 19
#         2048
#
# Computing histogram...
# ------ Inner loop. sz_classification: 20
#         2048
#
# Computing histogram...
# ------ Inner loop. sz_classification: 21
#         2048
#
# Computing histogram...
# ------ Inner loop. sz_classification: 22
#         2048
#
# Computing histogram...
# ------ Inner loop. sz_classification: 23
#         2048
#
# Computing histogram...
# ------ Inner loop. sz_classification: 24
#         2048
#
# Computing histogram...
# ------ Inner loop. sz_classification: 25
#         2048
#
# Computing histogram...
# ------ Inner loop. sz_classification: 26
#         2048
#
# Computing histogram...
# ------ Inner loop. sz_classification: 27
#         2048
#
# Computing histogram...
# ------ Inner loop. sz_classification: 28
#         2048
#
# Computing histogram...
# ------ Inner loop. sz_classification: 29
#         2048
#
# Computing histogram...
# ------ Inner loop. sz_classification: 30
#         2048
#
# Computing histogram...
# ------ Inner loop. sz_classification: 31
#         2048
#
# Computing histogram...
# ------ Inner loop. sz_classification: 32
#         2048
#
# Computing histogram...
# ------ Inner loop. sz_classification: 33
#         2048
#
# Computing histogram...
# ------ Inner loop. sz_classification: 34
#         2048
#
# Computing histogram...
# ------ Inner loop. sz_classification: 35
#         2048
#
# Computing histogram...
# ------ Inner loop. sz_classification: 36
#         2048
#
# Computing histogram...
# ------ Inner loop. sz_classification: 37
#         2048
#
# Computing histogram...
# ------ Inner loop. sz_classification: 38
#         2048
#
# Computing histogram...
# ------ Inner loop. sz_classification: 39
#         2048
#
# Computing histogram...
# ------ Inner loop. sz_classification: 40
#         2048
#
# Computing histogram...
# ------ Inner loop. sz_classification: 41
#         2048
#
# Computing histogram...
# ------ Inner loop. sz_classification: 42
#         2048
#
# Computing histogram...
# ------ Inner loop. sz_classification: 43
#         2048
#
# Computing histogram...
# ------ Inner loop. sz_classification: 44
#         2048
#
# Computing histogram...
# ------ Inner loop. sz_classification: 45
#         2048
#
# Computing histogram...
# ------ Inner loop. sz_classification: 46
#         2048
#
# Computing histogram...
# ------ Inner loop. sz_classification: 47
#         2048
#
# Computing histogram...
# ------ Inner loop. sz_classification: 48
#         2048
#
# Computing histogram...
# ------ Inner loop. sz_classification: 49
#         2048
#
# Computing histogram...
# ------ Inner loop. sz_classification: 50
#         2048
#
# Computing histogram...
# ------ Inner loop. sz_classification: 51
#         2048
#
# Computing histogram...
# ------ Inner loop. sz_classification: 52
#         2048
#
# Computing histogram...
# ------ Inner loop. sz_classification: 53
#         2048
#
# Computing histogram...
# ------ Inner loop. sz_classification: 54
#         2048
#
# Computing histogram...
# ------ Inner loop. sz_classification: 55
#         2048
#
# Computing histogram...
# ------ Inner loop. sz_classification: 56
#         2048
#
# Computing histogram...
# ------ Inner loop. sz_classification: 57
#         2048
#
# Computing histogram...
# ------ Inner loop. sz_classification: 58
#         2048
#
# Computing histogram...
# ------ Inner loop. sz_classification: 59
#         2048
#
# Computing histogram...
# ------ Inner loop. sz_classification: 60
#         2048
#
# Computing histogram...
# ------ Inner loop. sz_classification: 61
#         2048
#
# Computing histogram...
# ------ Inner loop. sz_classification: 62
#         2048
#
# Computing histogram...
# ------ Inner loop. sz_classification: 63
#         2048
#
# Computing histogram...
# ------ Inner loop. sz_classification: 64
#         2048
#
# Computing histogram...
# ------ Inner loop. sz_classification: 65
#         2048
#
# Computing histogram...
# ------ Inner loop. sz_classification: 66
#         2048
#
# Computing histogram...
# ------ Inner loop. sz_classification: 67
#         2048
#
# Computing histogram...
# ------ Inner loop. sz_classification: 68
#         2048
#
# Computing histogram...
# ------ Inner loop. sz_classification: 69
#         2048
#
# Computing histogram...
# ------ Inner loop. sz_classification: 70
#         2048
#
# Computing histogram...
# ------ Inner loop. sz_classification: 71
#         2048
#
# Computing histogram...
# ------ Inner loop. sz_classification: 72
#         2048
#
# Computing histogram...
# ------ Inner loop. sz_classification: 73
#         2048
#
# Computing histogram...
# ------ Inner loop. sz_classification: 74
#         2048
#
# Computing histogram...
# ------ Inner loop. sz_classification: 75
#         2048
#
# Computing histogram...
# ------ Inner loop. sz_classification: 76
#         2048
#
# Computing histogram...
# ------ Inner loop. sz_classification: 77
#         2048
#
# Computing histogram...
# ------ Inner loop. sz_classification: 78
#         2048
#
# Computing histogram...
# ------ Inner loop. sz_classification: 79
#         2048
#
# Computing histogram...
# ------ Inner loop. sz_classification: 80
#         2048
#
# Computing histogram...
# ------ Inner loop. sz_classification: 81
#         2048
#
# Computing histogram...
# ------ Inner loop. sz_classification: 82
#         2048
#
# Computing histogram...
# ------ Inner loop. sz_classification: 83
#         2048
#
# Computing histogram...
# ------ Inner loop. sz_classification: 84
#         2048
#
# Computing histogram...
# ------ Inner loop. sz_classification: 85
#         2048
#
# Computing histogram...
# ------ Inner loop. sz_classification: 86
#         2048
#
# Computing histogram...
# ------ Inner loop. sz_classification: 87
#         2048
#
# Computing histogram...
# ------ Inner loop. sz_classification: 88
#         2048
#
# Computing histogram...
# ------ Inner loop. sz_classification: 89
#         2048
#
# Computing histogram...
# ------ Inner loop. sz_classification: 90
#         2048
#
# Computing histogram...
# ------ Inner loop. sz_classification: 91
#         2048
#
# Computing histogram...
# ------ Inner loop. sz_classification: 92
#         2048
#
# Computing histogram...
# ------ Inner loop. sz_classification: 93
#         2048
#
# Computing histogram...
# ------ Inner loop. sz_classification: 94
#         2048
#
# Computing histogram...
# ------ Inner loop. sz_classification: 95
#         2048
#
# Computing histogram...
# ------ Inner loop. sz_classification: 96
#         2048
#
# Computing histogram...
# ------ Inner loop. sz_classification: 97
#         2048
#
# Computing histogram...
# ------ Inner loop. sz_classification: 98
#         2048
#
# Computing histogram...
# ------ Inner loop. sz_classification: 99
#         2048
#
# Computing histogram...
# Elapsed:20.01311926841736
# --- Method: thresholding_garrote
# ---- Parameters Combination: 0
# ------ Inner loop. thresholding_garrote: 0
# ------ Inner loop. thresholding_garrote: 1
# ------ Inner loop. thresholding_garrote: 2
# ------ Inner loop. thresholding_garrote: 3
# ------ Inner loop. thresholding_garrote: 4
# ------ Inner loop. thresholding_garrote: 5
# ------ Inner loop. thresholding_garrote: 6
# ------ Inner loop. thresholding_garrote: 7
# ------ Inner loop. thresholding_garrote: 8
# ------ Inner loop. thresholding_garrote: 9
# ------ Inner loop. thresholding_garrote: 10
# ------ Inner loop. thresholding_garrote: 11
# ------ Inner loop. thresholding_garrote: 12
# ------ Inner loop. thresholding_garrote: 13
# ------ Inner loop. thresholding_garrote: 14
# ------ Inner loop. thresholding_garrote: 15
# ------ Inner loop. thresholding_garrote: 16
# ------ Inner loop. thresholding_garrote: 17
# ------ Inner loop. thresholding_garrote: 18
# ------ Inner loop. thresholding_garrote: 19
# ------ Inner loop. thresholding_garrote: 20
# ------ Inner loop. thresholding_garrote: 21
# ------ Inner loop. thresholding_garrote: 22
# ------ Inner loop. thresholding_garrote: 23
# ------ Inner loop. thresholding_garrote: 24
# ------ Inner loop. thresholding_garrote: 25
# ------ Inner loop. thresholding_garrote: 26
# ------ Inner loop. thresholding_garrote: 27
# ------ Inner loop. thresholding_garrote: 28
# ------ Inner loop. thresholding_garrote: 29
# ------ Inner loop. thresholding_garrote: 30
# ------ Inner loop. thresholding_garrote: 31
# ------ Inner loop. thresholding_garrote: 32
# ------ Inner loop. thresholding_garrote: 33
# ------ Inner loop. thresholding_garrote: 34
# ------ Inner loop. thresholding_garrote: 35
# ------ Inner loop. thresholding_garrote: 36
# ------ Inner loop. thresholding_garrote: 37
# ------ Inner loop. thresholding_garrote: 38
# ------ Inner loop. thresholding_garrote: 39
# ------ Inner loop. thresholding_garrote: 40
# ------ Inner loop. thresholding_garrote: 41
# ------ Inner loop. thresholding_garrote: 42
# ------ Inner loop. thresholding_garrote: 43
# ------ Inner loop. thresholding_garrote: 44
# ------ Inner loop. thresholding_garrote: 45
# ------ Inner loop. thresholding_garrote: 46
# ------ Inner loop. thresholding_garrote: 47
# ------ Inner loop. thresholding_garrote: 48
# ------ Inner loop. thresholding_garrote: 49
# ------ Inner loop. thresholding_garrote: 50
# ------ Inner loop. thresholding_garrote: 51
# ------ Inner loop. thresholding_garrote: 52
# ------ Inner loop. thresholding_garrote: 53
# ------ Inner loop. thresholding_garrote: 54
# ------ Inner loop. thresholding_garrote: 55
# ------ Inner loop. thresholding_garrote: 56
# ------ Inner loop. thresholding_garrote: 57
# ------ Inner loop. thresholding_garrote: 58
# ------ Inner loop. thresholding_garrote: 59
# ------ Inner loop. thresholding_garrote: 60
# ------ Inner loop. thresholding_garrote: 61
# ------ Inner loop. thresholding_garrote: 62
# ------ Inner loop. thresholding_garrote: 63
# ------ Inner loop. thresholding_garrote: 64
# ------ Inner loop. thresholding_garrote: 65
# ------ Inner loop. thresholding_garrote: 66
# ------ Inner loop. thresholding_garrote: 67
# ------ Inner loop. thresholding_garrote: 68
# ------ Inner loop. thresholding_garrote: 69
# ------ Inner loop. thresholding_garrote: 70
# ------ Inner loop. thresholding_garrote: 71
# ------ Inner loop. thresholding_garrote: 72
# ------ Inner loop. thresholding_garrote: 73
# ------ Inner loop. thresholding_garrote: 74
# ------ Inner loop. thresholding_garrote: 75
# ------ Inner loop. thresholding_garrote: 76
# ------ Inner loop. thresholding_garrote: 77
# ------ Inner loop. thresholding_garrote: 78
# ------ Inner loop. thresholding_garrote: 79
# ------ Inner loop. thresholding_garrote: 80
# ------ Inner loop. thresholding_garrote: 81
# ------ Inner loop. thresholding_garrote: 82
# ------ Inner loop. thresholding_garrote: 83
# ------ Inner loop. thresholding_garrote: 84
# ------ Inner loop. thresholding_garrote: 85
# ------ Inner loop. thresholding_garrote: 86
# ------ Inner loop. thresholding_garrote: 87
# ------ Inner loop. thresholding_garrote: 88
# ------ Inner loop. thresholding_garrote: 89
# ------ Inner loop. thresholding_garrote: 90
# ------ Inner loop. thresholding_garrote: 91
# ------ Inner loop. thresholding_garrote: 92
# ------ Inner loop. thresholding_garrote: 93
# ------ Inner loop. thresholding_garrote: 94
# ------ Inner loop. thresholding_garrote: 95
# ------ Inner loop. thresholding_garrote: 96
# ------ Inner loop. thresholding_garrote: 97
# ------ Inner loop. thresholding_garrote: 98
# ------ Inner loop. thresholding_garrote: 99
# Elapsed:0.43715241432189944
# --- Method: thresholding_hard
# ---- Parameters Combination: 0
# ------ Inner loop. thresholding_hard: 0
# ------ Inner loop. thresholding_hard: 1
# ------ Inner loop. thresholding_hard: 2
# ------ Inner loop. thresholding_hard: 3
# ------ Inner loop. thresholding_hard: 4
# ------ Inner loop. thresholding_hard: 5
# ------ Inner loop. thresholding_hard: 6
# ------ Inner loop. thresholding_hard: 7
# ------ Inner loop. thresholding_hard: 8
# ------ Inner loop. thresholding_hard: 9
# ------ Inner loop. thresholding_hard: 10
# ------ Inner loop. thresholding_hard: 11
# ------ Inner loop. thresholding_hard: 12
# ------ Inner loop. thresholding_hard: 13
# ------ Inner loop. thresholding_hard: 14
# ------ Inner loop. thresholding_hard: 15
# ------ Inner loop. thresholding_hard: 16
# ------ Inner loop. thresholding_hard: 17
# ------ Inner loop. thresholding_hard: 18
# ------ Inner loop. thresholding_hard: 19
# ------ Inner loop. thresholding_hard: 20
# ------ Inner loop. thresholding_hard: 21
# ------ Inner loop. thresholding_hard: 22
# ------ Inner loop. thresholding_hard: 23
# ------ Inner loop. thresholding_hard: 24
# ------ Inner loop. thresholding_hard: 25
# ------ Inner loop. thresholding_hard: 26
# ------ Inner loop. thresholding_hard: 27
# ------ Inner loop. thresholding_hard: 28
# ------ Inner loop. thresholding_hard: 29
# ------ Inner loop. thresholding_hard: 30
# ------ Inner loop. thresholding_hard: 31
# ------ Inner loop. thresholding_hard: 32
# ------ Inner loop. thresholding_hard: 33
# ------ Inner loop. thresholding_hard: 34
# ------ Inner loop. thresholding_hard: 35
# ------ Inner loop. thresholding_hard: 36
# ------ Inner loop. thresholding_hard: 37
# ------ Inner loop. thresholding_hard: 38
# ------ Inner loop. thresholding_hard: 39
# ------ Inner loop. thresholding_hard: 40
# ------ Inner loop. thresholding_hard: 41
# ------ Inner loop. thresholding_hard: 42
# ------ Inner loop. thresholding_hard: 43
# ------ Inner loop. thresholding_hard: 44
# ------ Inner loop. thresholding_hard: 45
# ------ Inner loop. thresholding_hard: 46
# ------ Inner loop. thresholding_hard: 47
# ------ Inner loop. thresholding_hard: 48
# ------ Inner loop. thresholding_hard: 49
# ------ Inner loop. thresholding_hard: 50
# ------ Inner loop. thresholding_hard: 51
# ------ Inner loop. thresholding_hard: 52
# ------ Inner loop. thresholding_hard: 53
# ------ Inner loop. thresholding_hard: 54
# ------ Inner loop. thresholding_hard: 55
# ------ Inner loop. thresholding_hard: 56
# ------ Inner loop. thresholding_hard: 57
# ------ Inner loop. thresholding_hard: 58
# ------ Inner loop. thresholding_hard: 59
# ------ Inner loop. thresholding_hard: 60
# ------ Inner loop. thresholding_hard: 61
# ------ Inner loop. thresholding_hard: 62
# ------ Inner loop. thresholding_hard: 63
# ------ Inner loop. thresholding_hard: 64
# ------ Inner loop. thresholding_hard: 65
# ------ Inner loop. thresholding_hard: 66
# ------ Inner loop. thresholding_hard: 67
# ------ Inner loop. thresholding_hard: 68
# ------ Inner loop. thresholding_hard: 69
# ------ Inner loop. thresholding_hard: 70
# ------ Inner loop. thresholding_hard: 71
# ------ Inner loop. thresholding_hard: 72
# ------ Inner loop. thresholding_hard: 73
# ------ Inner loop. thresholding_hard: 74
# ------ Inner loop. thresholding_hard: 75
# ------ Inner loop. thresholding_hard: 76
# ------ Inner loop. thresholding_hard: 77
# ------ Inner loop. thresholding_hard: 78
# ------ Inner loop. thresholding_hard: 79
# ------ Inner loop. thresholding_hard: 80
# ------ Inner loop. thresholding_hard: 81
# ------ Inner loop. thresholding_hard: 82
# ------ Inner loop. thresholding_hard: 83
# ------ Inner loop. thresholding_hard: 84
# ------ Inner loop. thresholding_hard: 85
# ------ Inner loop. thresholding_hard: 86
# ------ Inner loop. thresholding_hard: 87
# ------ Inner loop. thresholding_hard: 88
# ------ Inner loop. thresholding_hard: 89
# ------ Inner loop. thresholding_hard: 90
# ------ Inner loop. thresholding_hard: 91
# ------ Inner loop. thresholding_hard: 92
# ------ Inner loop. thresholding_hard: 93
# ------ Inner loop. thresholding_hard: 94
# ------ Inner loop. thresholding_hard: 95
# ------ Inner loop. thresholding_hard: 96
# ------ Inner loop. thresholding_hard: 97
# ------ Inner loop. thresholding_hard: 98
# ------ Inner loop. thresholding_hard: 99
# Elapsed:0.42404101371765135
# The test has finished.
#                                                  Mean       Std
# brevdo_method-([], {})                       0.868370  0.005840
# contour_filtering-([], {})                  25.645484  0.085499
# delaunay_triangulation-{'LB': 1.6}           1.180566  0.039422
# delaunay_triangulation-{'adapt_thr': True}  11.425149  0.104824
# empty_space-{'adapt_thr': True}             23.060426  3.200152
# empty_space-{'radi_seg': 0.8}               10.478273  0.173951
# pseudo_bayesian_method-([], {})              3.618881  1.046851
# sz_classification-([], {})                  20.013119  2.582433
# thresholding_garrote-([], {})                0.437152  0.013215
# thresholding_hard-([], {})                   0.424041  0.009440

# %%
benchmark = Benchmark(task = 'denoising',
                        methods = my_methods,
                        parameters= my_parameters,
                        N = 2**9,
                        SNRin = [20,], 
                        repetitions = 100,
                        signal_ids=[ 'McMultiLinear',],
                        verbosity=5, 
                        parallelize=False)
                        
benchmark.run_test() # Run the test. my_results is a dictionary with the results for each of the variables of the simulation.
interpreter = ResultsInterpreter(benchmark)
df = interpreter.elapsed_time_summary()
df
# Out:
# Running benchmark...
# - Signal McMultiLinear
# -- SNR: 20 dB
# --- Method: brevdo_method
# ---- Parameters Combination: 0
# ------ Inner loop. brevdo_method: 0
# ------ Inner loop. brevdo_method: 1
# ------ Inner loop. brevdo_method: 2
# ------ Inner loop. brevdo_method: 3
# ------ Inner loop. brevdo_method: 4
# ------ Inner loop. brevdo_method: 5
# ------ Inner loop. brevdo_method: 6
# ------ Inner loop. brevdo_method: 7
# ------ Inner loop. brevdo_method: 8
# ------ Inner loop. brevdo_method: 9
# ------ Inner loop. brevdo_method: 10
# ------ Inner loop. brevdo_method: 11
# ------ Inner loop. brevdo_method: 12
# ------ Inner loop. brevdo_method: 13
# ------ Inner loop. brevdo_method: 14
# ------ Inner loop. brevdo_method: 15
# ------ Inner loop. brevdo_method: 16
# ------ Inner loop. brevdo_method: 17
# ------ Inner loop. brevdo_method: 18
# ------ Inner loop. brevdo_method: 19
# ------ Inner loop. brevdo_method: 20
# ------ Inner loop. brevdo_method: 21
# ------ Inner loop. brevdo_method: 22
# ------ Inner loop. brevdo_method: 23
# ------ Inner loop. brevdo_method: 24
# ------ Inner loop. brevdo_method: 25
# ------ Inner loop. brevdo_method: 26
# ------ Inner loop. brevdo_method: 27
# ------ Inner loop. brevdo_method: 28
# ------ Inner loop. brevdo_method: 29
# ------ Inner loop. brevdo_method: 30
# ------ Inner loop. brevdo_method: 31
# ------ Inner loop. brevdo_method: 32
# ------ Inner loop. brevdo_method: 33
# ------ Inner loop. brevdo_method: 34
# ------ Inner loop. brevdo_method: 35
# ------ Inner loop. brevdo_method: 36
# ------ Inner loop. brevdo_method: 37
# ------ Inner loop. brevdo_method: 38
# ------ Inner loop. brevdo_method: 39
# ------ Inner loop. brevdo_method: 40
# ------ Inner loop. brevdo_method: 41
# ------ Inner loop. brevdo_method: 42
# ------ Inner loop. brevdo_method: 43
# ------ Inner loop. brevdo_method: 44
# ------ Inner loop. brevdo_method: 45
# ------ Inner loop. brevdo_method: 46
# ------ Inner loop. brevdo_method: 47
# ------ Inner loop. brevdo_method: 48
# ------ Inner loop. brevdo_method: 49
# ------ Inner loop. brevdo_method: 50
# ------ Inner loop. brevdo_method: 51
# ------ Inner loop. brevdo_method: 52
# ------ Inner loop. brevdo_method: 53
# ------ Inner loop. brevdo_method: 54
# ------ Inner loop. brevdo_method: 55
# ------ Inner loop. brevdo_method: 56
# ------ Inner loop. brevdo_method: 57
# ------ Inner loop. brevdo_method: 58
# ------ Inner loop. brevdo_method: 59
# ------ Inner loop. brevdo_method: 60
# ------ Inner loop. brevdo_method: 61
# ------ Inner loop. brevdo_method: 62
# ------ Inner loop. brevdo_method: 63
# ------ Inner loop. brevdo_method: 64
# ------ Inner loop. brevdo_method: 65
# ------ Inner loop. brevdo_method: 66
# ------ Inner loop. brevdo_method: 67
# ------ Inner loop. brevdo_method: 68
# ------ Inner loop. brevdo_method: 69
# ------ Inner loop. brevdo_method: 70
# ------ Inner loop. brevdo_method: 71
# ------ Inner loop. brevdo_method: 72
# ------ Inner loop. brevdo_method: 73
# ------ Inner loop. brevdo_method: 74
# ------ Inner loop. brevdo_method: 75
# ------ Inner loop. brevdo_method: 76
# ------ Inner loop. brevdo_method: 77
# ------ Inner loop. brevdo_method: 78
# ------ Inner loop. brevdo_method: 79
# ------ Inner loop. brevdo_method: 80
# ------ Inner loop. brevdo_method: 81
# ------ Inner loop. brevdo_method: 82
# ------ Inner loop. brevdo_method: 83
# ------ Inner loop. brevdo_method: 84
# ------ Inner loop. brevdo_method: 85
# ------ Inner loop. brevdo_method: 86
# ------ Inner loop. brevdo_method: 87
# ------ Inner loop. brevdo_method: 88
# ------ Inner loop. brevdo_method: 89
# ------ Inner loop. brevdo_method: 90
# ------ Inner loop. brevdo_method: 91
# ------ Inner loop. brevdo_method: 92
# ------ Inner loop. brevdo_method: 93
# ------ Inner loop. brevdo_method: 94
# ------ Inner loop. brevdo_method: 95
# ------ Inner loop. brevdo_method: 96
# ------ Inner loop. brevdo_method: 97
# ------ Inner loop. brevdo_method: 98
# ------ Inner loop. brevdo_method: 99
# Elapsed:0.20218607902526856
# --- Method: contour_filtering
# ---- Parameters Combination: 0
# ------ Inner loop. contour_filtering: 0
# ------ Inner loop. contour_filtering: 1
# ------ Inner loop. contour_filtering: 2
# ------ Inner loop. contour_filtering: 3
# ------ Inner loop. contour_filtering: 4
# ------ Inner loop. contour_filtering: 5
# ------ Inner loop. contour_filtering: 6
# ------ Inner loop. contour_filtering: 7
# ------ Inner loop. contour_filtering: 8
# ------ Inner loop. contour_filtering: 9
# ------ Inner loop. contour_filtering: 10
# ------ Inner loop. contour_filtering: 11
# ------ Inner loop. contour_filtering: 12
# ------ Inner loop. contour_filtering: 13
# ------ Inner loop. contour_filtering: 14
# ------ Inner loop. contour_filtering: 15
# ------ Inner loop. contour_filtering: 16
# ------ Inner loop. contour_filtering: 17
# ------ Inner loop. contour_filtering: 18
# ------ Inner loop. contour_filtering: 19
# ------ Inner loop. contour_filtering: 20
# ------ Inner loop. contour_filtering: 21
# ------ Inner loop. contour_filtering: 22
# ------ Inner loop. contour_filtering: 23
# ------ Inner loop. contour_filtering: 24
# ------ Inner loop. contour_filtering: 25
# ------ Inner loop. contour_filtering: 26
# ------ Inner loop. contour_filtering: 27
# ------ Inner loop. contour_filtering: 28
# ------ Inner loop. contour_filtering: 29
# ------ Inner loop. contour_filtering: 30
# ------ Inner loop. contour_filtering: 31
# ------ Inner loop. contour_filtering: 32
# ------ Inner loop. contour_filtering: 33
# ------ Inner loop. contour_filtering: 34
# ------ Inner loop. contour_filtering: 35
# ------ Inner loop. contour_filtering: 36
# ------ Inner loop. contour_filtering: 37
# ------ Inner loop. contour_filtering: 38
# ------ Inner loop. contour_filtering: 39
# ------ Inner loop. contour_filtering: 40
# ------ Inner loop. contour_filtering: 41
# ------ Inner loop. contour_filtering: 42
# ------ Inner loop. contour_filtering: 43
# ------ Inner loop. contour_filtering: 44
# ------ Inner loop. contour_filtering: 45
# ------ Inner loop. contour_filtering: 46
# ------ Inner loop. contour_filtering: 47
# ------ Inner loop. contour_filtering: 48
# ------ Inner loop. contour_filtering: 49
# ------ Inner loop. contour_filtering: 50
# ------ Inner loop. contour_filtering: 51
# ------ Inner loop. contour_filtering: 52
# ------ Inner loop. contour_filtering: 53
# ------ Inner loop. contour_filtering: 54
# ------ Inner loop. contour_filtering: 55
# ------ Inner loop. contour_filtering: 56
# ------ Inner loop. contour_filtering: 57
# ------ Inner loop. contour_filtering: 58
# ------ Inner loop. contour_filtering: 59
# ------ Inner loop. contour_filtering: 60
# ------ Inner loop. contour_filtering: 61
# ------ Inner loop. contour_filtering: 62
# ------ Inner loop. contour_filtering: 63
# ------ Inner loop. contour_filtering: 64
# ------ Inner loop. contour_filtering: 65
# ------ Inner loop. contour_filtering: 66
# ------ Inner loop. contour_filtering: 67
# ------ Inner loop. contour_filtering: 68
# ------ Inner loop. contour_filtering: 69
# ------ Inner loop. contour_filtering: 70
# ------ Inner loop. contour_filtering: 71
# ------ Inner loop. contour_filtering: 72
# ------ Inner loop. contour_filtering: 73
# ------ Inner loop. contour_filtering: 74
# ------ Inner loop. contour_filtering: 75
# ------ Inner loop. contour_filtering: 76
# ------ Inner loop. contour_filtering: 77
# ------ Inner loop. contour_filtering: 78
# ------ Inner loop. contour_filtering: 79
# ------ Inner loop. contour_filtering: 80
# ------ Inner loop. contour_filtering: 81
# ------ Inner loop. contour_filtering: 82
# ------ Inner loop. contour_filtering: 83
# ------ Inner loop. contour_filtering: 84
# ------ Inner loop. contour_filtering: 85
# ------ Inner loop. contour_filtering: 86
# ------ Inner loop. contour_filtering: 87
# ------ Inner loop. contour_filtering: 88
# ------ Inner loop. contour_filtering: 89
# ------ Inner loop. contour_filtering: 90
# ------ Inner loop. contour_filtering: 91
# ------ Inner loop. contour_filtering: 92
# ------ Inner loop. contour_filtering: 93
# ------ Inner loop. contour_filtering: 94
# ------ Inner loop. contour_filtering: 95
# ------ Inner loop. contour_filtering: 96
# ------ Inner loop. contour_filtering: 97
# ------ Inner loop. contour_filtering: 98
# ------ Inner loop. contour_filtering: 99
# Elapsed:6.442941477298737
# --- Method: delaunay_triangulation
# ---- Parameters Combination: 0
# ------ Inner loop. delaunay_triangulation: 0
# ------ Inner loop. delaunay_triangulation: 1
# ------ Inner loop. delaunay_triangulation: 2
# ------ Inner loop. delaunay_triangulation: 3
# ------ Inner loop. delaunay_triangulation: 4
# ------ Inner loop. delaunay_triangulation: 5
# ------ Inner loop. delaunay_triangulation: 6
# ------ Inner loop. delaunay_triangulation: 7
# ------ Inner loop. delaunay_triangulation: 8
# ------ Inner loop. delaunay_triangulation: 9
# ------ Inner loop. delaunay_triangulation: 10
# ------ Inner loop. delaunay_triangulation: 11
# ------ Inner loop. delaunay_triangulation: 12
# ------ Inner loop. delaunay_triangulation: 13
# ------ Inner loop. delaunay_triangulation: 14
# ------ Inner loop. delaunay_triangulation: 15
# ------ Inner loop. delaunay_triangulation: 16
# ------ Inner loop. delaunay_triangulation: 17
# ------ Inner loop. delaunay_triangulation: 18
# ------ Inner loop. delaunay_triangulation: 19
# ------ Inner loop. delaunay_triangulation: 20
# ------ Inner loop. delaunay_triangulation: 21
# ------ Inner loop. delaunay_triangulation: 22
# ------ Inner loop. delaunay_triangulation: 23
# ------ Inner loop. delaunay_triangulation: 24
# ------ Inner loop. delaunay_triangulation: 25
# ------ Inner loop. delaunay_triangulation: 26
# ------ Inner loop. delaunay_triangulation: 27
# ------ Inner loop. delaunay_triangulation: 28
# ------ Inner loop. delaunay_triangulation: 29
# ------ Inner loop. delaunay_triangulation: 30
# ------ Inner loop. delaunay_triangulation: 31
# ------ Inner loop. delaunay_triangulation: 32
# ------ Inner loop. delaunay_triangulation: 33
# ------ Inner loop. delaunay_triangulation: 34
# ------ Inner loop. delaunay_triangulation: 35
# ------ Inner loop. delaunay_triangulation: 36
# ------ Inner loop. delaunay_triangulation: 37
# ------ Inner loop. delaunay_triangulation: 38
# ------ Inner loop. delaunay_triangulation: 39
# ------ Inner loop. delaunay_triangulation: 40
# ------ Inner loop. delaunay_triangulation: 41
# ------ Inner loop. delaunay_triangulation: 42
# ------ Inner loop. delaunay_triangulation: 43
# ------ Inner loop. delaunay_triangulation: 44
# ------ Inner loop. delaunay_triangulation: 45
# ------ Inner loop. delaunay_triangulation: 46
# ------ Inner loop. delaunay_triangulation: 47
# ------ Inner loop. delaunay_triangulation: 48
# ------ Inner loop. delaunay_triangulation: 49
# ------ Inner loop. delaunay_triangulation: 50
# ------ Inner loop. delaunay_triangulation: 51
# ------ Inner loop. delaunay_triangulation: 52
# ------ Inner loop. delaunay_triangulation: 53
# ------ Inner loop. delaunay_triangulation: 54
# ------ Inner loop. delaunay_triangulation: 55
# ------ Inner loop. delaunay_triangulation: 56
# ------ Inner loop. delaunay_triangulation: 57
# ------ Inner loop. delaunay_triangulation: 58
# ------ Inner loop. delaunay_triangulation: 59
# ------ Inner loop. delaunay_triangulation: 60
# ------ Inner loop. delaunay_triangulation: 61
# ------ Inner loop. delaunay_triangulation: 62
# ------ Inner loop. delaunay_triangulation: 63
# ------ Inner loop. delaunay_triangulation: 64
# ------ Inner loop. delaunay_triangulation: 65
# ------ Inner loop. delaunay_triangulation: 66
# ------ Inner loop. delaunay_triangulation: 67
# ------ Inner loop. delaunay_triangulation: 68
# ------ Inner loop. delaunay_triangulation: 69
# ------ Inner loop. delaunay_triangulation: 70
# ------ Inner loop. delaunay_triangulation: 71
# ------ Inner loop. delaunay_triangulation: 72
# ------ Inner loop. delaunay_triangulation: 73
# ------ Inner loop. delaunay_triangulation: 74
# ------ Inner loop. delaunay_triangulation: 75
# ------ Inner loop. delaunay_triangulation: 76
# ------ Inner loop. delaunay_triangulation: 77
# ------ Inner loop. delaunay_triangulation: 78
# ------ Inner loop. delaunay_triangulation: 79
# ------ Inner loop. delaunay_triangulation: 80
# ------ Inner loop. delaunay_triangulation: 81
# ------ Inner loop. delaunay_triangulation: 82
# ------ Inner loop. delaunay_triangulation: 83
# ------ Inner loop. delaunay_triangulation: 84
# ------ Inner loop. delaunay_triangulation: 85
# ------ Inner loop. delaunay_triangulation: 86
# ------ Inner loop. delaunay_triangulation: 87
# ------ Inner loop. delaunay_triangulation: 88
# ------ Inner loop. delaunay_triangulation: 89
# ------ Inner loop. delaunay_triangulation: 90
# ------ Inner loop. delaunay_triangulation: 91
# ------ Inner loop. delaunay_triangulation: 92
# ------ Inner loop. delaunay_triangulation: 93
# ------ Inner loop. delaunay_triangulation: 94
# ------ Inner loop. delaunay_triangulation: 95
# ------ Inner loop. delaunay_triangulation: 96
# ------ Inner loop. delaunay_triangulation: 97
# ------ Inner loop. delaunay_triangulation: 98
# ------ Inner loop. delaunay_triangulation: 99
# Elapsed:0.365731737613678
# ---- Parameters Combination: 1
# ------ Inner loop. delaunay_triangulation: 0
# A curve_set(1d) object with 2500 curves observed at 14 argument values
# (1 observed, 2499 simulated).
# Contains:
# $ r     :  num [1:14] 0.665 0.694 0.723 0.752 0.781 ...
# $ funcs :  num [1:14, 1:2500] 1.02 1.05 1.07 1.1 1.12 ...
#  - attr(*, "dimnames")=List of 2
#   ..$ : chr [1:14] "24" "25" "26" "27" ...
#   ..$ : chr [1:2500] "obs" "sim1" "sim2" "sim3" ...
#
# ------ Inner loop. delaunay_triangulation: 1
# A curve_set(1d) object with 2500 curves observed at 14 argument values
# (1 observed, 2499 simulated).
# Contains:
# $ r     :  num [1:14] 0.665 0.694 0.723 0.752 0.781 ...
# $ funcs :  num [1:14, 1:2500] 1.02 1.05 1.07 1.1 1.12 ...
#  - attr(*, "dimnames")=List of 2
#   ..$ : chr [1:14] "24" "25" "26" "27" ...
#   ..$ : chr [1:2500] "obs" "sim1" "sim2" "sim3" ...
#
# ------ Inner loop. delaunay_triangulation: 2
# A curve_set(1d) object with 2500 curves observed at 14 argument values
# (1 observed, 2499 simulated).
# Contains:
# $ r     :  num [1:14] 0.665 0.694 0.723 0.752 0.781 ...
# $ funcs :  num [1:14, 1:2500] 1.03 1.05 1.07 1.1 1.12 ...
#  - attr(*, "dimnames")=List of 2
#   ..$ : chr [1:14] "24" "25" "26" "27" ...
#   ..$ : chr [1:2500] "obs" "sim1" "sim2" "sim3" ...
#
# ------ Inner loop. delaunay_triangulation: 3
# A curve_set(1d) object with 2500 curves observed at 14 argument values
# (1 observed, 2499 simulated).
# Contains:
# $ r     :  num [1:14] 0.665 0.694 0.723 0.752 0.781 ...
# $ funcs :  num [1:14, 1:2500] 1.03 1.05 1.07 1.1 1.12 ...
#  - attr(*, "dimnames")=List of 2
#   ..$ : chr [1:14] "24" "25" "26" "27" ...
#   ..$ : chr [1:2500] "obs" "sim1" "sim2" "sim3" ...
#
# ------ Inner loop. delaunay_triangulation: 4
# A curve_set(1d) object with 2500 curves observed at 14 argument values
# (1 observed, 2499 simulated).
# Contains:
# $ r     :  num [1:14] 0.665 0.694 0.723 0.752 0.781 ...
# $ funcs :  num [1:14, 1:2500] 1.03 1.06 1.08 1.1 1.13 ...
#  - attr(*, "dimnames")=List of 2
#   ..$ : chr [1:14] "24" "25" "26" "27" ...
#   ..$ : chr [1:2500] "obs" "sim1" "sim2" "sim3" ...
#
# ------ Inner loop. delaunay_triangulation: 5
# A curve_set(1d) object with 2500 curves observed at 14 argument values
# (1 observed, 2499 simulated).
# Contains:
# $ r     :  num [1:14] 0.665 0.694 0.723 0.752 0.781 ...
# $ funcs :  num [1:14, 1:2500] 1.03 1.05 1.08 1.1 1.13 ...
#  - attr(*, "dimnames")=List of 2
#   ..$ : chr [1:14] "24" "25" "26" "27" ...
#   ..$ : chr [1:2500] "obs" "sim1" "sim2" "sim3" ...
#
# ------ Inner loop. delaunay_triangulation: 6
# A curve_set(1d) object with 2500 curves observed at 14 argument values
# (1 observed, 2499 simulated).
# Contains:
# $ r     :  num [1:14] 0.665 0.694 0.723 0.752 0.781 ...
# $ funcs :  num [1:14, 1:2500] 1.02 1.05 1.07 1.09 1.12 ...
#  - attr(*, "dimnames")=List of 2
#   ..$ : chr [1:14] "24" "25" "26" "27" ...
#   ..$ : chr [1:2500] "obs" "sim1" "sim2" "sim3" ...
#
# ------ Inner loop. delaunay_triangulation: 7
# A curve_set(1d) object with 2500 curves observed at 14 argument values
# (1 observed, 2499 simulated).
# Contains:
# $ r     :  num [1:14] 0.665 0.694 0.723 0.752 0.781 ...
# $ funcs :  num [1:14, 1:2500] 1.02 1.05 1.06 1.09 1.12 ...
#  - attr(*, "dimnames")=List of 2
#   ..$ : chr [1:14] "24" "25" "26" "27" ...
#   ..$ : chr [1:2500] "obs" "sim1" "sim2" "sim3" ...
#
# ------ Inner loop. delaunay_triangulation: 8
# A curve_set(1d) object with 2500 curves observed at 14 argument values
# (1 observed, 2499 simulated).
# Contains:
# $ r     :  num [1:14] 0.665 0.694 0.723 0.752 0.781 ...
# $ funcs :  num [1:14, 1:2500] 1.03 1.05 1.08 1.1 1.12 ...
#  - attr(*, "dimnames")=List of 2
#   ..$ : chr [1:14] "24" "25" "26" "27" ...
#   ..$ : chr [1:2500] "obs" "sim1" "sim2" "sim3" ...
#
# ------ Inner loop. delaunay_triangulation: 9
# A curve_set(1d) object with 2500 curves observed at 14 argument values
# (1 observed, 2499 simulated).
# Contains:
# $ r     :  num [1:14] 0.665 0.694 0.723 0.752 0.781 ...
# $ funcs :  num [1:14, 1:2500] 1.03 1.05 1.07 1.1 1.12 ...
#  - attr(*, "dimnames")=List of 2
#   ..$ : chr [1:14] "24" "25" "26" "27" ...
#   ..$ : chr [1:2500] "obs" "sim1" "sim2" "sim3" ...
#
# ------ Inner loop. delaunay_triangulation: 10
# A curve_set(1d) object with 2500 curves observed at 14 argument values
# (1 observed, 2499 simulated).
# Contains:
# $ r     :  num [1:14] 0.665 0.694 0.723 0.752 0.781 ...
# $ funcs :  num [1:14, 1:2500] 1.02 1.05 1.07 1.09 1.12 ...
#  - attr(*, "dimnames")=List of 2
#   ..$ : chr [1:14] "24" "25" "26" "27" ...
#   ..$ : chr [1:2500] "obs" "sim1" "sim2" "sim3" ...
#
# ------ Inner loop. delaunay_triangulation: 11
# A curve_set(1d) object with 2500 curves observed at 14 argument values
# (1 observed, 2499 simulated).
# Contains:
# $ r     :  num [1:14] 0.665 0.694 0.723 0.752 0.781 ...
# $ funcs :  num [1:14, 1:2500] 1.03 1.05 1.07 1.09 1.12 ...
#  - attr(*, "dimnames")=List of 2
#   ..$ : chr [1:14] "24" "25" "26" "27" ...
#   ..$ : chr [1:2500] "obs" "sim1" "sim2" "sim3" ...
#
# ------ Inner loop. delaunay_triangulation: 12
# A curve_set(1d) object with 2500 curves observed at 14 argument values
# (1 observed, 2499 simulated).
# Contains:
# $ r     :  num [1:14] 0.665 0.694 0.723 0.752 0.781 ...
# $ funcs :  num [1:14, 1:2500] 1.02 1.04 1.06 1.09 1.11 ...
#  - attr(*, "dimnames")=List of 2
#   ..$ : chr [1:14] "24" "25" "26" "27" ...
#   ..$ : chr [1:2500] "obs" "sim1" "sim2" "sim3" ...
#
# ------ Inner loop. delaunay_triangulation: 13
# A curve_set(1d) object with 2500 curves observed at 14 argument values
# (1 observed, 2499 simulated).
# Contains:
# $ r     :  num [1:14] 0.665 0.694 0.723 0.752 0.781 ...
# $ funcs :  num [1:14, 1:2500] 1.02 1.05 1.07 1.1 1.12 ...
#  - attr(*, "dimnames")=List of 2
#   ..$ : chr [1:14] "24" "25" "26" "27" ...
#   ..$ : chr [1:2500] "obs" "sim1" "sim2" "sim3" ...
#
# ------ Inner loop. delaunay_triangulation: 14
# A curve_set(1d) object with 2500 curves observed at 14 argument values
# (1 observed, 2499 simulated).
# Contains:
# $ r     :  num [1:14] 0.665 0.694 0.723 0.752 0.781 ...
# $ funcs :  num [1:14, 1:2500] 1.03 1.05 1.08 1.1 1.13 ...
#  - attr(*, "dimnames")=List of 2
#   ..$ : chr [1:14] "24" "25" "26" "27" ...
#   ..$ : chr [1:2500] "obs" "sim1" "sim2" "sim3" ...
#
# ------ Inner loop. delaunay_triangulation: 15
# A curve_set(1d) object with 2500 curves observed at 14 argument values
# (1 observed, 2499 simulated).
# Contains:
# $ r     :  num [1:14] 0.665 0.694 0.723 0.752 0.781 ...
# $ funcs :  num [1:14, 1:2500] 1.03 1.05 1.07 1.1 1.13 ...
#  - attr(*, "dimnames")=List of 2
#   ..$ : chr [1:14] "24" "25" "26" "27" ...
#   ..$ : chr [1:2500] "obs" "sim1" "sim2" "sim3" ...
#
# ------ Inner loop. delaunay_triangulation: 16
# A curve_set(1d) object with 2500 curves observed at 14 argument values
# (1 observed, 2499 simulated).
# Contains:
# $ r     :  num [1:14] 0.665 0.694 0.723 0.752 0.781 ...
# $ funcs :  num [1:14, 1:2500] 1.02 1.05 1.07 1.1 1.12 ...
#  - attr(*, "dimnames")=List of 2
#   ..$ : chr [1:14] "24" "25" "26" "27" ...
#   ..$ : chr [1:2500] "obs" "sim1" "sim2" "sim3" ...
#
# ------ Inner loop. delaunay_triangulation: 17
# A curve_set(1d) object with 2500 curves observed at 14 argument values
# (1 observed, 2499 simulated).
# Contains:
# $ r     :  num [1:14] 0.665 0.694 0.723 0.752 0.781 ...
# $ funcs :  num [1:14, 1:2500] 1.03 1.05 1.07 1.1 1.12 ...
#  - attr(*, "dimnames")=List of 2
#   ..$ : chr [1:14] "24" "25" "26" "27" ...
#   ..$ : chr [1:2500] "obs" "sim1" "sim2" "sim3" ...
#
# ------ Inner loop. delaunay_triangulation: 18
# A curve_set(1d) object with 2500 curves observed at 14 argument values
# (1 observed, 2499 simulated).
# Contains:
# $ r     :  num [1:14] 0.665 0.694 0.723 0.752 0.781 ...
# $ funcs :  num [1:14, 1:2500] 1.02 1.04 1.06 1.09 1.11 ...
#  - attr(*, "dimnames")=List of 2
#   ..$ : chr [1:14] "24" "25" "26" "27" ...
#   ..$ : chr [1:2500] "obs" "sim1" "sim2" "sim3" ...
#
# ------ Inner loop. delaunay_triangulation: 19
# A curve_set(1d) object with 2500 curves observed at 14 argument values
# (1 observed, 2499 simulated).
# Contains:
# $ r     :  num [1:14] 0.665 0.694 0.723 0.752 0.781 ...
# $ funcs :  num [1:14, 1:2500] 1.04 1.06 1.08 1.11 1.13 ...
#  - attr(*, "dimnames")=List of 2
#   ..$ : chr [1:14] "24" "25" "26" "27" ...
#   ..$ : chr [1:2500] "obs" "sim1" "sim2" "sim3" ...
#
# ------ Inner loop. delaunay_triangulation: 20
# A curve_set(1d) object with 2500 curves observed at 14 argument values
# (1 observed, 2499 simulated).
# Contains:
# $ r     :  num [1:14] 0.665 0.694 0.723 0.752 0.781 ...
# $ funcs :  num [1:14, 1:2500] 1.02 1.05 1.07 1.1 1.12 ...
#  - attr(*, "dimnames")=List of 2
#   ..$ : chr [1:14] "24" "25" "26" "27" ...
#   ..$ : chr [1:2500] "obs" "sim1" "sim2" "sim3" ...
#
# ------ Inner loop. delaunay_triangulation: 21
# A curve_set(1d) object with 2500 curves observed at 14 argument values
# (1 observed, 2499 simulated).
# Contains:
# $ r     :  num [1:14] 0.665 0.694 0.723 0.752 0.781 ...
# $ funcs :  num [1:14, 1:2500] 1.03 1.05 1.07 1.1 1.12 ...
#  - attr(*, "dimnames")=List of 2
#   ..$ : chr [1:14] "24" "25" "26" "27" ...
#   ..$ : chr [1:2500] "obs" "sim1" "sim2" "sim3" ...
#
# ------ Inner loop. delaunay_triangulation: 22
# A curve_set(1d) object with 2500 curves observed at 14 argument values
# (1 observed, 2499 simulated).
# Contains:
# $ r     :  num [1:14] 0.665 0.694 0.723 0.752 0.781 ...
# $ funcs :  num [1:14, 1:2500] 1.02 1.05 1.07 1.1 1.12 ...
#  - attr(*, "dimnames")=List of 2
#   ..$ : chr [1:14] "24" "25" "26" "27" ...
#   ..$ : chr [1:2500] "obs" "sim1" "sim2" "sim3" ...
#
# ------ Inner loop. delaunay_triangulation: 23
# A curve_set(1d) object with 2500 curves observed at 14 argument values
# (1 observed, 2499 simulated).
# Contains:
# $ r     :  num [1:14] 0.665 0.694 0.723 0.752 0.781 ...
# $ funcs :  num [1:14, 1:2500] 1.02 1.05 1.07 1.1 1.12 ...
#  - attr(*, "dimnames")=List of 2
#   ..$ : chr [1:14] "24" "25" "26" "27" ...
#   ..$ : chr [1:2500] "obs" "sim1" "sim2" "sim3" ...
#
# ------ Inner loop. delaunay_triangulation: 24
# A curve_set(1d) object with 2500 curves observed at 14 argument values
# (1 observed, 2499 simulated).
# Contains:
# $ r     :  num [1:14] 0.665 0.694 0.723 0.752 0.781 ...
# $ funcs :  num [1:14, 1:2500] 1.03 1.05 1.08 1.1 1.13 ...
#  - attr(*, "dimnames")=List of 2
#   ..$ : chr [1:14] "24" "25" "26" "27" ...
#   ..$ : chr [1:2500] "obs" "sim1" "sim2" "sim3" ...
#
# ------ Inner loop. delaunay_triangulation: 25
# A curve_set(1d) object with 2500 curves observed at 14 argument values
# (1 observed, 2499 simulated).
# Contains:
# $ r     :  num [1:14] 0.665 0.694 0.723 0.752 0.781 ...
# $ funcs :  num [1:14, 1:2500] 1.02 1.05 1.07 1.09 1.12 ...
#  - attr(*, "dimnames")=List of 2
#   ..$ : chr [1:14] "24" "25" "26" "27" ...
#   ..$ : chr [1:2500] "obs" "sim1" "sim2" "sim3" ...
#
# ------ Inner loop. delaunay_triangulation: 26
# A curve_set(1d) object with 2500 curves observed at 14 argument values
# (1 observed, 2499 simulated).
# Contains:
# $ r     :  num [1:14] 0.665 0.694 0.723 0.752 0.781 ...
# $ funcs :  num [1:14, 1:2500] 1.04 1.06 1.08 1.11 1.13 ...
#  - attr(*, "dimnames")=List of 2
#   ..$ : chr [1:14] "24" "25" "26" "27" ...
#   ..$ : chr [1:2500] "obs" "sim1" "sim2" "sim3" ...
#
# ------ Inner loop. delaunay_triangulation: 27
# A curve_set(1d) object with 2500 curves observed at 14 argument values
# (1 observed, 2499 simulated).
# Contains:
# $ r     :  num [1:14] 0.665 0.694 0.723 0.752 0.781 ...
# $ funcs :  num [1:14, 1:2500] 1.02 1.05 1.07 1.1 1.12 ...
#  - attr(*, "dimnames")=List of 2
#   ..$ : chr [1:14] "24" "25" "26" "27" ...
#   ..$ : chr [1:2500] "obs" "sim1" "sim2" "sim3" ...
#
# ------ Inner loop. delaunay_triangulation: 28
# A curve_set(1d) object with 2500 curves observed at 14 argument values
# (1 observed, 2499 simulated).
# Contains:
# $ r     :  num [1:14] 0.665 0.694 0.723 0.752 0.781 ...
# $ funcs :  num [1:14, 1:2500] 1.03 1.05 1.08 1.1 1.13 ...
#  - attr(*, "dimnames")=List of 2
#   ..$ : chr [1:14] "24" "25" "26" "27" ...
#   ..$ : chr [1:2500] "obs" "sim1" "sim2" "sim3" ...
#
# ------ Inner loop. delaunay_triangulation: 29
# A curve_set(1d) object with 2500 curves observed at 14 argument values
# (1 observed, 2499 simulated).
# Contains:
# $ r     :  num [1:14] 0.665 0.694 0.723 0.752 0.781 ...
# $ funcs :  num [1:14, 1:2500] 1.03 1.06 1.08 1.11 1.13 ...
#  - attr(*, "dimnames")=List of 2
#   ..$ : chr [1:14] "24" "25" "26" "27" ...
#   ..$ : chr [1:2500] "obs" "sim1" "sim2" "sim3" ...
#
# ------ Inner loop. delaunay_triangulation: 30
# A curve_set(1d) object with 2500 curves observed at 14 argument values
# (1 observed, 2499 simulated).
# Contains:
# $ r     :  num [1:14] 0.665 0.694 0.723 0.752 0.781 ...
# $ funcs :  num [1:14, 1:2500] 1.02 1.05 1.07 1.1 1.12 ...
#  - attr(*, "dimnames")=List of 2
#   ..$ : chr [1:14] "24" "25" "26" "27" ...
#   ..$ : chr [1:2500] "obs" "sim1" "sim2" "sim3" ...
#
# ------ Inner loop. delaunay_triangulation: 31
# A curve_set(1d) object with 2500 curves observed at 14 argument values
# (1 observed, 2499 simulated).
# Contains:
# $ r     :  num [1:14] 0.665 0.694 0.723 0.752 0.781 ...
# $ funcs :  num [1:14, 1:2500] 1.03 1.05 1.07 1.1 1.13 ...
#  - attr(*, "dimnames")=List of 2
#   ..$ : chr [1:14] "24" "25" "26" "27" ...
#   ..$ : chr [1:2500] "obs" "sim1" "sim2" "sim3" ...
#
# ------ Inner loop. delaunay_triangulation: 32
# A curve_set(1d) object with 2500 curves observed at 14 argument values
# (1 observed, 2499 simulated).
# Contains:
# $ r     :  num [1:14] 0.665 0.694 0.723 0.752 0.781 ...
# $ funcs :  num [1:14, 1:2500] 1.02 1.04 1.06 1.09 1.12 ...
#  - attr(*, "dimnames")=List of 2
#   ..$ : chr [1:14] "24" "25" "26" "27" ...
#   ..$ : chr [1:2500] "obs" "sim1" "sim2" "sim3" ...
#
# ------ Inner loop. delaunay_triangulation: 33
# A curve_set(1d) object with 2500 curves observed at 14 argument values
# (1 observed, 2499 simulated).
# Contains:
# $ r     :  num [1:14] 0.665 0.694 0.723 0.752 0.781 ...
# $ funcs :  num [1:14, 1:2500] 1.02 1.05 1.07 1.09 1.12 ...
#  - attr(*, "dimnames")=List of 2
#   ..$ : chr [1:14] "24" "25" "26" "27" ...
#   ..$ : chr [1:2500] "obs" "sim1" "sim2" "sim3" ...
#
# ------ Inner loop. delaunay_triangulation: 34
# A curve_set(1d) object with 2500 curves observed at 14 argument values
# (1 observed, 2499 simulated).
# Contains:
# $ r     :  num [1:14] 0.665 0.694 0.723 0.752 0.781 ...
# $ funcs :  num [1:14, 1:2500] 1.03 1.06 1.08 1.1 1.13 ...
#  - attr(*, "dimnames")=List of 2
#   ..$ : chr [1:14] "24" "25" "26" "27" ...
#   ..$ : chr [1:2500] "obs" "sim1" "sim2" "sim3" ...
#
# ------ Inner loop. delaunay_triangulation: 35
# A curve_set(1d) object with 2500 curves observed at 14 argument values
# (1 observed, 2499 simulated).
# Contains:
# $ r     :  num [1:14] 0.665 0.694 0.723 0.752 0.781 ...
# $ funcs :  num [1:14, 1:2500] 1.03 1.05 1.07 1.1 1.12 ...
#  - attr(*, "dimnames")=List of 2
#   ..$ : chr [1:14] "24" "25" "26" "27" ...
#   ..$ : chr [1:2500] "obs" "sim1" "sim2" "sim3" ...
#
# ------ Inner loop. delaunay_triangulation: 36
# A curve_set(1d) object with 2500 curves observed at 14 argument values
# (1 observed, 2499 simulated).
# Contains:
# $ r     :  num [1:14] 0.665 0.694 0.723 0.752 0.781 ...
# $ funcs :  num [1:14, 1:2500] 1.01 1.04 1.06 1.09 1.11 ...
#  - attr(*, "dimnames")=List of 2
#   ..$ : chr [1:14] "24" "25" "26" "27" ...
#   ..$ : chr [1:2500] "obs" "sim1" "sim2" "sim3" ...
#
# ------ Inner loop. delaunay_triangulation: 37
# A curve_set(1d) object with 2500 curves observed at 14 argument values
# (1 observed, 2499 simulated).
# Contains:
# $ r     :  num [1:14] 0.665 0.694 0.723 0.752 0.781 ...
# $ funcs :  num [1:14, 1:2500] 1.03 1.05 1.07 1.1 1.12 ...
#  - attr(*, "dimnames")=List of 2
#   ..$ : chr [1:14] "24" "25" "26" "27" ...
#   ..$ : chr [1:2500] "obs" "sim1" "sim2" "sim3" ...
#
# ------ Inner loop. delaunay_triangulation: 38
# A curve_set(1d) object with 2500 curves observed at 14 argument values
# (1 observed, 2499 simulated).
# Contains:
# $ r     :  num [1:14] 0.665 0.694 0.723 0.752 0.781 ...
# $ funcs :  num [1:14, 1:2500] 1.01 1.04 1.06 1.09 1.11 ...
#  - attr(*, "dimnames")=List of 2
#   ..$ : chr [1:14] "24" "25" "26" "27" ...
#   ..$ : chr [1:2500] "obs" "sim1" "sim2" "sim3" ...
#
# ------ Inner loop. delaunay_triangulation: 39
# A curve_set(1d) object with 2500 curves observed at 14 argument values
# (1 observed, 2499 simulated).
# Contains:
# $ r     :  num [1:14] 0.665 0.694 0.723 0.752 0.781 ...
# $ funcs :  num [1:14, 1:2500] 1.02 1.05 1.07 1.1 1.12 ...
#  - attr(*, "dimnames")=List of 2
#   ..$ : chr [1:14] "24" "25" "26" "27" ...
#   ..$ : chr [1:2500] "obs" "sim1" "sim2" "sim3" ...
#
# ------ Inner loop. delaunay_triangulation: 40
# A curve_set(1d) object with 2500 curves observed at 14 argument values
# (1 observed, 2499 simulated).
# Contains:
# $ r     :  num [1:14] 0.665 0.694 0.723 0.752 0.781 ...
# $ funcs :  num [1:14, 1:2500] 1.03 1.05 1.07 1.1 1.12 ...
#  - attr(*, "dimnames")=List of 2
#   ..$ : chr [1:14] "24" "25" "26" "27" ...
#   ..$ : chr [1:2500] "obs" "sim1" "sim2" "sim3" ...
#
# ------ Inner loop. delaunay_triangulation: 41
# A curve_set(1d) object with 2500 curves observed at 14 argument values
# (1 observed, 2499 simulated).
# Contains:
# $ r     :  num [1:14] 0.665 0.694 0.723 0.752 0.781 ...
# $ funcs :  num [1:14, 1:2500] 1.02 1.05 1.07 1.09 1.12 ...
#  - attr(*, "dimnames")=List of 2
#   ..$ : chr [1:14] "24" "25" "26" "27" ...
#   ..$ : chr [1:2500] "obs" "sim1" "sim2" "sim3" ...
#
# ------ Inner loop. delaunay_triangulation: 42
# A curve_set(1d) object with 2500 curves observed at 14 argument values
# (1 observed, 2499 simulated).
# Contains:
# $ r     :  num [1:14] 0.665 0.694 0.723 0.752 0.781 ...
# $ funcs :  num [1:14, 1:2500] 1.03 1.06 1.08 1.1 1.13 ...
#  - attr(*, "dimnames")=List of 2
#   ..$ : chr [1:14] "24" "25" "26" "27" ...
#   ..$ : chr [1:2500] "obs" "sim1" "sim2" "sim3" ...
#
# ------ Inner loop. delaunay_triangulation: 43
# A curve_set(1d) object with 2500 curves observed at 14 argument values
# (1 observed, 2499 simulated).
# Contains:
# $ r     :  num [1:14] 0.665 0.694 0.723 0.752 0.781 ...
# $ funcs :  num [1:14, 1:2500] 1.03 1.06 1.08 1.1 1.13 ...
#  - attr(*, "dimnames")=List of 2
#   ..$ : chr [1:14] "24" "25" "26" "27" ...
#   ..$ : chr [1:2500] "obs" "sim1" "sim2" "sim3" ...
#
# ------ Inner loop. delaunay_triangulation: 44
# A curve_set(1d) object with 2500 curves observed at 14 argument values
# (1 observed, 2499 simulated).
# Contains:
# $ r     :  num [1:14] 0.665 0.694 0.723 0.752 0.781 ...
# $ funcs :  num [1:14, 1:2500] 1.02 1.04 1.07 1.09 1.12 ...
#  - attr(*, "dimnames")=List of 2
#   ..$ : chr [1:14] "24" "25" "26" "27" ...
#   ..$ : chr [1:2500] "obs" "sim1" "sim2" "sim3" ...
#
# ------ Inner loop. delaunay_triangulation: 45
# A curve_set(1d) object with 2500 curves observed at 14 argument values
# (1 observed, 2499 simulated).
# Contains:
# $ r     :  num [1:14] 0.665 0.694 0.723 0.752 0.781 ...
# $ funcs :  num [1:14, 1:2500] 1.03 1.05 1.08 1.1 1.12 ...
#  - attr(*, "dimnames")=List of 2
#   ..$ : chr [1:14] "24" "25" "26" "27" ...
#   ..$ : chr [1:2500] "obs" "sim1" "sim2" "sim3" ...
#
# ------ Inner loop. delaunay_triangulation: 46
# A curve_set(1d) object with 2500 curves observed at 14 argument values
# (1 observed, 2499 simulated).
# Contains:
# $ r     :  num [1:14] 0.665 0.694 0.723 0.752 0.781 ...
# $ funcs :  num [1:14, 1:2500] 1.02 1.05 1.07 1.09 1.12 ...
#  - attr(*, "dimnames")=List of 2
#   ..$ : chr [1:14] "24" "25" "26" "27" ...
#   ..$ : chr [1:2500] "obs" "sim1" "sim2" "sim3" ...
#
# ------ Inner loop. delaunay_triangulation: 47
# A curve_set(1d) object with 2500 curves observed at 14 argument values
# (1 observed, 2499 simulated).
# Contains:
# $ r     :  num [1:14] 0.665 0.694 0.723 0.752 0.781 ...
# $ funcs :  num [1:14, 1:2500] 1.02 1.04 1.07 1.09 1.12 ...
#  - attr(*, "dimnames")=List of 2
#   ..$ : chr [1:14] "24" "25" "26" "27" ...
#   ..$ : chr [1:2500] "obs" "sim1" "sim2" "sim3" ...
#
# ------ Inner loop. delaunay_triangulation: 48
# A curve_set(1d) object with 2500 curves observed at 14 argument values
# (1 observed, 2499 simulated).
# Contains:
# $ r     :  num [1:14] 0.665 0.694 0.723 0.752 0.781 ...
# $ funcs :  num [1:14, 1:2500] 1.02 1.04 1.06 1.09 1.11 ...
#  - attr(*, "dimnames")=List of 2
#   ..$ : chr [1:14] "24" "25" "26" "27" ...
#   ..$ : chr [1:2500] "obs" "sim1" "sim2" "sim3" ...
#
# ------ Inner loop. delaunay_triangulation: 49
# A curve_set(1d) object with 2500 curves observed at 14 argument values
# (1 observed, 2499 simulated).
# Contains:
# $ r     :  num [1:14] 0.665 0.694 0.723 0.752 0.781 ...
# $ funcs :  num [1:14, 1:2500] 1.03 1.05 1.08 1.1 1.13 ...
#  - attr(*, "dimnames")=List of 2
#   ..$ : chr [1:14] "24" "25" "26" "27" ...
#   ..$ : chr [1:2500] "obs" "sim1" "sim2" "sim3" ...
#
# ------ Inner loop. delaunay_triangulation: 50
# A curve_set(1d) object with 2500 curves observed at 14 argument values
# (1 observed, 2499 simulated).
# Contains:
# $ r     :  num [1:14] 0.665 0.694 0.723 0.752 0.781 ...
# $ funcs :  num [1:14, 1:2500] 1.03 1.05 1.07 1.1 1.13 ...
#  - attr(*, "dimnames")=List of 2
#   ..$ : chr [1:14] "24" "25" "26" "27" ...
#   ..$ : chr [1:2500] "obs" "sim1" "sim2" "sim3" ...
#
# ------ Inner loop. delaunay_triangulation: 51
# A curve_set(1d) object with 2500 curves observed at 14 argument values
# (1 observed, 2499 simulated).
# Contains:
# $ r     :  num [1:14] 0.665 0.694 0.723 0.752 0.781 ...
# $ funcs :  num [1:14, 1:2500] 1.01 1.03 1.06 1.09 1.11 ...
#  - attr(*, "dimnames")=List of 2
#   ..$ : chr [1:14] "24" "25" "26" "27" ...
#   ..$ : chr [1:2500] "obs" "sim1" "sim2" "sim3" ...
#
# ------ Inner loop. delaunay_triangulation: 52
# A curve_set(1d) object with 2500 curves observed at 14 argument values
# (1 observed, 2499 simulated).
# Contains:
# $ r     :  num [1:14] 0.665 0.694 0.723 0.752 0.781 ...
# $ funcs :  num [1:14, 1:2500] 1.04 1.06 1.08 1.11 1.13 ...
#  - attr(*, "dimnames")=List of 2
#   ..$ : chr [1:14] "24" "25" "26" "27" ...
#   ..$ : chr [1:2500] "obs" "sim1" "sim2" "sim3" ...
#
# ------ Inner loop. delaunay_triangulation: 53
# A curve_set(1d) object with 2500 curves observed at 14 argument values
# (1 observed, 2499 simulated).
# Contains:
# $ r     :  num [1:14] 0.665 0.694 0.723 0.752 0.781 ...
# $ funcs :  num [1:14, 1:2500] 1.02 1.04 1.06 1.09 1.11 ...
#  - attr(*, "dimnames")=List of 2
#   ..$ : chr [1:14] "24" "25" "26" "27" ...
#   ..$ : chr [1:2500] "obs" "sim1" "sim2" "sim3" ...
#
# ------ Inner loop. delaunay_triangulation: 54
# A curve_set(1d) object with 2500 curves observed at 14 argument values
# (1 observed, 2499 simulated).
# Contains:
# $ r     :  num [1:14] 0.665 0.694 0.723 0.752 0.781 ...
# $ funcs :  num [1:14, 1:2500] 1.02 1.05 1.07 1.1 1.12 ...
#  - attr(*, "dimnames")=List of 2
#   ..$ : chr [1:14] "24" "25" "26" "27" ...
#   ..$ : chr [1:2500] "obs" "sim1" "sim2" "sim3" ...
#
# ------ Inner loop. delaunay_triangulation: 55
# A curve_set(1d) object with 2500 curves observed at 14 argument values
# (1 observed, 2499 simulated).
# Contains:
# $ r     :  num [1:14] 0.665 0.694 0.723 0.752 0.781 ...
# $ funcs :  num [1:14, 1:2500] 1.02 1.05 1.07 1.09 1.12 ...
#  - attr(*, "dimnames")=List of 2
#   ..$ : chr [1:14] "24" "25" "26" "27" ...
#   ..$ : chr [1:2500] "obs" "sim1" "sim2" "sim3" ...
#
# ------ Inner loop. delaunay_triangulation: 56
# A curve_set(1d) object with 2500 curves observed at 14 argument values
# (1 observed, 2499 simulated).
# Contains:
# $ r     :  num [1:14] 0.665 0.694 0.723 0.752 0.781 ...
# $ funcs :  num [1:14, 1:2500] 1.03 1.05 1.07 1.1 1.13 ...
#  - attr(*, "dimnames")=List of 2
#   ..$ : chr [1:14] "24" "25" "26" "27" ...
#   ..$ : chr [1:2500] "obs" "sim1" "sim2" "sim3" ...
#
# ------ Inner loop. delaunay_triangulation: 57
# A curve_set(1d) object with 2500 curves observed at 14 argument values
# (1 observed, 2499 simulated).
# Contains:
# $ r     :  num [1:14] 0.665 0.694 0.723 0.752 0.781 ...
# $ funcs :  num [1:14, 1:2500] 1.03 1.06 1.08 1.11 1.13 ...
#  - attr(*, "dimnames")=List of 2
#   ..$ : chr [1:14] "24" "25" "26" "27" ...
#   ..$ : chr [1:2500] "obs" "sim1" "sim2" "sim3" ...
#
# ------ Inner loop. delaunay_triangulation: 58
# A curve_set(1d) object with 2500 curves observed at 14 argument values
# (1 observed, 2499 simulated).
# Contains:
# $ r     :  num [1:14] 0.665 0.694 0.723 0.752 0.781 ...
# $ funcs :  num [1:14, 1:2500] 1.04 1.06 1.09 1.11 1.14 ...
#  - attr(*, "dimnames")=List of 2
#   ..$ : chr [1:14] "24" "25" "26" "27" ...
#   ..$ : chr [1:2500] "obs" "sim1" "sim2" "sim3" ...
#
# ------ Inner loop. delaunay_triangulation: 59
# A curve_set(1d) object with 2500 curves observed at 14 argument values
# (1 observed, 2499 simulated).
# Contains:
# $ r     :  num [1:14] 0.665 0.694 0.723 0.752 0.781 ...
# $ funcs :  num [1:14, 1:2500] 1.04 1.06 1.08 1.11 1.13 ...
#  - attr(*, "dimnames")=List of 2
#   ..$ : chr [1:14] "24" "25" "26" "27" ...
#   ..$ : chr [1:2500] "obs" "sim1" "sim2" "sim3" ...
#
# ------ Inner loop. delaunay_triangulation: 60
# A curve_set(1d) object with 2500 curves observed at 14 argument values
# (1 observed, 2499 simulated).
# Contains:
# $ r     :  num [1:14] 0.665 0.694 0.723 0.752 0.781 ...
# $ funcs :  num [1:14, 1:2500] 1.02 1.05 1.07 1.09 1.12 ...
#  - attr(*, "dimnames")=List of 2
#   ..$ : chr [1:14] "24" "25" "26" "27" ...
#   ..$ : chr [1:2500] "obs" "sim1" "sim2" "sim3" ...
#
# ------ Inner loop. delaunay_triangulation: 61
# A curve_set(1d) object with 2500 curves observed at 14 argument values
# (1 observed, 2499 simulated).
# Contains:
# $ r     :  num [1:14] 0.665 0.694 0.723 0.752 0.781 ...
# $ funcs :  num [1:14, 1:2500] 1.03 1.05 1.08 1.1 1.12 ...
#  - attr(*, "dimnames")=List of 2
#   ..$ : chr [1:14] "24" "25" "26" "27" ...
#   ..$ : chr [1:2500] "obs" "sim1" "sim2" "sim3" ...
#
# ------ Inner loop. delaunay_triangulation: 62
# A curve_set(1d) object with 2500 curves observed at 14 argument values
# (1 observed, 2499 simulated).
# Contains:
# $ r     :  num [1:14] 0.665 0.694 0.723 0.752 0.781 ...
# $ funcs :  num [1:14, 1:2500] 1.03 1.05 1.07 1.1 1.12 ...
#  - attr(*, "dimnames")=List of 2
#   ..$ : chr [1:14] "24" "25" "26" "27" ...
#   ..$ : chr [1:2500] "obs" "sim1" "sim2" "sim3" ...
#
# ------ Inner loop. delaunay_triangulation: 63
# A curve_set(1d) object with 2500 curves observed at 14 argument values
# (1 observed, 2499 simulated).
# Contains:
# $ r     :  num [1:14] 0.665 0.694 0.723 0.752 0.781 ...
# $ funcs :  num [1:14, 1:2500] 1.03 1.06 1.08 1.11 1.13 ...
#  - attr(*, "dimnames")=List of 2
#   ..$ : chr [1:14] "24" "25" "26" "27" ...
#   ..$ : chr [1:2500] "obs" "sim1" "sim2" "sim3" ...
#
# ------ Inner loop. delaunay_triangulation: 64
# A curve_set(1d) object with 2500 curves observed at 14 argument values
# (1 observed, 2499 simulated).
# Contains:
# $ r     :  num [1:14] 0.665 0.694 0.723 0.752 0.781 ...
# $ funcs :  num [1:14, 1:2500] 1.03 1.05 1.08 1.1 1.13 ...
#  - attr(*, "dimnames")=List of 2
#   ..$ : chr [1:14] "24" "25" "26" "27" ...
#   ..$ : chr [1:2500] "obs" "sim1" "sim2" "sim3" ...
#
# ------ Inner loop. delaunay_triangulation: 65
# A curve_set(1d) object with 2500 curves observed at 14 argument values
# (1 observed, 2499 simulated).
# Contains:
# $ r     :  num [1:14] 0.665 0.694 0.723 0.752 0.781 ...
# $ funcs :  num [1:14, 1:2500] 1.02 1.05 1.07 1.1 1.12 ...
#  - attr(*, "dimnames")=List of 2
#   ..$ : chr [1:14] "24" "25" "26" "27" ...
#   ..$ : chr [1:2500] "obs" "sim1" "sim2" "sim3" ...
#
# ------ Inner loop. delaunay_triangulation: 66
# A curve_set(1d) object with 2500 curves observed at 14 argument values
# (1 observed, 2499 simulated).
# Contains:
# $ r     :  num [1:14] 0.665 0.694 0.723 0.752 0.781 ...
# $ funcs :  num [1:14, 1:2500] 1.02 1.05 1.07 1.1 1.12 ...
#  - attr(*, "dimnames")=List of 2
#   ..$ : chr [1:14] "24" "25" "26" "27" ...
#   ..$ : chr [1:2500] "obs" "sim1" "sim2" "sim3" ...
#
# ------ Inner loop. delaunay_triangulation: 67
# A curve_set(1d) object with 2500 curves observed at 14 argument values
# (1 observed, 2499 simulated).
# Contains:
# $ r     :  num [1:14] 0.665 0.694 0.723 0.752 0.781 ...
# $ funcs :  num [1:14, 1:2500] 1.03 1.05 1.08 1.1 1.13 ...
#  - attr(*, "dimnames")=List of 2
#   ..$ : chr [1:14] "24" "25" "26" "27" ...
#   ..$ : chr [1:2500] "obs" "sim1" "sim2" "sim3" ...
#
# ------ Inner loop. delaunay_triangulation: 68
# A curve_set(1d) object with 2500 curves observed at 14 argument values
# (1 observed, 2499 simulated).
# Contains:
# $ r     :  num [1:14] 0.665 0.694 0.723 0.752 0.781 ...
# $ funcs :  num [1:14, 1:2500] 1.03 1.06 1.08 1.11 1.13 ...
#  - attr(*, "dimnames")=List of 2
#   ..$ : chr [1:14] "24" "25" "26" "27" ...
#   ..$ : chr [1:2500] "obs" "sim1" "sim2" "sim3" ...
#
# ------ Inner loop. delaunay_triangulation: 69
# A curve_set(1d) object with 2500 curves observed at 14 argument values
# (1 observed, 2499 simulated).
# Contains:
# $ r     :  num [1:14] 0.665 0.694 0.723 0.752 0.781 ...
# $ funcs :  num [1:14, 1:2500] 1.02 1.05 1.07 1.09 1.12 ...
#  - attr(*, "dimnames")=List of 2
#   ..$ : chr [1:14] "24" "25" "26" "27" ...
#   ..$ : chr [1:2500] "obs" "sim1" "sim2" "sim3" ...
#
# ------ Inner loop. delaunay_triangulation: 70
# A curve_set(1d) object with 2500 curves observed at 14 argument values
# (1 observed, 2499 simulated).
# Contains:
# $ r     :  num [1:14] 0.665 0.694 0.723 0.752 0.781 ...
# $ funcs :  num [1:14, 1:2500] 1.02 1.04 1.06 1.09 1.11 ...
#  - attr(*, "dimnames")=List of 2
#   ..$ : chr [1:14] "24" "25" "26" "27" ...
#   ..$ : chr [1:2500] "obs" "sim1" "sim2" "sim3" ...
#
# ------ Inner loop. delaunay_triangulation: 71
# A curve_set(1d) object with 2500 curves observed at 14 argument values
# (1 observed, 2499 simulated).
# Contains:
# $ r     :  num [1:14] 0.665 0.694 0.723 0.752 0.781 ...
# $ funcs :  num [1:14, 1:2500] 1.03 1.05 1.07 1.1 1.13 ...
#  - attr(*, "dimnames")=List of 2
#   ..$ : chr [1:14] "24" "25" "26" "27" ...
#   ..$ : chr [1:2500] "obs" "sim1" "sim2" "sim3" ...
#
# ------ Inner loop. delaunay_triangulation: 72
# A curve_set(1d) object with 2500 curves observed at 14 argument values
# (1 observed, 2499 simulated).
# Contains:
# $ r     :  num [1:14] 0.665 0.694 0.723 0.752 0.781 ...
# $ funcs :  num [1:14, 1:2500] 1.03 1.05 1.07 1.09 1.12 ...
#  - attr(*, "dimnames")=List of 2
#   ..$ : chr [1:14] "24" "25" "26" "27" ...
#   ..$ : chr [1:2500] "obs" "sim1" "sim2" "sim3" ...
#
# ------ Inner loop. delaunay_triangulation: 73
# A curve_set(1d) object with 2500 curves observed at 14 argument values
# (1 observed, 2499 simulated).
# Contains:
# $ r     :  num [1:14] 0.665 0.694 0.723 0.752 0.781 ...
# $ funcs :  num [1:14, 1:2500] 1.02 1.05 1.07 1.1 1.12 ...
#  - attr(*, "dimnames")=List of 2
#   ..$ : chr [1:14] "24" "25" "26" "27" ...
#   ..$ : chr [1:2500] "obs" "sim1" "sim2" "sim3" ...
#
# ------ Inner loop. delaunay_triangulation: 74
# A curve_set(1d) object with 2500 curves observed at 14 argument values
# (1 observed, 2499 simulated).
# Contains:
# $ r     :  num [1:14] 0.665 0.694 0.723 0.752 0.781 ...
# $ funcs :  num [1:14, 1:2500] 1.03 1.05 1.07 1.1 1.13 ...
#  - attr(*, "dimnames")=List of 2
#   ..$ : chr [1:14] "24" "25" "26" "27" ...
#   ..$ : chr [1:2500] "obs" "sim1" "sim2" "sim3" ...
#
# ------ Inner loop. delaunay_triangulation: 75
# A curve_set(1d) object with 2500 curves observed at 14 argument values
# (1 observed, 2499 simulated).
# Contains:
# $ r     :  num [1:14] 0.665 0.694 0.723 0.752 0.781 ...
# $ funcs :  num [1:14, 1:2500] 1.03 1.05 1.07 1.1 1.12 ...
#  - attr(*, "dimnames")=List of 2
#   ..$ : chr [1:14] "24" "25" "26" "27" ...
#   ..$ : chr [1:2500] "obs" "sim1" "sim2" "sim3" ...
#
# ------ Inner loop. delaunay_triangulation: 76
# A curve_set(1d) object with 2500 curves observed at 14 argument values
# (1 observed, 2499 simulated).
# Contains:
# $ r     :  num [1:14] 0.665 0.694 0.723 0.752 0.781 ...
# $ funcs :  num [1:14, 1:2500] 1.02 1.05 1.07 1.09 1.12 ...
#  - attr(*, "dimnames")=List of 2
#   ..$ : chr [1:14] "24" "25" "26" "27" ...
#   ..$ : chr [1:2500] "obs" "sim1" "sim2" "sim3" ...
#
# ------ Inner loop. delaunay_triangulation: 77
# A curve_set(1d) object with 2500 curves observed at 14 argument values
# (1 observed, 2499 simulated).
# Contains:
# $ r     :  num [1:14] 0.665 0.694 0.723 0.752 0.781 ...
# $ funcs :  num [1:14, 1:2500] 1.02 1.04 1.07 1.09 1.12 ...
#  - attr(*, "dimnames")=List of 2
#   ..$ : chr [1:14] "24" "25" "26" "27" ...
#   ..$ : chr [1:2500] "obs" "sim1" "sim2" "sim3" ...
#
# ------ Inner loop. delaunay_triangulation: 78
# A curve_set(1d) object with 2500 curves observed at 14 argument values
# (1 observed, 2499 simulated).
# Contains:
# $ r     :  num [1:14] 0.665 0.694 0.723 0.752 0.781 ...
# $ funcs :  num [1:14, 1:2500] 1.02 1.04 1.07 1.09 1.12 ...
#  - attr(*, "dimnames")=List of 2
#   ..$ : chr [1:14] "24" "25" "26" "27" ...
#   ..$ : chr [1:2500] "obs" "sim1" "sim2" "sim3" ...
#
# ------ Inner loop. delaunay_triangulation: 79
# A curve_set(1d) object with 2500 curves observed at 14 argument values
# (1 observed, 2499 simulated).
# Contains:
# $ r     :  num [1:14] 0.665 0.694 0.723 0.752 0.781 ...
# $ funcs :  num [1:14, 1:2500] 1.03 1.05 1.07 1.1 1.12 ...
#  - attr(*, "dimnames")=List of 2
#   ..$ : chr [1:14] "24" "25" "26" "27" ...
#   ..$ : chr [1:2500] "obs" "sim1" "sim2" "sim3" ...
#
# ------ Inner loop. delaunay_triangulation: 80
# A curve_set(1d) object with 2500 curves observed at 14 argument values
# (1 observed, 2499 simulated).
# Contains:
# $ r     :  num [1:14] 0.665 0.694 0.723 0.752 0.781 ...
# $ funcs :  num [1:14, 1:2500] 1.03 1.05 1.07 1.1 1.12 ...
#  - attr(*, "dimnames")=List of 2
#   ..$ : chr [1:14] "24" "25" "26" "27" ...
#   ..$ : chr [1:2500] "obs" "sim1" "sim2" "sim3" ...
#
# ------ Inner loop. delaunay_triangulation: 81
# A curve_set(1d) object with 2500 curves observed at 14 argument values
# (1 observed, 2499 simulated).
# Contains:
# $ r     :  num [1:14] 0.665 0.694 0.723 0.752 0.781 ...
# $ funcs :  num [1:14, 1:2500] 1.03 1.06 1.08 1.1 1.13 ...
#  - attr(*, "dimnames")=List of 2
#   ..$ : chr [1:14] "24" "25" "26" "27" ...
#   ..$ : chr [1:2500] "obs" "sim1" "sim2" "sim3" ...
#
# ------ Inner loop. delaunay_triangulation: 82
# A curve_set(1d) object with 2500 curves observed at 14 argument values
# (1 observed, 2499 simulated).
# Contains:
# $ r     :  num [1:14] 0.665 0.694 0.723 0.752 0.781 ...
# $ funcs :  num [1:14, 1:2500] 1.03 1.06 1.08 1.1 1.13 ...
#  - attr(*, "dimnames")=List of 2
#   ..$ : chr [1:14] "24" "25" "26" "27" ...
#   ..$ : chr [1:2500] "obs" "sim1" "sim2" "sim3" ...
#
# ------ Inner loop. delaunay_triangulation: 83
# A curve_set(1d) object with 2500 curves observed at 14 argument values
# (1 observed, 2499 simulated).
# Contains:
# $ r     :  num [1:14] 0.665 0.694 0.723 0.752 0.781 ...
# $ funcs :  num [1:14, 1:2500] 1.03 1.05 1.07 1.1 1.12 ...
#  - attr(*, "dimnames")=List of 2
#   ..$ : chr [1:14] "24" "25" "26" "27" ...
#   ..$ : chr [1:2500] "obs" "sim1" "sim2" "sim3" ...
#
# ------ Inner loop. delaunay_triangulation: 84
# A curve_set(1d) object with 2500 curves observed at 14 argument values
# (1 observed, 2499 simulated).
# Contains:
# $ r     :  num [1:14] 0.665 0.694 0.723 0.752 0.781 ...
# $ funcs :  num [1:14, 1:2500] 1.02 1.05 1.07 1.09 1.12 ...
#  - attr(*, "dimnames")=List of 2
#   ..$ : chr [1:14] "24" "25" "26" "27" ...
#   ..$ : chr [1:2500] "obs" "sim1" "sim2" "sim3" ...
#
# ------ Inner loop. delaunay_triangulation: 85
# A curve_set(1d) object with 2500 curves observed at 14 argument values
# (1 observed, 2499 simulated).
# Contains:
# $ r     :  num [1:14] 0.665 0.694 0.723 0.752 0.781 ...
# $ funcs :  num [1:14, 1:2500] 1.02 1.05 1.07 1.1 1.12 ...
#  - attr(*, "dimnames")=List of 2
#   ..$ : chr [1:14] "24" "25" "26" "27" ...
#   ..$ : chr [1:2500] "obs" "sim1" "sim2" "sim3" ...
#
# ------ Inner loop. delaunay_triangulation: 86
# A curve_set(1d) object with 2500 curves observed at 14 argument values
# (1 observed, 2499 simulated).
# Contains:
# $ r     :  num [1:14] 0.665 0.694 0.723 0.752 0.781 ...
# $ funcs :  num [1:14, 1:2500] 1.03 1.05 1.07 1.1 1.12 ...
#  - attr(*, "dimnames")=List of 2
#   ..$ : chr [1:14] "24" "25" "26" "27" ...
#   ..$ : chr [1:2500] "obs" "sim1" "sim2" "sim3" ...
#
# ------ Inner loop. delaunay_triangulation: 87
# A curve_set(1d) object with 2500 curves observed at 14 argument values
# (1 observed, 2499 simulated).
# Contains:
# $ r     :  num [1:14] 0.665 0.694 0.723 0.752 0.781 ...
# $ funcs :  num [1:14, 1:2500] 1.03 1.05 1.07 1.1 1.12 ...
#  - attr(*, "dimnames")=List of 2
#   ..$ : chr [1:14] "24" "25" "26" "27" ...
# ...
#
# Computing histogram...
# ------ Inner loop. sz_classification: 16
#         1024
#
# Computing histogram...
# ------ Inner loop. sz_classification: 17
#         1024
#
# Computing histogram...
# ------ Inner loop. sz_classification: 18
#         1024
#
# Computing histogram...
# ------ Inner loop. sz_classification: 19
#         1024
#
# Computing histogram...
# ------ Inner loop. sz_classification: 20
#         1024
#
# Computing histogram...
# ------ Inner loop. sz_classification: 21
#         1024
#
# Computing histogram...
# ------ Inner loop. sz_classification: 22
#         1024
#
# Computing histogram...
# ------ Inner loop. sz_classification: 23
#         1024
#
# Computing histogram...
# ------ Inner loop. sz_classification: 24
#         1024
#
# Computing histogram...
# ------ Inner loop. sz_classification: 25
#         1024
#
# Computing histogram...
# ------ Inner loop. sz_classification: 26
#         1024
#
# Computing histogram...
# ------ Inner loop. sz_classification: 27
#         1024
#
# Computing histogram...
# ------ Inner loop. sz_classification: 28
#         1024
#
# Computing histogram...
# ------ Inner loop. sz_classification: 29
#         1024
#
# Computing histogram...
# ------ Inner loop. sz_classification: 30
#         1024
#
# Computing histogram...
# ------ Inner loop. sz_classification: 31
#         1024
#
# Computing histogram...
# ------ Inner loop. sz_classification: 32
#         1024
#
# Computing histogram...
# ------ Inner loop. sz_classification: 33
#         1024
#
# Computing histogram...
# ------ Inner loop. sz_classification: 34
#         1024
#
# Computing histogram...
# ------ Inner loop. sz_classification: 35
#         1024
#
# Computing histogram...
# ------ Inner loop. sz_classification: 36
#         1024
#
# Computing histogram...
# ------ Inner loop. sz_classification: 37
#         1024
#
# Computing histogram...
# ------ Inner loop. sz_classification: 38
#         1024
#
# Computing histogram...
# ------ Inner loop. sz_classification: 39
#         1024
#
# Computing histogram...
# ------ Inner loop. sz_classification: 40
#         1024
#
# Computing histogram...
# ------ Inner loop. sz_classification: 41
#         1024
#
# Computing histogram...
# ------ Inner loop. sz_classification: 42
#         1024
#
# Computing histogram...
# ------ Inner loop. sz_classification: 43
#         1024
#
# Computing histogram...
# ------ Inner loop. sz_classification: 44
#         1024
#
# Computing histogram...
# ------ Inner loop. sz_classification: 45
#         1024
#
# Computing histogram...
# ------ Inner loop. sz_classification: 46
#         1024
#
# Computing histogram...
# ------ Inner loop. sz_classification: 47
#         1024
#
# Computing histogram...
# ------ Inner loop. sz_classification: 48
#         1024
#
# Computing histogram...
# ------ Inner loop. sz_classification: 49
#         1024
#
# Computing histogram...
# ------ Inner loop. sz_classification: 50
#         1024
#
# Computing histogram...
# ------ Inner loop. sz_classification: 51
#         1024
#
# Computing histogram...
# ------ Inner loop. sz_classification: 52
#         1024
#
# Computing histogram...
# ------ Inner loop. sz_classification: 53
#         1024
#
# Computing histogram...
# ------ Inner loop. sz_classification: 54
#         1024
#
# Computing histogram...
# ------ Inner loop. sz_classification: 55
#         1024
#
# Computing histogram...
# ------ Inner loop. sz_classification: 56
#         1024
#
# Computing histogram...
# ------ Inner loop. sz_classification: 57
#         1024
#
# Computing histogram...
# ------ Inner loop. sz_classification: 58
#         1024
#
# Computing histogram...
# ------ Inner loop. sz_classification: 59
#         1024
#
# Computing histogram...
# ------ Inner loop. sz_classification: 60
#         1024
#
# Computing histogram...
# ------ Inner loop. sz_classification: 61
#         1024
#
# Computing histogram...
# ------ Inner loop. sz_classification: 62
#         1024
#
# Computing histogram...
# ------ Inner loop. sz_classification: 63
#         1024
#
# Computing histogram...
# ------ Inner loop. sz_classification: 64
#         1024
#
# Computing histogram...
# ------ Inner loop. sz_classification: 65
#         1024
#
# Computing histogram...
# ------ Inner loop. sz_classification: 66
#         1024
#
# Computing histogram...
# ------ Inner loop. sz_classification: 67
#         1024
#
# Computing histogram...
# ------ Inner loop. sz_classification: 68
#         1024
#
# Computing histogram...
# ------ Inner loop. sz_classification: 69
#         1024
#
# Computing histogram...
# ------ Inner loop. sz_classification: 70
#         1024
#
# Computing histogram...
# ------ Inner loop. sz_classification: 71
#         1024
#
# Computing histogram...
# ------ Inner loop. sz_classification: 72
#         1024
#
# Computing histogram...
# ------ Inner loop. sz_classification: 73
#         1024
#
# Computing histogram...
# ------ Inner loop. sz_classification: 74
#         1024
#
# Computing histogram...
# ------ Inner loop. sz_classification: 75
#         1024
#
# Computing histogram...
# ------ Inner loop. sz_classification: 76
#         1024
#
# Computing histogram...
# ------ Inner loop. sz_classification: 77
#         1024
#
# Computing histogram...
# ------ Inner loop. sz_classification: 78
#         1024
#
# Computing histogram...
# ------ Inner loop. sz_classification: 79
#         1024
#
# Computing histogram...
# ------ Inner loop. sz_classification: 80
#         1024
#
# Computing histogram...
# ------ Inner loop. sz_classification: 81
#         1024
#
# Computing histogram...
# ------ Inner loop. sz_classification: 82
#         1024
#
# Computing histogram...
# ------ Inner loop. sz_classification: 83
#         1024
#
# Computing histogram...
# ------ Inner loop. sz_classification: 84
#         1024
#
# Computing histogram...
# ------ Inner loop. sz_classification: 85
#         1024
#
# Computing histogram...
# ------ Inner loop. sz_classification: 86
#         1024
#
# Computing histogram...
# ------ Inner loop. sz_classification: 87
#         1024
#
# Computing histogram...
# ------ Inner loop. sz_classification: 88
#         1024
#
# Computing histogram...
# ------ Inner loop. sz_classification: 89
#         1024
#
# Computing histogram...
# ------ Inner loop. sz_classification: 90
#         1024
#
# Computing histogram...
# ------ Inner loop. sz_classification: 91
#         1024
#
# Computing histogram...
# ------ Inner loop. sz_classification: 92
#         1024
#
# Computing histogram...
# ------ Inner loop. sz_classification: 93
#         1024
#
# Computing histogram...
# ------ Inner loop. sz_classification: 94
#         1024
#
# Computing histogram...
# ------ Inner loop. sz_classification: 95
#         1024
#
# Computing histogram...
# ------ Inner loop. sz_classification: 96
#         1024
#
# Computing histogram...
# ------ Inner loop. sz_classification: 97
#         1024
#
# Computing histogram...
# ------ Inner loop. sz_classification: 98
#         1024
#
# Computing histogram...
# ------ Inner loop. sz_classification: 99
#         1024
#
# Computing histogram...
# Elapsed:5.204440243244171
# --- Method: thresholding_garrote
# ---- Parameters Combination: 0
# ------ Inner loop. thresholding_garrote: 0
# ------ Inner loop. thresholding_garrote: 1
# ------ Inner loop. thresholding_garrote: 2
# ------ Inner loop. thresholding_garrote: 3
# ------ Inner loop. thresholding_garrote: 4
# ------ Inner loop. thresholding_garrote: 5
# ------ Inner loop. thresholding_garrote: 6
# ------ Inner loop. thresholding_garrote: 7
# ------ Inner loop. thresholding_garrote: 8
# ------ Inner loop. thresholding_garrote: 9
# ------ Inner loop. thresholding_garrote: 10
# ------ Inner loop. thresholding_garrote: 11
# ------ Inner loop. thresholding_garrote: 12
# ------ Inner loop. thresholding_garrote: 13
# ------ Inner loop. thresholding_garrote: 14
# ------ Inner loop. thresholding_garrote: 15
# ------ Inner loop. thresholding_garrote: 16
# ------ Inner loop. thresholding_garrote: 17
# ------ Inner loop. thresholding_garrote: 18
# ------ Inner loop. thresholding_garrote: 19
# ------ Inner loop. thresholding_garrote: 20
# ------ Inner loop. thresholding_garrote: 21
# ------ Inner loop. thresholding_garrote: 22
# ------ Inner loop. thresholding_garrote: 23
# ------ Inner loop. thresholding_garrote: 24
# ------ Inner loop. thresholding_garrote: 25
# ------ Inner loop. thresholding_garrote: 26
# ------ Inner loop. thresholding_garrote: 27
# ------ Inner loop. thresholding_garrote: 28
# ------ Inner loop. thresholding_garrote: 29
# ------ Inner loop. thresholding_garrote: 30
# ------ Inner loop. thresholding_garrote: 31
# ------ Inner loop. thresholding_garrote: 32
# ------ Inner loop. thresholding_garrote: 33
# ------ Inner loop. thresholding_garrote: 34
# ------ Inner loop. thresholding_garrote: 35
# ------ Inner loop. thresholding_garrote: 36
# ------ Inner loop. thresholding_garrote: 37
# ------ Inner loop. thresholding_garrote: 38
# ------ Inner loop. thresholding_garrote: 39
# ------ Inner loop. thresholding_garrote: 40
# ------ Inner loop. thresholding_garrote: 41
# ------ Inner loop. thresholding_garrote: 42
# ------ Inner loop. thresholding_garrote: 43
# ------ Inner loop. thresholding_garrote: 44
# ------ Inner loop. thresholding_garrote: 45
# ------ Inner loop. thresholding_garrote: 46
# ------ Inner loop. thresholding_garrote: 47
# ------ Inner loop. thresholding_garrote: 48
# ------ Inner loop. thresholding_garrote: 49
# ------ Inner loop. thresholding_garrote: 50
# ------ Inner loop. thresholding_garrote: 51
# ------ Inner loop. thresholding_garrote: 52
# ------ Inner loop. thresholding_garrote: 53
# ------ Inner loop. thresholding_garrote: 54
# ------ Inner loop. thresholding_garrote: 55
# ------ Inner loop. thresholding_garrote: 56
# ------ Inner loop. thresholding_garrote: 57
# ------ Inner loop. thresholding_garrote: 58
# ------ Inner loop. thresholding_garrote: 59
# ------ Inner loop. thresholding_garrote: 60
# ------ Inner loop. thresholding_garrote: 61
# ------ Inner loop. thresholding_garrote: 62
# ------ Inner loop. thresholding_garrote: 63
# ------ Inner loop. thresholding_garrote: 64
# ------ Inner loop. thresholding_garrote: 65
# ------ Inner loop. thresholding_garrote: 66
# ------ Inner loop. thresholding_garrote: 67
# ------ Inner loop. thresholding_garrote: 68
# ------ Inner loop. thresholding_garrote: 69
# ------ Inner loop. thresholding_garrote: 70
# ------ Inner loop. thresholding_garrote: 71
# ------ Inner loop. thresholding_garrote: 72
# ------ Inner loop. thresholding_garrote: 73
# ------ Inner loop. thresholding_garrote: 74
# ------ Inner loop. thresholding_garrote: 75
# ------ Inner loop. thresholding_garrote: 76
# ------ Inner loop. thresholding_garrote: 77
# ------ Inner loop. thresholding_garrote: 78
# ------ Inner loop. thresholding_garrote: 79
# ------ Inner loop. thresholding_garrote: 80
# ------ Inner loop. thresholding_garrote: 81
# ------ Inner loop. thresholding_garrote: 82
# ------ Inner loop. thresholding_garrote: 83
# ------ Inner loop. thresholding_garrote: 84
# ------ Inner loop. thresholding_garrote: 85
# ------ Inner loop. thresholding_garrote: 86
# ------ Inner loop. thresholding_garrote: 87
# ------ Inner loop. thresholding_garrote: 88
# ------ Inner loop. thresholding_garrote: 89
# ------ Inner loop. thresholding_garrote: 90
# ------ Inner loop. thresholding_garrote: 91
# ------ Inner loop. thresholding_garrote: 92
# ------ Inner loop. thresholding_garrote: 93
# ------ Inner loop. thresholding_garrote: 94
# ------ Inner loop. thresholding_garrote: 95
# ------ Inner loop. thresholding_garrote: 96
# ------ Inner loop. thresholding_garrote: 97
# ------ Inner loop. thresholding_garrote: 98
# ------ Inner loop. thresholding_garrote: 99
# Elapsed:0.18208914041519164
# --- Method: thresholding_hard
# ---- Parameters Combination: 0
# ------ Inner loop. thresholding_hard: 0
# ------ Inner loop. thresholding_hard: 1
# ------ Inner loop. thresholding_hard: 2
# ------ Inner loop. thresholding_hard: 3
# ------ Inner loop. thresholding_hard: 4
# ------ Inner loop. thresholding_hard: 5
# ------ Inner loop. thresholding_hard: 6
# ------ Inner loop. thresholding_hard: 7
# ------ Inner loop. thresholding_hard: 8
# ------ Inner loop. thresholding_hard: 9
# ------ Inner loop. thresholding_hard: 10
# ------ Inner loop. thresholding_hard: 11
# ------ Inner loop. thresholding_hard: 12
# ------ Inner loop. thresholding_hard: 13
# ------ Inner loop. thresholding_hard: 14
# ------ Inner loop. thresholding_hard: 15
# ------ Inner loop. thresholding_hard: 16
# ------ Inner loop. thresholding_hard: 17
# ------ Inner loop. thresholding_hard: 18
# ------ Inner loop. thresholding_hard: 19
# ------ Inner loop. thresholding_hard: 20
# ------ Inner loop. thresholding_hard: 21
# ------ Inner loop. thresholding_hard: 22
# ------ Inner loop. thresholding_hard: 23
# ------ Inner loop. thresholding_hard: 24
# ------ Inner loop. thresholding_hard: 25
# ------ Inner loop. thresholding_hard: 26
# ------ Inner loop. thresholding_hard: 27
# ------ Inner loop. thresholding_hard: 28
# ------ Inner loop. thresholding_hard: 29
# ------ Inner loop. thresholding_hard: 30
# ------ Inner loop. thresholding_hard: 31
# ------ Inner loop. thresholding_hard: 32
# ------ Inner loop. thresholding_hard: 33
# ------ Inner loop. thresholding_hard: 34
# ------ Inner loop. thresholding_hard: 35
# ------ Inner loop. thresholding_hard: 36
# ------ Inner loop. thresholding_hard: 37
# ------ Inner loop. thresholding_hard: 38
# ------ Inner loop. thresholding_hard: 39
# ------ Inner loop. thresholding_hard: 40
# ------ Inner loop. thresholding_hard: 41
# ------ Inner loop. thresholding_hard: 42
# ------ Inner loop. thresholding_hard: 43
# ------ Inner loop. thresholding_hard: 44
# ------ Inner loop. thresholding_hard: 45
# ------ Inner loop. thresholding_hard: 46
# ------ Inner loop. thresholding_hard: 47
# ------ Inner loop. thresholding_hard: 48
# ------ Inner loop. thresholding_hard: 49
# ------ Inner loop. thresholding_hard: 50
# ------ Inner loop. thresholding_hard: 51
# ------ Inner loop. thresholding_hard: 52
# ------ Inner loop. thresholding_hard: 53
# ------ Inner loop. thresholding_hard: 54
# ------ Inner loop. thresholding_hard: 55
# ------ Inner loop. thresholding_hard: 56
# ------ Inner loop. thresholding_hard: 57
# ------ Inner loop. thresholding_hard: 58
# ------ Inner loop. thresholding_hard: 59
# ------ Inner loop. thresholding_hard: 60
# ------ Inner loop. thresholding_hard: 61
# ------ Inner loop. thresholding_hard: 62
# ------ Inner loop. thresholding_hard: 63
# ------ Inner loop. thresholding_hard: 64
# ------ Inner loop. thresholding_hard: 65
# ------ Inner loop. thresholding_hard: 66
# ------ Inner loop. thresholding_hard: 67
# ------ Inner loop. thresholding_hard: 68
# ------ Inner loop. thresholding_hard: 69
# ------ Inner loop. thresholding_hard: 70
# ------ Inner loop. thresholding_hard: 71
# ------ Inner loop. thresholding_hard: 72
# ------ Inner loop. thresholding_hard: 73
# ------ Inner loop. thresholding_hard: 74
# ------ Inner loop. thresholding_hard: 75
# ------ Inner loop. thresholding_hard: 76
# ------ Inner loop. thresholding_hard: 77
# ------ Inner loop. thresholding_hard: 78
# ------ Inner loop. thresholding_hard: 79
# ------ Inner loop. thresholding_hard: 80
# ------ Inner loop. thresholding_hard: 81
# ------ Inner loop. thresholding_hard: 82
# ------ Inner loop. thresholding_hard: 83
# ------ Inner loop. thresholding_hard: 84
# ------ Inner loop. thresholding_hard: 85
# ------ Inner loop. thresholding_hard: 86
# ------ Inner loop. thresholding_hard: 87
# ------ Inner loop. thresholding_hard: 88
# ------ Inner loop. thresholding_hard: 89
# ------ Inner loop. thresholding_hard: 90
# ------ Inner loop. thresholding_hard: 91
# ------ Inner loop. thresholding_hard: 92
# ------ Inner loop. thresholding_hard: 93
# ------ Inner loop. thresholding_hard: 94
# ------ Inner loop. thresholding_hard: 95
# ------ Inner loop. thresholding_hard: 96
# ------ Inner loop. thresholding_hard: 97
# ------ Inner loop. thresholding_hard: 98
# ------ Inner loop. thresholding_hard: 99
# Elapsed:0.17030053377151488
# The test has finished.
#                                                  Mean       Std
# brevdo_method-([], {})                       0.202186  0.007627
# contour_filtering-([], {})                   6.442941  0.541625
# delaunay_triangulation-{'LB': 1.6}           0.365732  0.018060
# delaunay_triangulation-{'adapt_thr': True}  11.777884  1.657351
# empty_space-{'adapt_thr': True}             13.626914  1.709150
# empty_space-{'radi_seg': 0.8}                2.430968  0.051104
# pseudo_bayesian_method-([], {})              0.601340  0.031247
# sz_classification-([], {})                   5.204440  0.871541
# thresholding_garrote-([], {})                0.182089  0.008445
# thresholding_hard-([], {})                   0.170301  0.015069

# %%
df = interpreter.elapsed_time_summary()
df
# Out:
#                                                  Mean       Std
# brevdo_method-([], {})                       0.202186  0.007627
# contour_filtering-([], {})                   6.442941  0.541625
# delaunay_triangulation-{'LB': 1.6}           0.365732  0.018060
# delaunay_triangulation-{'adapt_thr': True}  11.777884  1.657351
# empty_space-{'adapt_thr': True}             13.626914  1.709150
# empty_space-{'radi_seg': 0.8}                2.430968  0.051104
# pseudo_bayesian_method-([], {})              0.601340  0.031247
# sz_classification-([], {})                   5.204440  0.871541
# thresholding_garrote-([], {})                0.182089  0.008445
# thresholding_hard-([], {})                   0.170301  0.015069
